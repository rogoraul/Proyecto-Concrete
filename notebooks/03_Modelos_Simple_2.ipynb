# %% [markdown]
# <a href="https://colab.research.google.com/github/rogoraul/Proyecto-Concrete/blob/main/notebooks/03_Modelos_Simple_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Concrete Crack Images for Classification
#
# ---

# %%
# Cargamos las librerias necesarias
import sys
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import zipfile
import shutil
import pandas as pd
import seaborn as sns
from PIL import Image
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from google.colab import files
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
import kagglehub
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import tensorflow as tf
from tensorflow.keras.metrics import Recall, AUC, Precision
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import roc_curve, auc

# %%
# Descarga de los datos
path = kagglehub.dataset_download("aniruddhsharma/structural-defects-network-concrete-crack-images")
print("Path to dataset files:", path)

os.makedirs('./data', exist_ok=True)

datasets_dl = {'structural_defects': path}

for name, source in datasets_dl.items():
    target = os.path.join('./data', name)
    if not os.path.exists(target):
        os.symlink(source, target)
        print(f'Dataset {name} vinculado en: {target}')
    else:
        print(f'El enlace para {name} ya existe en ./data')

print('\nContenido actual de ./data:', os.listdir('./data'))
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (1.0.0).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/aniruddhsharma/structural-defects-network-concrete-crack-images?dataset_version_number=1...
# 100%|██████████| 506M/506M [00:15<00:00, 33.2MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/aniruddhsharma/structural-defects-network-concrete-crack-images/versions/1
# Dataset structural_defects vinculado en: ./data/structural_defects
#
# Contenido actual de ./data: ['structural_defects']

# %%
# Fusión de las imagenes en una sola carpeta
structural_defects_path = Path('./data/structural_defects')
merged_path = Path('./data/merged_cracks')
merged_path.mkdir(exist_ok=True)

clases = ['Positive', 'Negative']
for clase in clases:
    (merged_path / clase).mkdir(exist_ok=True)

total_stats = {'Positive': 0, 'Negative': 0}

# Structural Defects (Cracked / Non-cracked × 3)
sd_mapping = {
    'Positive': [
        structural_defects_path / 'Walls' / 'Cracked',
        structural_defects_path / 'Decks' / 'Cracked',
        structural_defects_path / 'Pavements' / 'Cracked',
    ],
    'Negative': [
        structural_defects_path / 'Walls' / 'Non-cracked',
        structural_defects_path / 'Decks' / 'Non-cracked',
        structural_defects_path / 'Pavements' / 'Non-cracked',
    ],
}

for clase, dirs in sd_mapping.items():
    for src_dir in dirs:
        tag = src_dir.parent.name[:2].lower()  # wa, de, pa
        count = 0
        for img_file in src_dir.iterdir():
            if img_file.is_file():
                dest_file = merged_path / clase / f"sd_{tag}_{img_file.name}"
                if not dest_file.exists():
                    shutil.copy2(str(img_file), str(dest_file))
                    count += 1
        total_stats[clase] += count
        print(f"Structural Defects [{src_dir.parent.name}/{src_dir.name}]: +{count}")

# Resumen final
n_pos = len(list((merged_path / 'Positive').iterdir()))
n_neg = len(list((merged_path / 'Negative').iterdir()))
print(f"Dataset fusionado en: {merged_path.resolve()}")
print(f"  Positive (Grieta):    {n_pos}")
print(f"  Negative (Sin Grieta): {n_neg}")
print(f"  Total:                 {n_pos + n_neg}")
if n_pos > 0:
    print(f"  Ratio Neg/Pos:         {n_neg/n_pos:.2f}")
else:
    print("  Ratio Neg/Pos:         N/A")
# Out:
# Structural Defects [Walls/Cracked]: +3851
# Structural Defects [Decks/Cracked]: +2025
# Structural Defects [Pavements/Cracked]: +2608
# Structural Defects [Walls/Non-cracked]: +14287
# Structural Defects [Decks/Non-cracked]: +11595
# Structural Defects [Pavements/Non-cracked]: +21726
# Dataset fusionado en: /content/data/merged_cracks
#   Positive (Grieta):    8484
#   Negative (Sin Grieta): 47608
#   Total:                 56092
#   Ratio Neg/Pos:         5.61

# %%
# Split en Train, Validation y Test
SOURCE_DIR = Path('./data/merged_cracks')
SPLIT_DIR  = Path('./data/split')

# Recopilar todos los paths y labels
all_paths  = []
all_labels = []

for img_path in sorted((SOURCE_DIR / 'Positive').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(1)
for img_path in sorted((SOURCE_DIR / 'Negative').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(0)

print(f"Total imágenes encontradas: {len(all_paths)}")
print(f"  Positivas: {sum(all_labels)}, Negativas: {len(all_labels) - sum(all_labels)}")

# Split 60% train / 20% val / 20% test
paths_tv, paths_test, y_tv, y_te = train_test_split(
    all_paths, all_labels, test_size=0.2, random_state=42, stratify=all_labels
)
paths_train, paths_val, y_tr, y_va = train_test_split(
    paths_tv, y_tv, test_size=0.25, random_state=42, stratify=y_tv
)

# Crear directorios y copiar archivos
splits = {'train': paths_train, 'val': paths_val, 'test': paths_test}

for split_name, split_paths in splits.items():
    for cls in ['Positive', 'Negative']:
        (SPLIT_DIR / split_name / cls).mkdir(parents=True, exist_ok=True)

    copied = 0
    for p in split_paths:
        cls = p.parent.name
        dest = SPLIT_DIR / split_name / cls / p.name
        if not dest.exists():
            shutil.copy2(str(p), str(dest))
            copied += 1

    total = len(list((SPLIT_DIR / split_name / 'Positive').iterdir())) + \
            len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))
    print(f"\n{split_name.upper()}: {total} imágenes ({copied} copiadas ahora)")
    print(f"  Positive: {len(list((SPLIT_DIR / split_name / 'Positive').iterdir()))}")
    print(f"  Negative: {len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))}")
# Out:
# Total imágenes encontradas: 56092
#   Positivas: 8484, Negativas: 47608
#
# TRAIN: 33654 imágenes (33654 copiadas ahora)
#   Positive: 5090
#   Negative: 28564
#
# VAL: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522
#
# TEST: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522

# %%
import importlib

os.makedirs('models', exist_ok=True)

with open('models/cnn_simple2.py', 'w') as f:
    f.write("""
import tensorflow as tf
from tensorflow.keras import layers, models
def build_simple_2(input_shape=(227, 227, 3)):
  model = models.Sequential([
          layers.Input(shape=input_shape),

          layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
          layers.MaxPooling2D((2, 2)),
          layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
          layers.MaxPooling2D((2, 2)),
          layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
          layers.MaxPooling2D((2, 2)),

          layers.GlobalAveragePooling2D(),
          layers.Dense(256, activation='relu'),
          layers.Dropout(0.3),
          layers.Dense(1, activation='sigmoid')
      ])
  return model
""")

sys.path.append('./models')

import cnn_simple2
importlib.reload(cnn_simple2)

from cnn_simple2 import build_simple_2

modelo_complejo = build_simple_2()
modelo_complejo.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 227, 227, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 113, 113, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 436,865 (1.67 MB)
#  Trainable params: 436,865 (1.67 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Carga de datos para entrenamiento
IMG_SIZE = (227, 227)
BATCH_SIZE = 32

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'train'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=True, seed=42
)

val_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'val'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)

test_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'test'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)
# Out:
# Found 33654 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import Adam
# Compilacion y entrenamiento
model = build_simple_2(input_shape=(227, 227, 3))

# Compilamos usando un Learning Rate bajo
optimizer = Adam(learning_rate=0.00001)
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy', Recall(name='recall'), Precision(name='precision'), AUC(name='auc')]
)
csv_logger = CSVLogger('historial_entrenamiento_cnn2.csv', append=True)
checkpoint = ModelCheckpoint('best_cnn_model2.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.0000001, verbose=1, mode='max')
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True, mode='max')

n_pos = 8484   # Positive (Clase 1)
n_neg = 47608  # Negative (Clase 0)
total = n_pos + n_neg

# Fórmula para balancear pesos
weight_for_0 = (1 / n_neg) * (total / 2.0)
weight_for_1 = (1 / n_pos) * (total / 2.0)

class_weight = {
    0: weight_for_0,
    1: weight_for_1
}

print(f"Peso para Negative (0): {weight_for_0:.2f}")
print(f"Peso para Positive (1): {weight_for_1:.2f}")

history = model.fit(
    train_gen,
    validation_data=val_gen,
    class_weight=class_weight,
    epochs=120,
    callbacks=[checkpoint, reduce_lr, early_stopping, csv_logger]
)

# Cargar el modelo en su mejor punto
model.load_weights('best_cnn_model_2.keras')
# Out:
# Peso para Negative (0): 0.59
# Peso para Positive (1): 3.31
# Epoch 1/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5086 - auc: 0.5313 - loss: 1.0524 - precision: 0.1652 - recall: 0.5507
# Epoch 1: val_accuracy improved from None to 0.28880, saving model to best_resnet_model_6.keras
#
# Epoch 1: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 175s 155ms/step - accuracy: 0.5113 - auc: 0.5429 - loss: 0.8511 - precision: 0.1684 - recall: 0.5664 - val_accuracy: 0.2888 - val_auc: 0.6608 - val_loss: 0.7618 - val_precision: 0.1686 - val_recall: 0.9417 - learning_rate: 1.0000e-05
# Epoch 2/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5016 - auc: 0.5861 - loss: 0.6971 - precision: 0.1811 - recall: 0.6384
# Epoch 2: val_accuracy improved from 0.28880 to 0.48899, saving model to best_resnet_model_6.keras
#
# Epoch 2: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.5147 - auc: 0.5985 - loss: 0.6849 - precision: 0.1834 - recall: 0.6399 - val_accuracy: 0.4890 - val_auc: 0.6734 - val_loss: 0.6758 - val_precision: 0.1995 - val_recall: 0.7896 - learning_rate: 1.0000e-05
# Epoch 3/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5378 - auc: 0.6378 - loss: 0.6602 - precision: 0.1972 - recall: 0.6844
# Epoch 3: val_accuracy improved from 0.48899 to 0.57447, saving model to best_resnet_model_6.keras
#
# Epoch 3: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.5300 - auc: 0.6331 - loss: 0.6667 - precision: 0.1975 - recall: 0.6878 - val_accuracy: 0.5745 - val_auc: 0.6468 - val_loss: 0.5824 - val_precision: 0.2037 - val_recall: 0.6235 - learning_rate: 1.0000e-05
# Epoch 4/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5437 - auc: 0.6308 - loss: 0.6629 - precision: 0.1955 - recall: 0.6677
# Epoch 4: val_accuracy did not improve from 0.57447
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.5351 - auc: 0.6389 - loss: 0.6645 - precision: 0.1995 - recall: 0.6882 - val_accuracy: 0.5139 - val_auc: 0.6657 - val_loss: 0.6353 - val_precision: 0.1969 - val_recall: 0.7189 - learning_rate: 1.0000e-05
# Epoch 5/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5348 - auc: 0.6476 - loss: 0.6612 - precision: 0.2019 - recall: 0.6921
# Epoch 5: val_accuracy improved from 0.57447 to 0.66165, saving model to best_resnet_model_6.keras
#
# Epoch 5: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.5414 - auc: 0.6546 - loss: 0.6560 - precision: 0.2028 - recall: 0.6935 - val_accuracy: 0.6616 - val_auc: 0.6762 - val_loss: 0.6067 - val_precision: 0.2354 - val_recall: 0.5504 - learning_rate: 1.0000e-05
# Epoch 6/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.5375 - auc: 0.6567 - loss: 0.6638 - precision: 0.2117 - recall: 0.7202
# Epoch 6: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.5456 - auc: 0.6606 - loss: 0.6535 - precision: 0.2070 - recall: 0.7083 - val_accuracy: 0.4743 - val_auc: 0.7031 - val_loss: 0.6848 - val_precision: 0.2029 - val_recall: 0.8450 - learning_rate: 1.0000e-05
# Epoch 7/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5526 - auc: 0.6769 - loss: 0.6483 - precision: 0.2118 - recall: 0.7093
# Epoch 7: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 145ms/step - accuracy: 0.5544 - auc: 0.6711 - loss: 0.6483 - precision: 0.2096 - recall: 0.7022 - val_accuracy: 0.4926 - val_auc: 0.6973 - val_loss: 0.6701 - val_precision: 0.2039 - val_recall: 0.8108 - learning_rate: 1.0000e-05
# Epoch 8/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5526 - auc: 0.6804 - loss: 0.6439 - precision: 0.2121 - recall: 0.7186
# Epoch 8: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.5558 - auc: 0.6791 - loss: 0.6431 - precision: 0.2120 - recall: 0.7128 - val_accuracy: 0.4494 - val_auc: 0.7042 - val_loss: 0.7135 - val_precision: 0.1985 - val_recall: 0.8692 - learning_rate: 1.0000e-05
# Epoch 9/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5774 - auc: 0.6840 - loss: 0.6356 - precision: 0.2147 - recall: 0.6919
# Epoch 9: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.5705 - auc: 0.6868 - loss: 0.6372 - precision: 0.2175 - recall: 0.7079 - val_accuracy: 0.5183 - val_auc: 0.7071 - val_loss: 0.6441 - val_precision: 0.2098 - val_recall: 0.7896 - learning_rate: 1.0000e-05
# Epoch 10/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5778 - auc: 0.6902 - loss: 0.6324 - precision: 0.2172 - recall: 0.6985
# Epoch 10: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.5804 - auc: 0.6938 - loss: 0.6321 - precision: 0.2222 - recall: 0.7094 - val_accuracy: 0.4610 - val_auc: 0.7065 - val_loss: 0.7125 - val_precision: 0.1994 - val_recall: 0.8503 - learning_rate: 1.0000e-05
# Epoch 11/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5813 - auc: 0.6917 - loss: 0.6312 - precision: 0.2184 - recall: 0.6936
# Epoch 11: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 145ms/step - accuracy: 0.5814 - auc: 0.6986 - loss: 0.6291 - precision: 0.2226 - recall: 0.7094 - val_accuracy: 0.6036 - val_auc: 0.7009 - val_loss: 0.5688 - val_precision: 0.2238 - val_recall: 0.6565 - learning_rate: 1.0000e-05
# Epoch 12/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5795 - auc: 0.6932 - loss: 0.6295 - precision: 0.2179 - recall: 0.6993
# Epoch 12: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.5880 - auc: 0.7035 - loss: 0.6255 - precision: 0.2249 - recall: 0.7051 - val_accuracy: 0.5374 - val_auc: 0.7231 - val_loss: 0.6216 - val_precision: 0.2161 - val_recall: 0.7831 - learning_rate: 1.0000e-05
# Epoch 13/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5879 - auc: 0.7059 - loss: 0.6245 - precision: 0.2278 - recall: 0.7199
# Epoch 13: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 142ms/step - accuracy: 0.5924 - auc: 0.7105 - loss: 0.6211 - precision: 0.2288 - recall: 0.7151 - val_accuracy: 0.5378 - val_auc: 0.7262 - val_loss: 0.6324 - val_precision: 0.2141 - val_recall: 0.7696 - learning_rate: 1.0000e-05
# Epoch 14/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5935 - auc: 0.7091 - loss: 0.6214 - precision: 0.2284 - recall: 0.7044
# Epoch 14: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.5961 - auc: 0.7093 - loss: 0.6212 - precision: 0.2284 - recall: 0.7026 - val_accuracy: 0.6142 - val_auc: 0.7161 - val_loss: 0.5792 - val_precision: 0.2331 - val_recall: 0.6771 - learning_rate: 1.0000e-05
# Epoch 15/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5804 - auc: 0.7087 - loss: 0.6242 - precision: 0.2272 - recall: 0.7249
# Epoch 15: val_accuracy did not improve from 0.66165
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.5938 - auc: 0.7125 - loss: 0.6188 - precision: 0.2283 - recall: 0.7083 - val_accuracy: 0.5719 - val_auc: 0.7286 - val_loss: 0.6082 - val_precision: 0.2242 - val_recall: 0.7437 - learning_rate: 1.0000e-05
# Epoch 16/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6067 - auc: 0.7285 - loss: 0.6078 - precision: 0.2379 - recall: 0.7197
# Epoch 16: val_accuracy did not improve from 0.66165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6155 - auc: 0.7276 - loss: 0.6075 - precision: 0.2402 - recall: 0.7126 - val_accuracy: 0.5261 - val_auc: 0.7300 - val_loss: 0.6309 - val_precision: 0.2149 - val_recall: 0.8038 - learning_rate: 5.0000e-06
# Epoch 17/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6135 - auc: 0.7367 - loss: 0.6033 - precision: 0.2430 - recall: 0.7261
# Epoch 17: val_accuracy improved from 0.66165 to 0.68455, saving model to best_resnet_model_6.keras
#
# Epoch 17: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6151 - auc: 0.7291 - loss: 0.6064 - precision: 0.2386 - recall: 0.7051 - val_accuracy: 0.6846 - val_auc: 0.7308 - val_loss: 0.5896 - val_precision: 0.2695 - val_recall: 0.6346 - learning_rate: 5.0000e-06
# Epoch 18/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6174 - auc: 0.7314 - loss: 0.6045 - precision: 0.2424 - recall: 0.7102
# Epoch 18: val_accuracy improved from 0.68455 to 0.69302, saving model to best_resnet_model_6.keras
#
# Epoch 18: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6214 - auc: 0.7317 - loss: 0.6036 - precision: 0.2431 - recall: 0.7112 - val_accuracy: 0.6930 - val_auc: 0.7334 - val_loss: 0.6007 - val_precision: 0.2718 - val_recall: 0.6128 - learning_rate: 5.0000e-06
# Epoch 19/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6308 - auc: 0.7365 - loss: 0.6012 - precision: 0.2487 - recall: 0.7056
# Epoch 19: val_accuracy did not improve from 0.69302
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6250 - auc: 0.7335 - loss: 0.6027 - precision: 0.2442 - recall: 0.7063 - val_accuracy: 0.6589 - val_auc: 0.7387 - val_loss: 0.5836 - val_precision: 0.2576 - val_recall: 0.6671 - learning_rate: 5.0000e-06
# Epoch 20/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6184 - auc: 0.7350 - loss: 0.6015 - precision: 0.2443 - recall: 0.7162
# Epoch 20: val_accuracy improved from 0.69302 to 0.74222, saving model to best_resnet_model_6.keras
#
# Epoch 20: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6230 - auc: 0.7326 - loss: 0.6022 - precision: 0.2440 - recall: 0.7112 - val_accuracy: 0.7422 - val_auc: 0.7383 - val_loss: 0.5471 - val_precision: 0.3052 - val_recall: 0.5516 - learning_rate: 5.0000e-06
# Epoch 21/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6370 - auc: 0.7394 - loss: 0.5975 - precision: 0.2498 - recall: 0.7027
# Epoch 21: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6268 - auc: 0.7333 - loss: 0.6021 - precision: 0.2449 - recall: 0.7041 - val_accuracy: 0.6873 - val_auc: 0.7394 - val_loss: 0.5871 - val_precision: 0.2730 - val_recall: 0.6417 - learning_rate: 5.0000e-06
# Epoch 22/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6289 - auc: 0.7344 - loss: 0.6055 - precision: 0.2495 - recall: 0.7063
# Epoch 22: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6286 - auc: 0.7335 - loss: 0.6010 - precision: 0.2447 - recall: 0.6976 - val_accuracy: 0.6381 - val_auc: 0.7368 - val_loss: 0.5814 - val_precision: 0.2499 - val_recall: 0.6959 - learning_rate: 5.0000e-06
# Epoch 23/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6147 - auc: 0.7374 - loss: 0.6058 - precision: 0.2492 - recall: 0.7340
# Epoch 23: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6295 - auc: 0.7378 - loss: 0.5990 - precision: 0.2477 - recall: 0.7116 - val_accuracy: 0.6626 - val_auc: 0.7408 - val_loss: 0.5872 - val_precision: 0.2611 - val_recall: 0.6724 - learning_rate: 5.0000e-06
# Epoch 24/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6354 - auc: 0.7429 - loss: 0.5922 - precision: 0.2510 - recall: 0.7167
# Epoch 24: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6333 - auc: 0.7379 - loss: 0.5979 - precision: 0.2497 - recall: 0.7108 - val_accuracy: 0.6427 - val_auc: 0.7442 - val_loss: 0.6198 - val_precision: 0.2534 - val_recall: 0.6995 - learning_rate: 5.0000e-06
# Epoch 25/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6462 - auc: 0.7355 - loss: 0.5968 - precision: 0.2503 - recall: 0.6868
# Epoch 25: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6363 - auc: 0.7416 - loss: 0.5960 - precision: 0.2508 - recall: 0.7071 - val_accuracy: 0.7338 - val_auc: 0.7407 - val_loss: 0.5784 - val_precision: 0.2986 - val_recall: 0.5633 - learning_rate: 5.0000e-06
# Epoch 26/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6381 - auc: 0.7431 - loss: 0.5943 - precision: 0.2513 - recall: 0.6949
# Epoch 26: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6382 - auc: 0.7396 - loss: 0.5963 - precision: 0.2500 - recall: 0.6961 - val_accuracy: 0.6346 - val_auc: 0.7488 - val_loss: 0.5901 - val_precision: 0.2520 - val_recall: 0.7189 - learning_rate: 5.0000e-06
# Epoch 27/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6400 - auc: 0.7353 - loss: 0.5922 - precision: 0.2413 - recall: 0.6819
# Epoch 27: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 171s 163ms/step - accuracy: 0.6368 - auc: 0.7442 - loss: 0.5934 - precision: 0.2510 - recall: 0.7063 - val_accuracy: 0.6276 - val_auc: 0.7393 - val_loss: 0.6547 - val_precision: 0.2468 - val_recall: 0.7124 - learning_rate: 5.0000e-06
# Epoch 28/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6293 - auc: 0.7387 - loss: 0.5944 - precision: 0.2437 - recall: 0.6986
# Epoch 28: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 145ms/step - accuracy: 0.6373 - auc: 0.7418 - loss: 0.5950 - precision: 0.2499 - recall: 0.6982 - val_accuracy: 0.5339 - val_auc: 0.7499 - val_loss: 0.6299 - val_precision: 0.2203 - val_recall: 0.8197 - learning_rate: 5.0000e-06
# Epoch 29/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6309 - auc: 0.7439 - loss: 0.5904 - precision: 0.2487 - recall: 0.7129
# Epoch 29: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6384 - auc: 0.7420 - loss: 0.5935 - precision: 0.2512 - recall: 0.7020 - val_accuracy: 0.6190 - val_auc: 0.7460 - val_loss: 0.6026 - val_precision: 0.2447 - val_recall: 0.7278 - learning_rate: 5.0000e-06
# Epoch 30/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6316 - auc: 0.7421 - loss: 0.5917 - precision: 0.2476 - recall: 0.7051
# Epoch 30: val_accuracy did not improve from 0.74222
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6399 - auc: 0.7435 - loss: 0.5924 - precision: 0.2522 - recall: 0.7028 - val_accuracy: 0.7011 - val_auc: 0.7518 - val_loss: 0.5913 - val_precision: 0.2815 - val_recall: 0.6288 - learning_rate: 5.0000e-06
# Epoch 31/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6675 - auc: 0.7472 - loss: 0.5824 - precision: 0.2591 - recall: 0.6819
# Epoch 31: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6497 - auc: 0.7497 - loss: 0.5874 - precision: 0.2582 - recall: 0.7026 - val_accuracy: 0.5845 - val_auc: 0.7523 - val_loss: 0.6107 - val_precision: 0.2357 - val_recall: 0.7790 - learning_rate: 2.5000e-06
# Epoch 32/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6314 - auc: 0.7417 - loss: 0.5944 - precision: 0.2478 - recall: 0.7016
# Epoch 32: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6490 - auc: 0.7502 - loss: 0.5864 - precision: 0.2565 - recall: 0.6957 - val_accuracy: 0.6993 - val_auc: 0.7541 - val_loss: 0.5746 - val_precision: 0.2830 - val_recall: 0.6441 - learning_rate: 2.5000e-06
# Epoch 33/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6345 - auc: 0.7475 - loss: 0.5909 - precision: 0.2541 - recall: 0.7141
# Epoch 33: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6516 - auc: 0.7508 - loss: 0.5866 - precision: 0.2595 - recall: 0.7031 - val_accuracy: 0.6492 - val_auc: 0.7587 - val_loss: 0.6134 - val_precision: 0.2629 - val_recall: 0.7313 - learning_rate: 2.5000e-06
# Epoch 34/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6506 - auc: 0.7488 - loss: 0.5903 - precision: 0.2592 - recall: 0.7067
# Epoch 34: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 153s 145ms/step - accuracy: 0.6529 - auc: 0.7540 - loss: 0.5851 - precision: 0.2608 - recall: 0.7059 - val_accuracy: 0.6270 - val_auc: 0.7547 - val_loss: 0.6042 - val_precision: 0.2525 - val_recall: 0.7478 - learning_rate: 2.5000e-06
# Epoch 35/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6411 - auc: 0.7474 - loss: 0.5903 - precision: 0.2550 - recall: 0.7033
# Epoch 35: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 142ms/step - accuracy: 0.6479 - auc: 0.7476 - loss: 0.5884 - precision: 0.2559 - recall: 0.6963 - val_accuracy: 0.7411 - val_auc: 0.7560 - val_loss: 0.5497 - val_precision: 0.3097 - val_recall: 0.5793 - learning_rate: 2.5000e-06
# Epoch 36/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6494 - auc: 0.7548 - loss: 0.5830 - precision: 0.2610 - recall: 0.7112
# Epoch 36: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6586 - auc: 0.7558 - loss: 0.5813 - precision: 0.2636 - recall: 0.7012 - val_accuracy: 0.6350 - val_auc: 0.7548 - val_loss: 0.6169 - val_precision: 0.2548 - val_recall: 0.7342 - learning_rate: 2.5000e-06
# Epoch 37/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6685 - auc: 0.7597 - loss: 0.5750 - precision: 0.2645 - recall: 0.6923
# Epoch 37: val_accuracy did not improve from 0.74222
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6577 - auc: 0.7552 - loss: 0.5826 - precision: 0.2623 - recall: 0.6967 - val_accuracy: 0.7182 - val_auc: 0.7545 - val_loss: 0.5481 - val_precision: 0.2977 - val_recall: 0.6352 - learning_rate: 2.5000e-06
# Epoch 38/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6513 - auc: 0.7541 - loss: 0.5838 - precision: 0.2590 - recall: 0.7015
# Epoch 38: val_accuracy improved from 0.74222 to 0.75720, saving model to best_resnet_model_6.keras
#
# Epoch 38: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6507 - auc: 0.7525 - loss: 0.5843 - precision: 0.2587 - recall: 0.7024 - val_accuracy: 0.7572 - val_auc: 0.7561 - val_loss: 0.5314 - val_precision: 0.3237 - val_recall: 0.5557 - learning_rate: 2.5000e-06
# Epoch 39/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6739 - auc: 0.7491 - loss: 0.5813 - precision: 0.2649 - recall: 0.6706
# Epoch 39: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 145ms/step - accuracy: 0.6618 - auc: 0.7533 - loss: 0.5831 - precision: 0.2640 - recall: 0.6917 - val_accuracy: 0.6195 - val_auc: 0.7610 - val_loss: 0.6046 - val_precision: 0.2511 - val_recall: 0.7643 - learning_rate: 2.5000e-06
# Epoch 40/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6518 - auc: 0.7531 - loss: 0.5820 - precision: 0.2616 - recall: 0.7220
# Epoch 40: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 153s 146ms/step - accuracy: 0.6556 - auc: 0.7550 - loss: 0.5826 - precision: 0.2638 - recall: 0.7132 - val_accuracy: 0.7155 - val_auc: 0.7584 - val_loss: 0.5781 - val_precision: 0.2946 - val_recall: 0.6317 - learning_rate: 2.5000e-06
# Epoch 41/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6638 - auc: 0.7615 - loss: 0.5815 - precision: 0.2704 - recall: 0.7018
# Epoch 41: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6602 - auc: 0.7558 - loss: 0.5832 - precision: 0.2639 - recall: 0.6971 - val_accuracy: 0.7330 - val_auc: 0.7575 - val_loss: 0.5648 - val_precision: 0.3051 - val_recall: 0.5993 - learning_rate: 2.5000e-06
# Epoch 42/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6591 - auc: 0.7613 - loss: 0.5808 - precision: 0.2684 - recall: 0.7046
# Epoch 42: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6577 - auc: 0.7531 - loss: 0.5830 - precision: 0.2608 - recall: 0.6886 - val_accuracy: 0.7039 - val_auc: 0.7609 - val_loss: 0.5647 - val_precision: 0.2913 - val_recall: 0.6682 - learning_rate: 2.5000e-06
# Epoch 43/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6618 - auc: 0.7554 - loss: 0.5812 - precision: 0.2649 - recall: 0.7013
# Epoch 43: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6602 - auc: 0.7579 - loss: 0.5811 - precision: 0.2650 - recall: 0.7026 - val_accuracy: 0.5644 - val_auc: 0.7616 - val_loss: 0.6164 - val_precision: 0.2319 - val_recall: 0.8132 - learning_rate: 2.5000e-06
# Epoch 44/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6531 - auc: 0.7595 - loss: 0.5780 - precision: 0.2630 - recall: 0.7214
# Epoch 44: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6634 - auc: 0.7585 - loss: 0.5790 - precision: 0.2676 - recall: 0.7053 - val_accuracy: 0.6531 - val_auc: 0.7612 - val_loss: 0.5948 - val_precision: 0.2649 - val_recall: 0.7289 - learning_rate: 2.5000e-06
# Epoch 45/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6531 - auc: 0.7558 - loss: 0.5787 - precision: 0.2599 - recall: 0.7036
# Epoch 45: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6570 - auc: 0.7562 - loss: 0.5819 - precision: 0.2628 - recall: 0.7024 - val_accuracy: 0.7357 - val_auc: 0.7607 - val_loss: 0.5515 - val_precision: 0.3092 - val_recall: 0.6052 - learning_rate: 2.5000e-06
# Epoch 46/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6587 - auc: 0.7530 - loss: 0.5830 - precision: 0.2622 - recall: 0.6964
# Epoch 46: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6636 - auc: 0.7565 - loss: 0.5809 - precision: 0.2667 - recall: 0.6996 - val_accuracy: 0.6915 - val_auc: 0.7592 - val_loss: 0.5902 - val_precision: 0.2821 - val_recall: 0.6730 - learning_rate: 2.5000e-06
# Epoch 47/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6487 - auc: 0.7607 - loss: 0.5819 - precision: 0.2657 - recall: 0.7223
# Epoch 47: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6597 - auc: 0.7584 - loss: 0.5789 - precision: 0.2641 - recall: 0.6998 - val_accuracy: 0.6579 - val_auc: 0.7587 - val_loss: 0.5563 - val_precision: 0.2634 - val_recall: 0.7024 - learning_rate: 2.5000e-06
# Epoch 48/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6569 - auc: 0.7598 - loss: 0.5788 - precision: 0.2654 - recall: 0.7146
# Epoch 48: val_accuracy did not improve from 0.75720
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6628 - auc: 0.7589 - loss: 0.5788 - precision: 0.2671 - recall: 0.7051 - val_accuracy: 0.7412 - val_auc: 0.7612 - val_loss: 0.5464 - val_precision: 0.3124 - val_recall: 0.5916 - learning_rate: 2.5000e-06
# Epoch 49/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6630 - auc: 0.7535 - loss: 0.5831 - precision: 0.2664 - recall: 0.6951
# Epoch 49: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 150s 143ms/step - accuracy: 0.6678 - auc: 0.7598 - loss: 0.5783 - precision: 0.2695 - recall: 0.6998 - val_accuracy: 0.7313 - val_auc: 0.7632 - val_loss: 0.5564 - val_precision: 0.3076 - val_recall: 0.6211 - learning_rate: 1.2500e-06
# Epoch 50/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6623 - auc: 0.7648 - loss: 0.5784 - precision: 0.2723 - recall: 0.7131
# Epoch 50: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6686 - auc: 0.7628 - loss: 0.5757 - precision: 0.2707 - recall: 0.7029 - val_accuracy: 0.7100 - val_auc: 0.7645 - val_loss: 0.5663 - val_precision: 0.2941 - val_recall: 0.6547 - learning_rate: 1.2500e-06
# Epoch 51/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6760 - auc: 0.7654 - loss: 0.5735 - precision: 0.2730 - recall: 0.7033
# Epoch 51: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6722 - auc: 0.7646 - loss: 0.5745 - precision: 0.2727 - recall: 0.7004 - val_accuracy: 0.6388 - val_auc: 0.7641 - val_loss: 0.5843 - val_precision: 0.2586 - val_recall: 0.7431 - learning_rate: 1.2500e-06
# Epoch 52/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6706 - auc: 0.7631 - loss: 0.5752 - precision: 0.2703 - recall: 0.7030
# Epoch 52: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 153s 145ms/step - accuracy: 0.6680 - auc: 0.7615 - loss: 0.5755 - precision: 0.2688 - recall: 0.6949 - val_accuracy: 0.6690 - val_auc: 0.7652 - val_loss: 0.5897 - val_precision: 0.2735 - val_recall: 0.7177 - learning_rate: 1.2500e-06
# Epoch 53/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6509 - auc: 0.7668 - loss: 0.5772 - precision: 0.2679 - recall: 0.7217
# Epoch 53: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6679 - auc: 0.7635 - loss: 0.5754 - precision: 0.2705 - recall: 0.7051 - val_accuracy: 0.7215 - val_auc: 0.7626 - val_loss: 0.5575 - val_precision: 0.3002 - val_recall: 0.6323 - learning_rate: 1.2500e-06
# Epoch 54/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6662 - auc: 0.7525 - loss: 0.5816 - precision: 0.2640 - recall: 0.6829
# Epoch 54: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6710 - auc: 0.7629 - loss: 0.5756 - precision: 0.2716 - recall: 0.6984 - val_accuracy: 0.7093 - val_auc: 0.7642 - val_loss: 0.5787 - val_precision: 0.2929 - val_recall: 0.6517 - learning_rate: 1.2500e-06
# Epoch 55/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6742 - auc: 0.7648 - loss: 0.5745 - precision: 0.2754 - recall: 0.7013
# Epoch 55: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6750 - auc: 0.7619 - loss: 0.5767 - precision: 0.2739 - recall: 0.6961 - val_accuracy: 0.7002 - val_auc: 0.7633 - val_loss: 0.5892 - val_precision: 0.2875 - val_recall: 0.6641 - learning_rate: 1.2500e-06
# Epoch 56/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6855 - auc: 0.7628 - loss: 0.5721 - precision: 0.2757 - recall: 0.6811
# Epoch 56: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6739 - auc: 0.7654 - loss: 0.5736 - precision: 0.2737 - recall: 0.6988 - val_accuracy: 0.6892 - val_auc: 0.7656 - val_loss: 0.5842 - val_precision: 0.2851 - val_recall: 0.6995 - learning_rate: 1.2500e-06
# Epoch 57/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6642 - auc: 0.7684 - loss: 0.5688 - precision: 0.2688 - recall: 0.7129
# Epoch 57: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6661 - auc: 0.7602 - loss: 0.5762 - precision: 0.2675 - recall: 0.6951 - val_accuracy: 0.6688 - val_auc: 0.7664 - val_loss: 0.5969 - val_precision: 0.2734 - val_recall: 0.7177 - learning_rate: 1.2500e-06
# Epoch 58/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6723 - auc: 0.7660 - loss: 0.5734 - precision: 0.2742 - recall: 0.7063
# Epoch 58: val_accuracy did not improve from 0.75720
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6711 - auc: 0.7644 - loss: 0.5742 - precision: 0.2727 - recall: 0.7047 - val_accuracy: 0.7482 - val_auc: 0.7650 - val_loss: 0.5393 - val_precision: 0.3197 - val_recall: 0.5893 - learning_rate: 1.2500e-06
# Epoch 59/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6846 - auc: 0.7657 - loss: 0.5725 - precision: 0.2794 - recall: 0.6802
# Epoch 59: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 143ms/step - accuracy: 0.6794 - auc: 0.7641 - loss: 0.5733 - precision: 0.2754 - recall: 0.6866 - val_accuracy: 0.6601 - val_auc: 0.7672 - val_loss: 0.5870 - val_precision: 0.2700 - val_recall: 0.7319 - learning_rate: 6.2500e-07
# Epoch 60/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6626 - auc: 0.7686 - loss: 0.5739 - precision: 0.2723 - recall: 0.7212
# Epoch 60: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 153s 145ms/step - accuracy: 0.6726 - auc: 0.7664 - loss: 0.5720 - precision: 0.2731 - recall: 0.7008 - val_accuracy: 0.7325 - val_auc: 0.7662 - val_loss: 0.5537 - val_precision: 0.3104 - val_recall: 0.6288 - learning_rate: 6.2500e-07
# Epoch 61/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6740 - auc: 0.7667 - loss: 0.5720 - precision: 0.2735 - recall: 0.6895
# Epoch 61: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 152s 144ms/step - accuracy: 0.6761 - auc: 0.7655 - loss: 0.5737 - precision: 0.2751 - recall: 0.6980 - val_accuracy: 0.7158 - val_auc: 0.7660 - val_loss: 0.5752 - val_precision: 0.2977 - val_recall: 0.6464 - learning_rate: 6.2500e-07
# Epoch 62/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6729 - auc: 0.7645 - loss: 0.5745 - precision: 0.2742 - recall: 0.6948
# Epoch 62: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6725 - auc: 0.7650 - loss: 0.5734 - precision: 0.2728 - recall: 0.7000 - val_accuracy: 0.7125 - val_auc: 0.7663 - val_loss: 0.5729 - val_precision: 0.2964 - val_recall: 0.6559 - learning_rate: 6.2500e-07
# Epoch 63/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6826 - auc: 0.7625 - loss: 0.5688 - precision: 0.2699 - recall: 0.6769
# Epoch 63: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6753 - auc: 0.7655 - loss: 0.5719 - precision: 0.2737 - recall: 0.6939 - val_accuracy: 0.7108 - val_auc: 0.7667 - val_loss: 0.5664 - val_precision: 0.2961 - val_recall: 0.6618 - learning_rate: 6.2500e-07
# Epoch 64/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6768 - auc: 0.7666 - loss: 0.5690 - precision: 0.2741 - recall: 0.7070
# Epoch 64: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 154s 146ms/step - accuracy: 0.6758 - auc: 0.7669 - loss: 0.5717 - precision: 0.2760 - recall: 0.7041 - val_accuracy: 0.7079 - val_auc: 0.7664 - val_loss: 0.5721 - val_precision: 0.2935 - val_recall: 0.6618 - learning_rate: 6.2500e-07
# Epoch 65/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6766 - auc: 0.7635 - loss: 0.5723 - precision: 0.2712 - recall: 0.6867
# Epoch 65: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6765 - auc: 0.7655 - loss: 0.5720 - precision: 0.2744 - recall: 0.6925 - val_accuracy: 0.7005 - val_auc: 0.7672 - val_loss: 0.5757 - val_precision: 0.2905 - val_recall: 0.6794 - learning_rate: 6.2500e-07
# Epoch 66/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6790 - auc: 0.7669 - loss: 0.5682 - precision: 0.2736 - recall: 0.6965
# Epoch 66: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6782 - auc: 0.7671 - loss: 0.5714 - precision: 0.2766 - recall: 0.6982 - val_accuracy: 0.7035 - val_auc: 0.7674 - val_loss: 0.5758 - val_precision: 0.2918 - val_recall: 0.6730 - learning_rate: 6.2500e-07
# Epoch 67/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6700 - auc: 0.7630 - loss: 0.5739 - precision: 0.2719 - recall: 0.6967
# Epoch 67: val_accuracy did not improve from 0.75720
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 151s 144ms/step - accuracy: 0.6758 - auc: 0.7637 - loss: 0.5737 - precision: 0.2746 - recall: 0.6967 - val_accuracy: 0.7281 - val_auc: 0.7668 - val_loss: 0.5502 - val_precision: 0.3061 - val_recall: 0.6293 - learning_rate: 6.2500e-07
# Epoch 68/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6658 - auc: 0.7592 - loss: 0.5770 - precision: 0.2683 - recall: 0.6914
# Epoch 68: val_accuracy did not improve from 0.75720
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 162s 154ms/step - accuracy: 0.6704 - auc: 0.7639 - loss: 0.5733 - precision: 0.2711 - recall: 0.6984 - val_accuracy: 0.7321 - val_auc: 0.7665 - val_loss: 0.5607 - val_precision: 0.3091 - val_recall: 0.6246 - learning_rate: 6.2500e-07
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1640/1957055703.py in <cell line: 0>()
#      40
#      41 # Cargar el modelo en su mejor punto
# ---> 42 model.load_weights('best_cnn_model_2.keras')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1355                         filemode = modeDict[filemode]
#    1356                         continue
# -> 1357                     raise
#    1358                 break
#    1359         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best_cnn_model_2.keras'

# %%
model.load_weights('best_cnn_model2.keras')
# Buscamos el índice de la época con el mayor val_accuracy
best_epoch_idx = np.argmax(history.history['val_accuracy'])

# 1. CURVAS DE CONVERGENCIA DEL ENTRENAMIENTO
plt.figure(figsize=(14, 10))

# Gráfica de Loss
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Función de Coste (Binary Crossentropy)')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

# Gráfica de Accuracy
plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Accuracy')
plt.legend()

# Gráfica de AUC
plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Área bajo la curva (AUC) por época')
plt.xlabel('Época')
plt.ylabel('AUC')
plt.legend()

# Gráfica de Recall
plt.subplot(2, 2, 4)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Sensibilidad (Recall)')
plt.xlabel('Época')
plt.ylabel('Recall')
plt.legend()

plt.tight_layout()
plt.show()

# 2. PREDICCIONES Y EVALUACIÓN
print(f"\nEvaluando el mejor modelo guardado (Época {best_epoch_idx + 1})...")
eval_results = model.evaluate(test_gen, verbose=1)

print(f"\nMétricas de Test -> Loss: {eval_results[0]:.4f} | Accuracy: {eval_results[1]:.4f} | Recall: {eval_results[2]:.4f} | Precision: {eval_results[3]:.4f} | AUC: {eval_results[4]:.4f}")

predictions = model.predict(test_gen)
y_pred = (predictions > 0.5).astype(int).flatten()
y_true = test_gen.classes

# 3. CURVA ROC
plt.figure(figsize=(14, 6))
fpr, tpr, thresholds = roc_curve(y_true, predictions)
roc_auc = auc(fpr, tpr)
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC del Modelo')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# 4. MATRIZ DE CONFUSIÓN Y REPORTE
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_gen.class_indices.keys(),
            yticklabels=test_gen.class_indices.keys())
plt.title('Matriz de Confusión - ResNet50')
plt.ylabel('Real (Verdad)')
plt.xlabel('Predicción del Modelo')
plt.show()

print("\nReporte de Clasificación:")
print(classification_report(y_true, y_pred, target_names=test_gen.class_indices.keys()))
# Out:
# Evaluando el mejor modelo guardado (Época 38)...
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 31s 88ms/step - accuracy: 0.7578 - auc: 0.7785 - loss: 0.5302 - precision: 0.3344 - recall: 0.6070
#
# Métricas de Test -> Loss: 0.5302 | Accuracy: 0.7578 | Recall: 0.6070 | Precision: 0.3344 | AUC: 0.7785
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 25s 69ms/step
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.78      0.85      9522
#     Positive       0.33      0.61      0.43      1697
#
#     accuracy                           0.76     11219
#    macro avg       0.63      0.70      0.64     11219
# weighted avg       0.83      0.76      0.78     11219

# %%
positive_dir = SPLIT_DIR / 'test' / 'Positive'
negative_dir = SPLIT_DIR / 'test' / 'Negative'
sample_positive_path = sorted(positive_dir.glob('*.jpg'))[5]
sample_negative_path = sorted(negative_dir.glob('*.jpg'))[5]

# Buscamos la primera capa convolucional
capa_base = model.layers[0]
if isinstance(capa_base, tf.keras.Model):
    conv_layer = [layer for layer in capa_base.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=capa_base.inputs, outputs=conv_layer.output)
    es_resnet = True
else:
    conv_layer = [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=model.inputs, outputs=conv_layer.output)
    es_resnet = False

print(f"Extrayendo mapas de características de la capa: {conv_layer.name}")
num_filtros = min(6, conv_layer.filters)
muestras = [
    (sample_positive_path, 'Grieta (Positive)'),
    (sample_negative_path, 'Sin Grieta (Negative)')]
for path, label in muestras:
    # Cargar imagen original para mostrarla
    img_raw = load_img(path, target_size=(227, 227))
    img_array = img_to_array(img_raw)
    if es_resnet:
        img_procesada = preprocess_input(img_array.copy())
    else:
        img_procesada = img_array.copy() / 255.0
    img_batch = np.expand_dims(img_procesada, axis=0)
    # Extraer los mapas de características
    feature_maps = visual_model.predict(img_batch, verbose=0)
    fig, axes = plt.subplots(1, num_filtros + 1, figsize=(3 * (num_filtros + 1), 4))
    fig.suptitle(f"Análisis Interno - {label} | Capa: {conv_layer.name}", fontsize=16, fontweight='bold')
    axes[0].imshow(img_raw)
    axes[0].set_title("Original", fontsize=12)
    axes[0].axis('off')
    # Dibujar los mapas de características
    for i in range(num_filtros):
        axes[i + 1].imshow(feature_maps[0, :, :, i], cmap='viridis')
        axes[i + 1].set_title(f"Filtro {i}", fontsize=12)
        axes[i + 1].axis('off')
    plt.tight_layout()
    plt.show()
# Out:
# Extrayendo mapas de características de la capa: conv2d_3
