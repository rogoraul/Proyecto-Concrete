# %% [markdown]
# ## Concrete Crack Images for Classification
#
# ---
#
# #### Modelo Machine Learning

# %%
# ---------- #
# LIBRERÍAS  #
# ---------- #

import os
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import IncrementalPCA
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from skimage.feature import hog
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import kagglehub
from sklearn.utils.class_weight import compute_class_weight

# %%
# %%
# ------------ #
# DESCARGA     #
# ------------ #

path3 = kagglehub.dataset_download("aniruddhsharma/structural-defects-network-concrete-crack-images")
print("Path to dataset files:", path3)

os.makedirs('./data', exist_ok=True)

datasets_dl = {
    'structural_defects': path3
}

for name, source in datasets_dl.items():
    target = os.path.join('./data', name)
    if not os.path.exists(target):
        os.symlink(source, target)
        print(f'Dataset {name} vinculado en: {target}')
    else:
        print(f'El enlace para {name} ya existe en ./data')

print('\nContenido actual de ./data:', os.listdir('./data'))
# Out:
# Using Colab cache for faster access to the 'structural-defects-network-concrete-crack-images' dataset.
# Path to dataset files: /kaggle/input/structural-defects-network-concrete-crack-images
# El enlace para structural_defects ya existe en ./data
#
# Contenido actual de ./data: ['merged_cracks', 'split', 'structural_defects']

# %%
# %%
# ------------------------------------------------- #
# CREAR DATASET EN ./data (SOLO STRUCTURAL DEFECTS) #
# ------------------------------------------------- #

structural_defects_path = Path('./data/structural_defects')
merged_path = Path('./data/merged_cracks')
merged_path.mkdir(exist_ok=True)

clases = ['Positive', 'Negative']
for clase in clases:
    (merged_path / clase).mkdir(exist_ok=True)

total_stats = {'Positive': 0, 'Negative': 0}

# --------------------------------------------------- #
# Structural Defects (Cracked / Non-cracked × 3)      #
# --------------------------------------------------- #
sd_mapping = {
    'Positive': [
        structural_defects_path / 'Walls' / 'Cracked',
        structural_defects_path / 'Decks' / 'Cracked',
        structural_defects_path / 'Pavements' / 'Cracked',
    ],
    'Negative': [
        structural_defects_path / 'Walls' / 'Non-cracked',
        structural_defects_path / 'Decks' / 'Non-cracked',
        structural_defects_path / 'Pavements' / 'Non-cracked',
    ],
}

for clase, dirs in sd_mapping.items():
    for src_dir in dirs:
        tag = src_dir.parent.name[:2].lower()  # wa, de, pa
        count = 0
        if src_dir.exists():
            for img_file in src_dir.iterdir():
                if img_file.is_file():
                    dest_file = merged_path / clase / f"sd_{tag}_{img_file.name}"
                    if not dest_file.exists():
                        shutil.copy2(str(img_file), str(dest_file))
                        count += 1
            total_stats[clase] += count
            print(f"Structural Defects [{src_dir.parent.name}/{src_dir.name}]: +{count}")

# Resumen final
n_pos = len(list((merged_path / 'Positive').iterdir()))
n_neg = len(list((merged_path / 'Negative').iterdir()))
print(f"\n{'='*45}")
print(f"Dataset estructurado en: {merged_path.resolve()}")
print(f"  Positive (Grieta):    {n_pos}")
print(f"  Negative (Sin Grieta): {n_neg}")
print(f"  Total:                 {n_pos + n_neg}")
if n_pos > 0:
    print(f"  Ratio Neg/Pos:         {n_neg/n_pos:.2f}")
print(f"{'='*45}")
# Out:
# Structural Defects [Walls/Cracked]: +0
# Structural Defects [Decks/Cracked]: +0
# Structural Defects [Pavements/Cracked]: +0
# Structural Defects [Walls/Non-cracked]: +0
# Structural Defects [Decks/Non-cracked]: +0
# Structural Defects [Pavements/Non-cracked]: +0
#
# ...
# Dataset estructurado en: /content/data/merged_cracks
#   Positive (Grieta):    8484
#   Negative (Sin Grieta): 47608
#   Total:                 56092
#   Ratio Neg/Pos:         5.61
# ...

# %%
# %%
# ------------------------------------------ #
# SPLIT FÍSICO EN DIRECTORIOS TRAIN/VAL/TEST #
# ------------------------------------------ #

SOURCE_DIR = Path('./data/merged_cracks')  # Cambiar si solo usas un dataset
SPLIT_DIR  = Path('./data/split')

# Recopilar todos los paths y labels
all_paths  = []
all_labels = []

for img_path in sorted((SOURCE_DIR / 'Positive').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(1)
for img_path in sorted((SOURCE_DIR / 'Negative').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(0)

print(f"Total imágenes encontradas: {len(all_paths)}")
print(f"  Positivas: {sum(all_labels)}, Negativas: {len(all_labels) - sum(all_labels)}")

# Split 60% train / 20% val / 20% test
paths_tv, paths_test, y_tv, y_te = train_test_split(
    all_paths, all_labels, test_size=0.2, random_state=42, stratify=all_labels
)
paths_train, paths_val, y_tr, y_va = train_test_split(
    paths_tv, y_tv, test_size=0.25, random_state=42, stratify=y_tv
)

# Crear directorios y copiar archivos
splits = {'train': paths_train, 'val': paths_val, 'test': paths_test}

for split_name, split_paths in splits.items():
    for cls in ['Positive', 'Negative']:
        (SPLIT_DIR / split_name / cls).mkdir(parents=True, exist_ok=True)

    copied = 0
    for p in split_paths:
        cls = p.parent.name
        dest = SPLIT_DIR / split_name / cls / p.name
        if not dest.exists():
            shutil.copy2(str(p), str(dest))
            copied += 1

    total = len(list((SPLIT_DIR / split_name / 'Positive').iterdir())) + \
            len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))
    print(f"\n{split_name.upper()}: {total} imágenes ({copied} copiadas ahora)")
    print(f"  Positive: {len(list((SPLIT_DIR / split_name / 'Positive').iterdir()))}")
    print(f"  Negative: {len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))}")
# Out:
# Total imágenes encontradas: 56092
#   Positivas: 8484, Negativas: 47608
#
# TRAIN: 33654 imágenes (0 copiadas ahora)
#   Positive: 5090
#   Negative: 28564
#
# VAL: 11219 imágenes (0 copiadas ahora)
#   Positive: 1697
#   Negative: 9522
#
# TEST: 11219 imágenes (0 copiadas ahora)
#   Positive: 1697
#   Negative: 9522

# %%
# %%
# ------------------------------- #
# IMAGEDATAGENERATORS POR SPLIT   #
# ------------------------------- #

IMG_SIZE   = (64, 64)
BATCH_SIZE = 600
CLASSES    = np.array([0, 1])

datagen = ImageDataGenerator(rescale=1./255)

train_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'train'),
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=True,
    seed=42
)

val_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'val'),
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)

test_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'test'),
    target_size=IMG_SIZE,
    color_mode='grayscale',
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)

print(f"\nClases: {train_gen.class_indices}")
print(f"Batches -> Train: {len(train_gen)}, Val: {len(val_gen)}, Test: {len(test_gen)}")
# Out:
# Found 33654 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.
#
# Clases: {'Negative': 0, 'Positive': 1}
# Batches -> Train: 57, Val: 19, Test: 19

# %%
# %%
# -------------------------------- #
# EXTRACCIÓN DE FEATURES POR BATCH #
# -------------------------------- #

def extract_raw_batch(images_batch):
    """(batch, 64, 64, 1) float → (batch, 4096) píxeles aplanados."""
    return images_batch.reshape(images_batch.shape[0], -1)

def extract_hog_batch(images_batch):
    """(batch, 64, 64, 1) float → (batch, n_hog) descriptores HOG."""
    features = []
    for img in images_batch:
        img_2d = (img[:, :, 0] * 255).astype(np.uint8)
        fd = hog(img_2d, orientations=9, pixels_per_cell=(8, 8),
                 cells_per_block=(2, 2), visualize=False)
        features.append(fd)
    return np.array(features)

def iterate_generator(gen, extract_fn):
    """Itera un generador completo UNA vez, extrayendo features por batch."""
    gen.reset()
    for i in range(len(gen)):
        images_batch, labels_batch = gen[i]
        X_batch = extract_fn(images_batch)
        yield X_batch, labels_batch.astype(int)

# %%
# %%
# ----------------------------------------- #
# FIT INCREMENTAL: SCALERS + PCA (95% VAR.) #
# ----------------------------------------- #

scaler_raw = StandardScaler()
scaler_hog = StandardScaler()

# ---- Pasada 1: Ajustar ambos scalers a la vez ----
print("Pasada 1: Ajustando scalers (RAW + HOG)...")
for X_batch_raw, _ in iterate_generator(train_gen, extract_raw_batch):
    scaler_raw.partial_fit(X_batch_raw)

for X_batch_hog, _ in iterate_generator(train_gen, extract_hog_batch):
    scaler_hog.partial_fit(X_batch_hog)

print(f"  Scaler RAW ajustado ✓ ({scaler_raw.n_features_in_} features)")
print(f"  Scaler HOG ajustado ✓ ({scaler_hog.n_features_in_} features)")

# ---- Pasada 2: Ajustar IncrementalPCA sobre HOG escalado ----
# Usamos n_components alto para luego seleccionar 95% de varianza
N_COMPONENTS_INIT = 590  # Ajustable, debe ser < BATCH_SIZE

ipca = IncrementalPCA(n_components=N_COMPONENTS_INIT)

print(f"\nPasada 2: Ajustando IncrementalPCA ({N_COMPONENTS_INIT} componentes)...")
for X_batch_hog, _ in iterate_generator(train_gen, extract_hog_batch):
    X_batch_sc = scaler_hog.transform(X_batch_hog)
    ipca.partial_fit(X_batch_sc)

# Determinar cuántos componentes necesitamos para 95% de varianza
cumvar = np.cumsum(ipca.explained_variance_ratio_)
n_95 = int(np.argmax(cumvar >= 0.95) + 1)

print(f"  PCA ajustado ✓")
print(f"  Varianza total explicada ({N_COMPONENTS_INIT} comp.): {cumvar[-1]:.4f}")
print(f"  Componentes para 95% varianza: {n_95}")
print(f"  Varianza con {n_95} componentes: {cumvar[n_95-1]:.4f}")
# Out:
# Pasada 1: Ajustando scalers (RAW + HOG)...
#   Scaler RAW ajustado ✓ (4096 features)
#   Scaler HOG ajustado ✓ (1764 features)
#
# Pasada 2: Ajustando IncrementalPCA (590 componentes)...
#   PCA ajustado ✓
#   Varianza total explicada (590 comp.): 0.9879
#   Componentes para 95% varianza: 517
#   Varianza con 517 componentes: 0.9507

# %%
# %%
# ----------------------- #
# VISUALIZACIÓN COMPARATIVA #
# ----------------------- #

# Tomamos una imagen de ejemplo de cada clase directamente del disco
sample_positive = list((SPLIT_DIR / 'train' / 'Positive').iterdir())[5]
sample_negative = list((SPLIT_DIR / 'train' / 'Negative').iterdir())[5]

fig, axes = plt.subplots(2, 4, figsize=(20, 10))

for row, (sample_path, label) in enumerate([(sample_positive, 'Grieta (Positive)'),
                                             (sample_negative, 'Sin Grieta (Negative)')]):
    # 1. Original
    img_original = Image.open(sample_path)
    axes[row, 0].imshow(img_original)
    axes[row, 0].set_title(f'{label}\nOriginal')
    axes[row, 0].axis('off')

    # 2. Raw (Grises)
    img_gray = Image.open(sample_path).convert('L').resize(IMG_SIZE)
    img_array = np.array(img_gray)
    axes[row, 1].imshow(img_array, cmap='gray')
    axes[row, 1].set_title('Raw Data (Escala Grises)')
    axes[row, 1].axis('off')

    # 3. HOG
    fd_hog, hog_image = hog(img_array, orientations=9, pixels_per_cell=(8, 8),
                             cells_per_block=(2, 2), visualize=True)
    axes[row, 2].imshow(hog_image, cmap='gray')
    axes[row, 2].set_title(f'HOG\n({fd_hog.shape[0]} features)')
    axes[row, 2].axis('off')

    # 4. HOG + PCA
    fd_scaled = scaler_hog.transform(fd_hog.reshape(1, -1))
    fd_pca_full = ipca.transform(fd_scaled)[0]
    fd_pca = fd_pca_full[:n_95]  # Solo los componentes al 95%
    axes[row, 3].plot(fd_pca, color='blue', alpha=0.7)
    axes[row, 3].set_title(f'Vector HOG + PCA\n({n_95} features, 95% var.)')
    axes[row, 3].set_xlabel('Componentes Principales')
    axes[row, 3].set_ylabel('Magnitud')

plt.suptitle('Evolución de los Datos: Original → Raw → HOG → HOG+PCA', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# -------------------------------------------- #
# ENTRENAMIENTO PARTIAL FIT - 3 CONFIGURACIONES #
# -------------------------------------------- #

N_EPOCHS = 5

configs = {
    "1. RAW (Píxeles Planos)": {
        'extract_fn': extract_raw_batch,
        'scaler': scaler_raw,
        'use_pca': False,
    },
    "2. HOG (Descriptores)": {
        'extract_fn': extract_hog_batch,
        'scaler': scaler_hog,
        'use_pca': False,
    },
    "3. HOG + PCA (95% Varianza)": {
        'extract_fn': extract_hog_batch,
        'scaler': scaler_hog,
        'use_pca': True,
    },
}

models = {}

# Calcular pesos a partir de la distribución del train_gen
class_weights = compute_class_weight('balanced', classes=CLASSES, y=train_gen.classes)
weight_map = {0: class_weights[0], 1: class_weights[1]}
print(f"Pesos de clase: {weight_map}")

for name, cfg in configs.items():
    print(f"\n{'='*55}")
    print(f"  {name}")
    print(f"{'='*55}")

    model = SGDClassifier(
        loss='hinge',
        penalty='l2',
        alpha=1e-4,
        random_state=42
    )

    for epoch in range(N_EPOCHS):
        for X_batch, y_batch in iterate_generator(train_gen, cfg['extract_fn']):
            X_batch_sc = cfg['scaler'].transform(X_batch)
            if cfg['use_pca']:
                X_batch_sc = ipca.transform(X_batch_sc)[:, :n_95]
            # Asignar peso por muestra según su clase
            sample_weights = np.array([weight_map[y] for y in y_batch])
            model.partial_fit(X_batch_sc, y_batch, classes=CLASSES, sample_weight=sample_weights)

        print(f"    Epoch {epoch+1}/{N_EPOCHS} ✓")

    n_params = model.coef_.size + model.intercept_.size
    dim_input = n_95 if cfg['use_pca'] else cfg['scaler'].n_features_in_
    print(f"  Dimensiones entrada: {dim_input}")
    print(f"  Parámetros: {n_params}")

    models[name] = model
# Out:
# Pesos de clase: {0: np.float64(0.589098165523036), 1: np.float64(3.305893909626719)}
#
# ...
#   1. RAW (Píxeles Planos)
# ...
#     Epoch 1/5 ✓
#     Epoch 2/5 ✓
#     Epoch 3/5 ✓
#     Epoch 4/5 ✓
#     Epoch 5/5 ✓
#   Dimensiones entrada: 4096
#   Parámetros: 4097
#
# ...
#   2. HOG (Descriptores)
# ...
#     Epoch 1/5 ✓
#     Epoch 2/5 ✓
#     Epoch 3/5 ✓
#     Epoch 4/5 ✓
#     Epoch 5/5 ✓
#   Dimensiones entrada: 1764
#   Parámetros: 1765
#
# ...
#   3. HOG + PCA (95% Varianza)
# ...
#     Epoch 1/5 ✓
#     Epoch 2/5 ✓
#     Epoch 3/5 ✓
#     Epoch 4/5 ✓
#     Epoch 5/5 ✓
#   Dimensiones entrada: 517
#   Parámetros: 518

# %%
# %%
# ------------------------------- #
# EVALUACIÓN POR LOTES + MÉTRICAS #
# ------------------------------- #
from sklearn.metrics import accuracy_score, classification_report, recall_score, roc_auc_score
import numpy as np
import pandas as pd

target_names = ['Sano (0)', 'Grieta (1)']

def evaluate_gen(model, gen, extract_fn, scaler, use_pca=False):
    """Evalúa consumiendo el generador por lotes."""
    all_preds, all_scores, all_labels = [], [], []

    for X_batch, y_batch in iterate_generator(gen, extract_fn):
        X_batch_sc = scaler.transform(X_batch)
        if use_pca:
            X_batch_sc = ipca.transform(X_batch_sc)[:, :n_95]

        preds = model.predict(X_batch_sc)

        if hasattr(model, "predict_proba"):
            scores = model.predict_proba(X_batch_sc)[:, 1]
        else:
            scores = model.decision_function(X_batch_sc)

        all_preds.extend(preds)
        all_scores.extend(scores)
        all_labels.extend(y_batch)

    return np.array(all_labels), np.array(all_preds), np.array(all_scores)

results = []

for name, cfg in configs.items():
    model = models[name]
    print(f"\n{'='*55}")
    print(f"  {name}")
    print(f"{'='*55}")

    split_metrics = {}

    for split_name, gen in [('Train', train_gen), ('Val', val_gen), ('Test', test_gen)]:
        y_true, y_pred, y_score = evaluate_gen(model, gen, cfg['extract_fn'], cfg['scaler'], cfg['use_pca'])
        split_metrics[split_name] = {
            'y_true': y_true,
            'y_pred': y_pred,
            'accuracy': accuracy_score(y_true, y_pred),
            'recall': recall_score(y_true, y_pred),
            'auc': roc_auc_score(y_true, y_score)
        }

    for split_name in ['Train', 'Val', 'Test']:
        metrics = split_metrics[split_name]
        print(f"  {split_name} -> Accuracy: {metrics['accuracy']:.4f} | Recall: {metrics['recall']:.4f} | AUC: {metrics['auc']:.4f}")

    print(f"\n  Reporte de Clasificación (Test):")
    print(classification_report(split_metrics['Test']['y_true'], split_metrics['Test']['y_pred'], target_names=target_names))

    if hasattr(model, 'coef_'):
        n_params = model.coef_.size + model.intercept_.size
    else:
        n_params = np.nan

    dim_input = n_95 if cfg['use_pca'] else cfg['scaler'].n_features_in_

    results.append({
        'Modelo': name,
        'Acc Train': split_metrics['Train']['accuracy'],
        'Recall Train': split_metrics['Train']['recall'],
        'AUC Train': split_metrics['Train']['auc'],
        'Acc Val': split_metrics['Val']['accuracy'],
        'Recall Val': split_metrics['Val']['recall'],
        'AUC Val': split_metrics['Val']['auc'],
        'Acc Test': split_metrics['Test']['accuracy'],
        'Recall Test': split_metrics['Test']['recall'],
        'AUC Test': split_metrics['Test']['auc'],
        'Dimensiones': dim_input,
        'Parámetros': n_params
    })

# ----------------- #
# TABLA COMPARATIVA #
# ----------------- #
print(f"\n{'='*75}")
print("TABLA COMPARATIVA")
print(f"{'='*75}")
results_df = pd.DataFrame(results)

format_dict = {
    'Acc Train': lambda x: f"{x:.3f}",
    'Recall Train': lambda x: f"{x:.3f}",
    'AUC Train': lambda x: f"{x:.3f}",
    'Acc Val': lambda x: f"{x:.3f}",
    'Recall Val': lambda x: f"{x:.3f}",
    'AUC Val': lambda x: f"{x:.3f}",
    'Acc Test': lambda x: f"{x:.3f}",
    'Recall Test': lambda x: f"{x:.3f}",
    'AUC Test': lambda x: f"{x:.3f}"
}

print(results_df.to_string(index=False, formatters=format_dict))
# Out:
# ...
#   1. RAW (Píxeles Planos)
# ...
#   Train -> Accuracy: 0.6031 | Recall: 0.7090 | AUC: 0.7051
#   Val -> Accuracy: 0.5492 | Recall: 0.5457 | AUC: 0.5522
#   Test -> Accuracy: 0.5373 | Recall: 0.5374 | AUC: 0.5493
#
#   Reporte de Clasificación (Test):
#               precision    recall  f1-score   support
#
#     Sano (0)       0.87      0.54      0.66      9522
#   Grieta (1)       0.17      0.54      0.26      1697
#
#     accuracy                           0.54     11219
#    macro avg       0.52      0.54      0.46     11219
# weighted avg       0.76      0.54      0.60     11219
#
#
# ...
#   2. HOG (Descriptores)
# ...
#   Train -> Accuracy: 0.5403 | Recall: 0.5631 | AUC: 0.5699
#   Val -> Accuracy: 0.5320 | Recall: 0.5133 | AUC: 0.5401
#   Test -> Accuracy: 0.5296 | Recall: 0.5156 | AUC: 0.5266
#
#   Reporte de Clasificación (Test):
#               precision    recall  f1-score   support
#
#     Sano (0)       0.86      0.53      0.66      9522
# ...

# %%
# %%
# ---------------------- #
# MATRICES DE CONFUSIÓN  #
# ---------------------- #

fig, axes = plt.subplots(1, 3, figsize=(20, 5))
cmaps = ['Blues', 'Oranges', 'Greens']

for i, (name, cfg) in enumerate(configs.items()):
    model = models[name]
    y_true, y_pred, _ = evaluate_gen(model, test_gen, cfg['extract_fn'], cfg['scaler'], cfg['use_pca'])
    cm = confusion_matrix(y_true, y_pred)

    sns.heatmap(cm, annot=True, fmt='d', cmap=cmaps[i], ax=axes[i],
                xticklabels=target_names, yticklabels=target_names)
    axes[i].set_title(name, fontsize=11)
    axes[i].set_ylabel('Real')
    axes[i].set_xlabel('Predicho')

plt.suptitle('Matrices de Confusión — SGD LogReg (partial_fit + ImageDataGenerator)',
             fontsize=13, y=1.02)
plt.tight_layout()
plt.savefig('confusion_matrices_sgd_idg.png', dpi=150, bbox_inches='tight')
plt.show()
