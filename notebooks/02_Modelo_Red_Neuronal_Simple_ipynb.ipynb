# %% [markdown]
# <a href="https://colab.research.google.com/github/rogoraul/Proyecto-Concrete/blob/main/notebooks/02_Modelo_Red_Neuronal_Simple_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Concrete Crack Images for Classification
#
# ---

# %%
# Cargamos las librerias necesarias
import sys
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import zipfile
import shutil
import pandas as pd
import seaborn as sns
from PIL import Image
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from google.colab import files
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
import kagglehub
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import tensorflow as tf
from tensorflow.keras.metrics import Recall, AUC, Precision
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import roc_curve, auc

# %%
# Descarga de los datos
path = kagglehub.dataset_download("aniruddhsharma/structural-defects-network-concrete-crack-images")
print("Path to dataset files:", path)

os.makedirs('./data', exist_ok=True)

datasets_dl = {'structural_defects': path}

for name, source in datasets_dl.items():
    target = os.path.join('./data', name)
    if not os.path.exists(target):
        os.symlink(source, target)
        print(f'Dataset {name} vinculado en: {target}')
    else:
        print(f'El enlace para {name} ya existe en ./data')

print('\nContenido actual de ./data:', os.listdir('./data'))
# Out:
# Using Colab cache for faster access to the 'structural-defects-network-concrete-crack-images' dataset.
# Path to dataset files: /kaggle/input/structural-defects-network-concrete-crack-images
# Dataset structural_defects vinculado en: ./data/structural_defects
#
# Contenido actual de ./data: ['structural_defects']

# %%
# Fusión de las imagenes en una sola carpeta
structural_defects_path = Path('./data/structural_defects')
merged_path = Path('./data/merged_cracks')
merged_path.mkdir(exist_ok=True)

clases = ['Positive', 'Negative']
for clase in clases:
    (merged_path / clase).mkdir(exist_ok=True)

total_stats = {'Positive': 0, 'Negative': 0}

# Structural Defects (Cracked / Non-cracked × 3)
sd_mapping = {
    'Positive': [
        structural_defects_path / 'Walls' / 'Cracked',
        structural_defects_path / 'Decks' / 'Cracked',
        structural_defects_path / 'Pavements' / 'Cracked',
    ],
    'Negative': [
        structural_defects_path / 'Walls' / 'Non-cracked',
        structural_defects_path / 'Decks' / 'Non-cracked',
        structural_defects_path / 'Pavements' / 'Non-cracked',
    ],
}

for clase, dirs in sd_mapping.items():
    for src_dir in dirs:
        tag = src_dir.parent.name[:2].lower()  # wa, de, pa
        count = 0
        for img_file in src_dir.iterdir():
            if img_file.is_file():
                dest_file = merged_path / clase / f"sd_{tag}_{img_file.name}"
                if not dest_file.exists():
                    shutil.copy2(str(img_file), str(dest_file))
                    count += 1
        total_stats[clase] += count
        print(f"Structural Defects [{src_dir.parent.name}/{src_dir.name}]: +{count}")

# Resumen final
n_pos = len(list((merged_path / 'Positive').iterdir()))
n_neg = len(list((merged_path / 'Negative').iterdir()))
print(f"Dataset fusionado en: {merged_path.resolve()}")
print(f"  Positive (Grieta):    {n_pos}")
print(f"  Negative (Sin Grieta): {n_neg}")
print(f"  Total:                 {n_pos + n_neg}")
if n_pos > 0:
    print(f"  Ratio Neg/Pos:         {n_neg/n_pos:.2f}")
else:
    print("  Ratio Neg/Pos:         N/A")
# Out:
# Structural Defects [Walls/Cracked]: +3851
# Structural Defects [Decks/Cracked]: +2025
# Structural Defects [Pavements/Cracked]: +2608
# Structural Defects [Walls/Non-cracked]: +14287
# Structural Defects [Decks/Non-cracked]: +11595
# Structural Defects [Pavements/Non-cracked]: +21726
# Dataset fusionado en: /content/data/merged_cracks
#   Positive (Grieta):    8484
#   Negative (Sin Grieta): 47608
#   Total:                 56092
#   Ratio Neg/Pos:         5.61

# %%
# Split en Train, Validation y Test
SOURCE_DIR = Path('./data/merged_cracks')
SPLIT_DIR  = Path('./data/split')

# Recopilar todos los paths y labels
all_paths  = []
all_labels = []

for img_path in sorted((SOURCE_DIR / 'Positive').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(1)
for img_path in sorted((SOURCE_DIR / 'Negative').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(0)

print(f"Total imágenes encontradas: {len(all_paths)}")
print(f"  Positivas: {sum(all_labels)}, Negativas: {len(all_labels) - sum(all_labels)}")

# Split 60% train / 20% val / 20% test
paths_tv, paths_test, y_tv, y_te = train_test_split(
    all_paths, all_labels, test_size=0.2, random_state=42, stratify=all_labels
)
paths_train, paths_val, y_tr, y_va = train_test_split(
    paths_tv, y_tv, test_size=0.25, random_state=42, stratify=y_tv
)

# Crear directorios y copiar archivos
splits = {'train': paths_train, 'val': paths_val, 'test': paths_test}

for split_name, split_paths in splits.items():
    for cls in ['Positive', 'Negative']:
        (SPLIT_DIR / split_name / cls).mkdir(parents=True, exist_ok=True)

    copied = 0
    for p in split_paths:
        cls = p.parent.name
        dest = SPLIT_DIR / split_name / cls / p.name
        if not dest.exists():
            shutil.copy2(str(p), str(dest))
            copied += 1

    total = len(list((SPLIT_DIR / split_name / 'Positive').iterdir())) + \
            len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))
    print(f"\n{split_name.upper()}: {total} imágenes ({copied} copiadas ahora)")
    print(f"  Positive: {len(list((SPLIT_DIR / split_name / 'Positive').iterdir()))}")
    print(f"  Negative: {len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))}")
# Out:
# Total imágenes encontradas: 56092
#   Positivas: 8484, Negativas: 47608
#
# TRAIN: 33654 imágenes (33654 copiadas ahora)
#   Positive: 5090
#   Negative: 28564
#
# VAL: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522
#
# TEST: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522

# %%
import importlib

os.makedirs('models', exist_ok=True)

with open('models/cnn_simple.py', 'w') as f:
    f.write("""
import tensorflow as tf
from tensorflow.keras import layers, models

def build_simple_cnn(input_shape=(227, 227, 3)):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        # Una sola capa convolucional
        # Usamos 2 filtros de 3x3 para detectar bordes básicos
        layers.Conv2D(2, (3, 3), activation='relu', padding='same'),

        # Global Average Pooling: Reduce cada mapa de activación a un solo número
        layers.GlobalAveragePooling2D(),

        # Capa de salida: 1 neurona para clasificación binaria
        layers.Dense(1, activation='sigmoid')
    ])

    return model
""")

sys.path.append('./models')

import cnn_simple
importlib.reload(cnn_simple)

from cnn_simple import build_simple_cnn

modelo_complejo = build_simple_cnn()
modelo_complejo.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 227, 227, 2)    │            56 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2)              │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 59 (236.00 B)
#  Trainable params: 59 (236.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Carga de datos para entrenamiento
IMG_SIZE = (227, 227)
BATCH_SIZE = 32

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'train'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=True, seed=42
)

val_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'val'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)

test_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'test'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)
# Out:
# Found 33654 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import Adam
# Compilacion y entrenamiento
model = build_simple_cnn(input_shape=(227, 227, 3))

# Compilamos usando un Learning Rate bajo
optimizer = Adam(learning_rate=0.00001)
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy', Recall(name='recall'), Precision(name='precision'), AUC(name='auc')]
)
csv_logger = CSVLogger('historial_entrenamiento_cnn.csv', append=True)
checkpoint = ModelCheckpoint('best_cnn_model_simple.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.0000001, verbose=1, mode='max')
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True, mode='max')

n_pos = 8484   # Positive (Clase 1)
n_neg = 47608  # Negative (Clase 0)
total = n_pos + n_neg

# Fórmula para balancear pesos
weight_for_0 = (1 / n_neg) * (total / 2.0)
weight_for_1 = (1 / n_pos) * (total / 2.0)

class_weight = {
    0: weight_for_0,
    1: weight_for_1
}

print(f"Peso para Negative (0): {weight_for_0:.2f}")
print(f"Peso para Positive (1): {weight_for_1:.2f}")

history = model.fit(
    train_gen,
    validation_data=val_gen,
    class_weight=class_weight,
    epochs=120,
    callbacks=[checkpoint, reduce_lr, early_stopping, csv_logger]
)

# Cargar el modelo en su mejor punto
model.load_weights('best_cnn_model_simple.keras')
# Out:
# Peso para Negative (0): 0.59
# Peso para Positive (1): 3.31
# Epoch 1/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.1498 - auc: 0.4884 - loss: 1.2642 - precision: 0.1498 - recall: 1.0000
# Epoch 1: val_accuracy improved from None to 0.15135, saving model to best_cnn_model_simple.keras
#
# Epoch 1: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 86s 78ms/step - accuracy: 0.1512 - auc: 0.4934 - loss: 1.2276 - precision: 0.1512 - recall: 1.0000 - val_accuracy: 0.1514 - val_auc: 0.4826 - val_loss: 1.6658 - val_precision: 0.1513 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1534 - auc: 0.4892 - loss: 1.1598 - precision: 0.1531 - recall: 0.9999
# Epoch 2: val_accuracy improved from 0.15135 to 0.15402, saving model to best_cnn_model_simple.keras
#
# Epoch 2: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.1520 - auc: 0.4922 - loss: 1.1181 - precision: 0.1513 - recall: 0.9998 - val_accuracy: 0.1540 - val_auc: 0.4795 - val_loss: 1.4914 - val_precision: 0.1516 - val_recall: 0.9988 - learning_rate: 1.0000e-05
# Epoch 3/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1579 - auc: 0.4942 - loss: 1.0578 - precision: 0.1556 - recall: 0.9989
# Epoch 3: val_accuracy improved from 0.15402 to 0.15857, saving model to best_cnn_model_simple.keras
#
# Epoch 3: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 71ms/step - accuracy: 0.1546 - auc: 0.4923 - loss: 1.0341 - precision: 0.1515 - recall: 0.9976 - val_accuracy: 0.1586 - val_auc: 0.4823 - val_loss: 1.3650 - val_precision: 0.1517 - val_recall: 0.9941 - learning_rate: 1.0000e-05
# Epoch 4/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.1612 - auc: 0.4922 - loss: 0.9846 - precision: 0.1537 - recall: 0.9924
# Epoch 4: val_accuracy improved from 0.15857 to 0.16624, saving model to best_cnn_model_simple.keras
#
# Epoch 4: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 73s 70ms/step - accuracy: 0.1602 - auc: 0.4941 - loss: 0.9760 - precision: 0.1517 - recall: 0.9916 - val_accuracy: 0.1662 - val_auc: 0.4814 - val_loss: 1.2774 - val_precision: 0.1522 - val_recall: 0.9876 - learning_rate: 1.0000e-05
# Epoch 5/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.1670 - auc: 0.4940 - loss: 0.9462 - precision: 0.1495 - recall: 0.9791
# Epoch 5: val_accuracy improved from 0.16624 to 0.19654, saving model to best_cnn_model_simple.keras
#
# Epoch 5: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.1767 - auc: 0.4940 - loss: 0.9373 - precision: 0.1528 - recall: 0.9774 - val_accuracy: 0.1965 - val_auc: 0.4815 - val_loss: 1.2121 - val_precision: 0.1528 - val_recall: 0.9487 - learning_rate: 1.0000e-05
# Epoch 6/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2083 - auc: 0.4900 - loss: 0.9214 - precision: 0.1548 - recall: 0.9353
# Epoch 6: val_accuracy improved from 0.19654 to 0.25608, saving model to best_cnn_model_simple.keras
#
# Epoch 6: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 72ms/step - accuracy: 0.2222 - auc: 0.4949 - loss: 0.9073 - precision: 0.1533 - recall: 0.9157 - val_accuracy: 0.2561 - val_auc: 0.4832 - val_loss: 1.1547 - val_precision: 0.1524 - val_recall: 0.8586 - learning_rate: 1.0000e-05
# Epoch 7/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.2751 - auc: 0.4909 - loss: 0.8906 - precision: 0.1556 - recall: 0.8475
# Epoch 7: val_accuracy improved from 0.25608 to 0.36625, saving model to best_cnn_model_simple.keras
#
# Epoch 7: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.3027 - auc: 0.4949 - loss: 0.8809 - precision: 0.1555 - recall: 0.8147 - val_accuracy: 0.3663 - val_auc: 0.4817 - val_loss: 1.1020 - val_precision: 0.1544 - val_recall: 0.7124 - learning_rate: 1.0000e-05
# Epoch 8/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3878 - auc: 0.4874 - loss: 0.8694 - precision: 0.1549 - recall: 0.6774
# Epoch 8: val_accuracy improved from 0.36625 to 0.44371, saving model to best_cnn_model_simple.keras
#
# Epoch 8: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 71ms/step - accuracy: 0.4122 - auc: 0.4947 - loss: 0.8576 - precision: 0.1570 - recall: 0.6603 - val_accuracy: 0.4437 - val_auc: 0.4812 - val_loss: 1.0550 - val_precision: 0.1525 - val_recall: 0.5875 - learning_rate: 1.0000e-05
# Epoch 9/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.4649 - auc: 0.4990 - loss: 0.8447 - precision: 0.1601 - recall: 0.5970
# Epoch 9: val_accuracy improved from 0.44371 to 0.48302, saving model to best_cnn_model_simple.keras
#
# Epoch 9: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.4716 - auc: 0.4924 - loss: 0.8371 - precision: 0.1560 - recall: 0.5656 - val_accuracy: 0.4830 - val_auc: 0.4824 - val_loss: 1.0127 - val_precision: 0.1473 - val_recall: 0.5050 - learning_rate: 1.0000e-05
# Epoch 10/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.4987 - auc: 0.4929 - loss: 0.8265 - precision: 0.1552 - recall: 0.5191
# Epoch 10: val_accuracy improved from 0.48302 to 0.51030, saving model to best_cnn_model_simple.keras
#
# Epoch 10: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.5062 - auc: 0.4925 - loss: 0.8193 - precision: 0.1528 - recall: 0.4982 - val_accuracy: 0.5103 - val_auc: 0.4802 - val_loss: 0.9755 - val_precision: 0.1432 - val_recall: 0.4490 - learning_rate: 1.0000e-05
# Epoch 11/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5227 - auc: 0.4948 - loss: 0.8179 - precision: 0.1549 - recall: 0.4673
# Epoch 11: val_accuracy improved from 0.51030 to 0.52812, saving model to best_cnn_model_simple.keras
#
# Epoch 11: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 73s 70ms/step - accuracy: 0.5272 - auc: 0.4913 - loss: 0.8038 - precision: 0.1475 - recall: 0.4448 - val_accuracy: 0.5281 - val_auc: 0.4780 - val_loss: 0.9423 - val_precision: 0.1369 - val_recall: 0.3995 - learning_rate: 1.0000e-05
# Epoch 12/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.5344 - auc: 0.4811 - loss: 0.8002 - precision: 0.1411 - recall: 0.4030
# Epoch 12: val_accuracy improved from 0.52812 to 0.54488, saving model to best_cnn_model_simple.keras
#
# Epoch 12: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.5445 - auc: 0.4906 - loss: 0.7904 - precision: 0.1426 - recall: 0.4012 - val_accuracy: 0.5449 - val_auc: 0.4796 - val_loss: 0.9131 - val_precision: 0.1321 - val_recall: 0.3606 - learning_rate: 1.0000e-05
# Epoch 13/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5555 - auc: 0.4874 - loss: 0.7842 - precision: 0.1395 - recall: 0.3604
# Epoch 13: val_accuracy improved from 0.54488 to 0.55718, saving model to best_cnn_model_simple.keras
#
# Epoch 13: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 74s 71ms/step - accuracy: 0.5587 - auc: 0.4900 - loss: 0.7788 - precision: 0.1359 - recall: 0.3580 - val_accuracy: 0.5572 - val_auc: 0.4753 - val_loss: 0.8872 - val_precision: 0.1287 - val_recall: 0.3341 - learning_rate: 1.0000e-05
# Epoch 14/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5657 - auc: 0.4875 - loss: 0.7694 - precision: 0.1319 - recall: 0.3342
# Epoch 14: val_accuracy improved from 0.55718 to 0.57055, saving model to best_cnn_model_simple.keras
#
# Epoch 14: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.5696 - auc: 0.4874 - loss: 0.7688 - precision: 0.1320 - recall: 0.3308 - val_accuracy: 0.5705 - val_auc: 0.4769 - val_loss: 0.8642 - val_precision: 0.1264 - val_recall: 0.3111 - learning_rate: 1.0000e-05
# Epoch 15/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.5861 - auc: 0.4912 - loss: 0.7582 - precision: 0.1329 - recall: 0.3173
# Epoch 15: val_accuracy improved from 0.57055 to 0.58232, saving model to best_cnn_model_simple.keras
#
# Epoch 15: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 73s 70ms/step - accuracy: 0.5832 - auc: 0.4887 - loss: 0.7601 - precision: 0.1294 - recall: 0.3067 - val_accuracy: 0.5823 - val_auc: 0.4782 - val_loss: 0.8444 - val_precision: 0.1248 - val_recall: 0.2929 - learning_rate: 1.0000e-05
# Epoch 16/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.5928 - auc: 0.4838 - loss: 0.7505 - precision: 0.1240 - recall: 0.2860
# Epoch 16: val_accuracy improved from 0.58232 to 0.59560, saving model to best_cnn_model_simple.keras
#
# Epoch 16: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 84s 72ms/step - accuracy: 0.5967 - auc: 0.4903 - loss: 0.7527 - precision: 0.1297 - recall: 0.2919 - val_accuracy: 0.5956 - val_auc: 0.4780 - val_loss: 0.8266 - val_precision: 0.1247 - val_recall: 0.2781 - learning_rate: 1.0000e-05
# Epoch 17/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6064 - auc: 0.4904 - loss: 0.7475 - precision: 0.1289 - recall: 0.2791
# Epoch 17: val_accuracy improved from 0.59560 to 0.61128, saving model to best_cnn_model_simple.keras
#
# Epoch 17: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 71ms/step - accuracy: 0.6103 - auc: 0.4862 - loss: 0.7463 - precision: 0.1302 - recall: 0.2774 - val_accuracy: 0.6113 - val_auc: 0.4704 - val_loss: 0.8107 - val_precision: 0.1250 - val_recall: 0.2616 - learning_rate: 1.0000e-05
# Epoch 18/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.6220 - auc: 0.4833 - loss: 0.7417 - precision: 0.1368 - recall: 0.2774
# Epoch 18: val_accuracy improved from 0.61128 to 0.62465, saving model to best_cnn_model_simple.keras
#
# Epoch 18: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 73s 70ms/step - accuracy: 0.6255 - auc: 0.4788 - loss: 0.7407 - precision: 0.1316 - recall: 0.2637 - val_accuracy: 0.6247 - val_auc: 0.4691 - val_loss: 0.7971 - val_precision: 0.1266 - val_recall: 0.2510 - learning_rate: 1.0000e-05
# Epoch 19/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.6339 - auc: 0.4872 - loss: 0.7346 - precision: 0.1331 - recall: 0.2599
# Epoch 19: val_accuracy improved from 0.62465 to 0.63740, saving model to best_cnn_model_simple.keras
#
# Epoch 19: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 73s 69ms/step - accuracy: 0.6367 - auc: 0.4816 - loss: 0.7359 - precision: 0.1315 - recall: 0.2501 - val_accuracy: 0.6374 - val_auc: 0.4742 - val_loss: 0.7846 - val_precision: 0.1280 - val_recall: 0.2404 - learning_rate: 1.0000e-05
# Epoch 20/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6479 - auc: 0.4927 - loss: 0.7347 - precision: 0.1403 - recall: 0.2519
# Epoch 20: val_accuracy improved from 0.63740 to 0.64961, saving model to best_cnn_model_simple.keras
#
# Epoch 20: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.6495 - auc: 0.4869 - loss: 0.7316 - precision: 0.1325 - recall: 0.2375 - val_accuracy: 0.6496 - val_auc: 0.4794 - val_loss: 0.7734 - val_precision: 0.1279 - val_recall: 0.2263 - learning_rate: 1.0000e-05
# Epoch 21/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6577 - auc: 0.4942 - loss: 0.7324 - precision: 0.1353 - recall: 0.2286
# Epoch 21: val_accuracy improved from 0.64961 to 0.66084, saving model to best_cnn_model_simple.keras
#
# Epoch 21: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.6608 - auc: 0.4922 - loss: 0.7278 - precision: 0.1337 - recall: 0.2267 - val_accuracy: 0.6608 - val_auc: 0.4781 - val_loss: 0.7634 - val_precision: 0.1294 - val_recall: 0.2169 - learning_rate: 1.0000e-05
# Epoch 22/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6737 - auc: 0.4916 - loss: 0.7187 - precision: 0.1343 - recall: 0.2189
# Epoch 22: val_accuracy improved from 0.66084 to 0.67038, saving model to best_cnn_model_simple.keras
#
# Epoch 22: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.6710 - auc: 0.4890 - loss: 0.7245 - precision: 0.1348 - recall: 0.2169 - val_accuracy: 0.6704 - val_auc: 0.4750 - val_loss: 0.7544 - val_precision: 0.1326 - val_recall: 0.2127 - learning_rate: 1.0000e-05
# Epoch 23/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6779 - auc: 0.4873 - loss: 0.7208 - precision: 0.1341 - recall: 0.2092
# Epoch 23: val_accuracy improved from 0.67038 to 0.67929, saving model to best_cnn_model_simple.keras
#
# Epoch 23: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.6802 - auc: 0.4855 - loss: 0.7215 - precision: 0.1353 - recall: 0.2067 - val_accuracy: 0.6793 - val_auc: 0.4772 - val_loss: 0.7462 - val_precision: 0.1337 - val_recall: 0.2045 - learning_rate: 1.0000e-05
# Epoch 24/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6826 - auc: 0.4862 - loss: 0.7267 - precision: 0.1311 - recall: 0.1875
# Epoch 24: val_accuracy improved from 0.67929 to 0.68553, saving model to best_cnn_model_simple.keras
#
# Epoch 24: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.6886 - auc: 0.4881 - loss: 0.7189 - precision: 0.1349 - recall: 0.1957 - val_accuracy: 0.6855 - val_auc: 0.4802 - val_loss: 0.7389 - val_precision: 0.1325 - val_recall: 0.1945 - learning_rate: 1.0000e-05
# Epoch 25/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6948 - auc: 0.4857 - loss: 0.7175 - precision: 0.1327 - recall: 0.1832
# Epoch 25: val_accuracy improved from 0.68553 to 0.69151, saving model to best_cnn_model_simple.keras
#
# Epoch 25: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.6966 - auc: 0.4910 - loss: 0.7165 - precision: 0.1361 - recall: 0.1880 - val_accuracy: 0.6915 - val_auc: 0.4819 - val_loss: 0.7320 - val_precision: 0.1316 - val_recall: 0.1856 - learning_rate: 1.0000e-05
# Epoch 26/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.6967 - auc: 0.4899 - loss: 0.7217 - precision: 0.1326 - recall: 0.1752
# Epoch 26: val_accuracy improved from 0.69151 to 0.69721, saving model to best_cnn_model_simple.keras
#
# Epoch 26: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.7034 - auc: 0.4977 - loss: 0.7143 - precision: 0.1370 - recall: 0.1813 - val_accuracy: 0.6972 - val_auc: 0.4928 - val_loss: 0.7253 - val_precision: 0.1301 - val_recall: 0.1762 - learning_rate: 1.0000e-05
# Epoch 27/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7030 - auc: 0.5000 - loss: 0.7175 - precision: 0.1350 - recall: 0.1744
# Epoch 27: val_accuracy improved from 0.69721 to 0.70381, saving model to best_cnn_model_simple.keras
#
# Epoch 27: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.7090 - auc: 0.5032 - loss: 0.7121 - precision: 0.1365 - recall: 0.1735 - val_accuracy: 0.7038 - val_auc: 0.4963 - val_loss: 0.7188 - val_precision: 0.1305 - val_recall: 0.1691 - learning_rate: 1.0000e-05
# Epoch 28/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7077 - auc: 0.5014 - loss: 0.7167 - precision: 0.1315 - recall: 0.1600
# Epoch 28: val_accuracy improved from 0.70381 to 0.70817, saving model to best_cnn_model_simple.keras
#
# Epoch 28: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.7140 - auc: 0.5035 - loss: 0.7099 - precision: 0.1345 - recall: 0.1640 - val_accuracy: 0.7082 - val_auc: 0.4946 - val_loss: 0.7125 - val_precision: 0.1289 - val_recall: 0.1615 - learning_rate: 1.0000e-05
# Epoch 29/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7186 - auc: 0.4981 - loss: 0.7087 - precision: 0.1315 - recall: 0.1531
# Epoch 29: val_accuracy improved from 0.70817 to 0.71156, saving model to best_cnn_model_simple.keras
#
# Epoch 29: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7195 - auc: 0.4994 - loss: 0.7078 - precision: 0.1337 - recall: 0.1560 - val_accuracy: 0.7116 - val_auc: 0.4886 - val_loss: 0.7062 - val_precision: 0.1266 - val_recall: 0.1538 - learning_rate: 1.0000e-05
# Epoch 30/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7223 - auc: 0.4916 - loss: 0.7038 - precision: 0.1325 - recall: 0.1530
# Epoch 30: val_accuracy improved from 0.71156 to 0.71789, saving model to best_cnn_model_simple.keras
#
# Epoch 30: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.7235 - auc: 0.4935 - loss: 0.7058 - precision: 0.1314 - recall: 0.1475 - val_accuracy: 0.7179 - val_auc: 0.4879 - val_loss: 0.6998 - val_precision: 0.1263 - val_recall: 0.1461 - learning_rate: 1.0000e-05
# Epoch 31/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7237 - auc: 0.4878 - loss: 0.7101 - precision: 0.1263 - recall: 0.1364
# Epoch 31: val_accuracy improved from 0.71789 to 0.72244, saving model to best_cnn_model_simple.keras
#
# Epoch 31: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7290 - auc: 0.4907 - loss: 0.7040 - precision: 0.1311 - recall: 0.1407 - val_accuracy: 0.7224 - val_auc: 0.4864 - val_loss: 0.6941 - val_precision: 0.1245 - val_recall: 0.1385 - learning_rate: 1.0000e-05
# Epoch 32/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7280 - auc: 0.4819 - loss: 0.7089 - precision: 0.1290 - recall: 0.1332
# Epoch 32: val_accuracy improved from 0.72244 to 0.72930, saving model to best_cnn_model_simple.keras
#
# Epoch 32: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7346 - auc: 0.4860 - loss: 0.7024 - precision: 0.1314 - recall: 0.1346 - val_accuracy: 0.7293 - val_auc: 0.4823 - val_loss: 0.6890 - val_precision: 0.1244 - val_recall: 0.1308 - learning_rate: 1.0000e-05
# Epoch 33/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7432 - auc: 0.4857 - loss: 0.6982 - precision: 0.1282 - recall: 0.1244
# Epoch 33: val_accuracy improved from 0.72930 to 0.73420, saving model to best_cnn_model_simple.keras
#
# Epoch 33: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 73ms/step - accuracy: 0.7404 - auc: 0.4832 - loss: 0.7010 - precision: 0.1311 - recall: 0.1273 - val_accuracy: 0.7342 - val_auc: 0.4799 - val_loss: 0.6845 - val_precision: 0.1267 - val_recall: 0.1285 - learning_rate: 1.0000e-05
# Epoch 34/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7461 - auc: 0.4792 - loss: 0.6947 - precision: 0.1270 - recall: 0.1203
# Epoch 34: val_accuracy improved from 0.73420 to 0.73964, saving model to best_cnn_model_simple.keras
#
# Epoch 34: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7446 - auc: 0.4791 - loss: 0.6999 - precision: 0.1294 - recall: 0.1202 - val_accuracy: 0.7396 - val_auc: 0.4781 - val_loss: 0.6807 - val_precision: 0.1268 - val_recall: 0.1226 - learning_rate: 1.0000e-05
# Epoch 35/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7467 - auc: 0.4701 - loss: 0.6976 - precision: 0.1164 - recall: 0.1048
# Epoch 35: val_accuracy improved from 0.73964 to 0.74329, saving model to best_cnn_model_simple.keras
#
# Epoch 35: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7505 - auc: 0.4790 - loss: 0.6990 - precision: 0.1300 - recall: 0.1141 - val_accuracy: 0.7433 - val_auc: 0.4755 - val_loss: 0.6774 - val_precision: 0.1244 - val_recall: 0.1155 - learning_rate: 1.0000e-05
# Epoch 36/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7532 - auc: 0.4823 - loss: 0.7036 - precision: 0.1408 - recall: 0.1181
# Epoch 36: val_accuracy improved from 0.74329 to 0.74864, saving model to best_cnn_model_simple.keras
#
# Epoch 36: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7545 - auc: 0.4778 - loss: 0.6982 - precision: 0.1306 - recall: 0.1102 - val_accuracy: 0.7486 - val_auc: 0.4758 - val_loss: 0.6750 - val_precision: 0.1234 - val_recall: 0.1084 - learning_rate: 1.0000e-05
# Epoch 37/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7584 - auc: 0.4807 - loss: 0.6985 - precision: 0.1373 - recall: 0.1116
# Epoch 37: val_accuracy improved from 0.74864 to 0.75515, saving model to best_cnn_model_simple.keras
#
# Epoch 37: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 75ms/step - accuracy: 0.7584 - auc: 0.4751 - loss: 0.6976 - precision: 0.1290 - recall: 0.1039 - val_accuracy: 0.7551 - val_auc: 0.4770 - val_loss: 0.6729 - val_precision: 0.1261 - val_recall: 0.1043 - learning_rate: 1.0000e-05
# Epoch 38/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7600 - auc: 0.4744 - loss: 0.7048 - precision: 0.1385 - recall: 0.1054
# Epoch 38: val_accuracy improved from 0.75515 to 0.76076, saving model to best_cnn_model_simple.keras
#
# Epoch 38: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7631 - auc: 0.4735 - loss: 0.6971 - precision: 0.1314 - recall: 0.1010 - val_accuracy: 0.7608 - val_auc: 0.4763 - val_loss: 0.6714 - val_precision: 0.1281 - val_recall: 0.1002 - learning_rate: 1.0000e-05
# Epoch 39/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7722 - auc: 0.4772 - loss: 0.6944 - precision: 0.1378 - recall: 0.0991
# Epoch 39: val_accuracy improved from 0.76076 to 0.76513, saving model to best_cnn_model_simple.keras
#
# Epoch 39: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.7697 - auc: 0.4769 - loss: 0.6966 - precision: 0.1350 - recall: 0.0967 - val_accuracy: 0.7651 - val_auc: 0.4738 - val_loss: 0.6696 - val_precision: 0.1301 - val_recall: 0.0972 - learning_rate: 1.0000e-05
# Epoch 40/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7732 - auc: 0.4602 - loss: 0.6941 - precision: 0.1307 - recall: 0.0911
# Epoch 40: val_accuracy improved from 0.76513 to 0.77101, saving model to best_cnn_model_simple.keras
#
# Epoch 40: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.7725 - auc: 0.4661 - loss: 0.6962 - precision: 0.1353 - recall: 0.0935 - val_accuracy: 0.7710 - val_auc: 0.4668 - val_loss: 0.6686 - val_precision: 0.1330 - val_recall: 0.0931 - learning_rate: 1.0000e-05
# Epoch 41/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7749 - auc: 0.4661 - loss: 0.6943 - precision: 0.1311 - recall: 0.0881
# Epoch 41: val_accuracy improved from 0.77101 to 0.77449, saving model to best_cnn_model_simple.keras
#
# Epoch 41: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7761 - auc: 0.4678 - loss: 0.6959 - precision: 0.1356 - recall: 0.0894 - val_accuracy: 0.7745 - val_auc: 0.4767 - val_loss: 0.6678 - val_precision: 0.1317 - val_recall: 0.0878 - learning_rate: 1.0000e-05
# Epoch 42/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7792 - auc: 0.4744 - loss: 0.6971 - precision: 0.1322 - recall: 0.0820
# Epoch 42: val_accuracy improved from 0.77449 to 0.77823, saving model to best_cnn_model_simple.keras
#
# Epoch 42: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.7802 - auc: 0.4754 - loss: 0.6956 - precision: 0.1381 - recall: 0.0864 - val_accuracy: 0.7782 - val_auc: 0.4799 - val_loss: 0.6666 - val_precision: 0.1348 - val_recall: 0.0860 - learning_rate: 1.0000e-05
# Epoch 43/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7818 - auc: 0.4770 - loss: 0.6966 - precision: 0.1408 - recall: 0.0855
# Epoch 43: val_accuracy improved from 0.77823 to 0.78233, saving model to best_cnn_model_simple.keras
#
# Epoch 43: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7820 - auc: 0.4755 - loss: 0.6953 - precision: 0.1377 - recall: 0.0839 - val_accuracy: 0.7823 - val_auc: 0.4838 - val_loss: 0.6666 - val_precision: 0.1352 - val_recall: 0.0813 - learning_rate: 1.0000e-05
# Epoch 44/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7856 - auc: 0.4778 - loss: 0.6922 - precision: 0.1373 - recall: 0.0811
# Epoch 44: val_accuracy improved from 0.78233 to 0.78510, saving model to best_cnn_model_simple.keras
#
# Epoch 44: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7851 - auc: 0.4771 - loss: 0.6951 - precision: 0.1370 - recall: 0.0794 - val_accuracy: 0.7851 - val_auc: 0.4830 - val_loss: 0.6659 - val_precision: 0.1357 - val_recall: 0.0784 - learning_rate: 1.0000e-05
# Epoch 45/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.7849 - auc: 0.4761 - loss: 0.6971 - precision: 0.1315 - recall: 0.0737
# Epoch 45: val_accuracy improved from 0.78510 to 0.78857, saving model to best_cnn_model_simple.keras
#
# Epoch 45: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.7874 - auc: 0.4780 - loss: 0.6948 - precision: 0.1366 - recall: 0.0762 - val_accuracy: 0.7886 - val_auc: 0.4837 - val_loss: 0.6656 - val_precision: 0.1398 - val_recall: 0.0772 - learning_rate: 1.0000e-05
# Epoch 46/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.7897 - auc: 0.4761 - loss: 0.6935 - precision: 0.1315 - recall: 0.0704
# Epoch 46: val_accuracy improved from 0.78857 to 0.79089, saving model to best_cnn_model_simple.keras
#
# Epoch 46: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.7907 - auc: 0.4798 - loss: 0.6946 - precision: 0.1379 - recall: 0.0731 - val_accuracy: 0.7909 - val_auc: 0.4844 - val_loss: 0.6653 - val_precision: 0.1390 - val_recall: 0.0737 - learning_rate: 1.0000e-05
# Epoch 47/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7893 - auc: 0.4728 - loss: 0.6979 - precision: 0.1341 - recall: 0.0702
# Epoch 47: val_accuracy improved from 0.79089 to 0.79303, saving model to best_cnn_model_simple.keras
#
# Epoch 47: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.7937 - auc: 0.4808 - loss: 0.6944 - precision: 0.1401 - recall: 0.0709 - val_accuracy: 0.7930 - val_auc: 0.4845 - val_loss: 0.6649 - val_precision: 0.1396 - val_recall: 0.0713 - learning_rate: 1.0000e-05
# Epoch 48/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7970 - auc: 0.4814 - loss: 0.6961 - precision: 0.1478 - recall: 0.0700
# Epoch 48: val_accuracy improved from 0.79303 to 0.79615, saving model to best_cnn_model_simple.keras
#
# Epoch 48: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.7952 - auc: 0.4808 - loss: 0.6943 - precision: 0.1390 - recall: 0.0682 - val_accuracy: 0.7961 - val_auc: 0.4849 - val_loss: 0.6647 - val_precision: 0.1454 - val_recall: 0.0713 - learning_rate: 1.0000e-05
# Epoch 49/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7981 - auc: 0.4896 - loss: 0.6961 - precision: 0.1535 - recall: 0.0711
# Epoch 49: val_accuracy improved from 0.79615 to 0.79758, saving model to best_cnn_model_simple.keras
#
# Epoch 49: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 71ms/step - accuracy: 0.7980 - auc: 0.4807 - loss: 0.6941 - precision: 0.1403 - recall: 0.0654 - val_accuracy: 0.7976 - val_auc: 0.4839 - val_loss: 0.6645 - val_precision: 0.1439 - val_recall: 0.0684 - learning_rate: 1.0000e-05
# Epoch 50/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7987 - auc: 0.4749 - loss: 0.6942 - precision: 0.1381 - recall: 0.0625
# Epoch 50: val_accuracy improved from 0.79758 to 0.80052, saving model to best_cnn_model_simple.keras
#
# Epoch 50: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 71ms/step - accuracy: 0.8002 - auc: 0.4801 - loss: 0.6939 - precision: 0.1388 - recall: 0.0617 - val_accuracy: 0.8005 - val_auc: 0.4854 - val_loss: 0.6649 - val_precision: 0.1436 - val_recall: 0.0642 - learning_rate: 1.0000e-05
# Epoch 51/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.7998 - auc: 0.4709 - loss: 0.6934 - precision: 0.1379 - recall: 0.0620
# Epoch 51: val_accuracy improved from 0.80052 to 0.80239, saving model to best_cnn_model_simple.keras
#
# Epoch 51: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.8022 - auc: 0.4720 - loss: 0.6938 - precision: 0.1367 - recall: 0.0580 - val_accuracy: 0.8024 - val_auc: 0.4791 - val_loss: 0.6652 - val_precision: 0.1458 - val_recall: 0.0631 - learning_rate: 1.0000e-05
# Epoch 52/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.8076 - auc: 0.4746 - loss: 0.6858 - precision: 0.1353 - recall: 0.0563
# Epoch 52: val_accuracy improved from 0.80239 to 0.80462, saving model to best_cnn_model_simple.keras
#
# Epoch 52: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.8044 - auc: 0.4748 - loss: 0.6937 - precision: 0.1395 - recall: 0.0568 - val_accuracy: 0.8046 - val_auc: 0.4864 - val_loss: 0.6649 - val_precision: 0.1469 - val_recall: 0.0607 - learning_rate: 1.0000e-05
# Epoch 53/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8052 - auc: 0.4775 - loss: 0.6937 - precision: 0.1369 - recall: 0.0546
# Epoch 53: val_accuracy improved from 0.80462 to 0.80551, saving model to best_cnn_model_simple.keras
#
# Epoch 53: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.8064 - auc: 0.4803 - loss: 0.6935 - precision: 0.1381 - recall: 0.0534 - val_accuracy: 0.8055 - val_auc: 0.4915 - val_loss: 0.6651 - val_precision: 0.1449 - val_recall: 0.0583 - learning_rate: 1.0000e-05
# Epoch 54/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8071 - auc: 0.4823 - loss: 0.6941 - precision: 0.1430 - recall: 0.0542
# Epoch 54: val_accuracy improved from 0.80551 to 0.80640, saving model to best_cnn_model_simple.keras
#
# Epoch 54: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8073 - auc: 0.4835 - loss: 0.6934 - precision: 0.1347 - recall: 0.0505 - val_accuracy: 0.8064 - val_auc: 0.4946 - val_loss: 0.6655 - val_precision: 0.1439 - val_recall: 0.0566 - learning_rate: 1.0000e-05
# Epoch 55/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8123 - auc: 0.4848 - loss: 0.6859 - precision: 0.1262 - recall: 0.0459
# Epoch 55: val_accuracy improved from 0.80640 to 0.80756, saving model to best_cnn_model_simple.keras
#
# Epoch 55: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.8088 - auc: 0.4851 - loss: 0.6933 - precision: 0.1360 - recall: 0.0493 - val_accuracy: 0.8076 - val_auc: 0.4972 - val_loss: 0.6654 - val_precision: 0.1424 - val_recall: 0.0542 - learning_rate: 1.0000e-05
# Epoch 56/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8090 - auc: 0.4881 - loss: 0.6941 - precision: 0.1240 - recall: 0.0427
# Epoch 56: val_accuracy improved from 0.80756 to 0.80988, saving model to best_cnn_model_simple.keras
#
# Epoch 56: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.8105 - auc: 0.4877 - loss: 0.6931 - precision: 0.1367 - recall: 0.0475 - val_accuracy: 0.8099 - val_auc: 0.4944 - val_loss: 0.6654 - val_precision: 0.1450 - val_recall: 0.0524 - learning_rate: 1.0000e-05
# Epoch 57/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8117 - auc: 0.4870 - loss: 0.6937 - precision: 0.1432 - recall: 0.0489
# Epoch 57: val_accuracy improved from 0.80988 to 0.81139, saving model to best_cnn_model_simple.keras
#
# Epoch 57: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 76s 72ms/step - accuracy: 0.8117 - auc: 0.4862 - loss: 0.6930 - precision: 0.1360 - recall: 0.0458 - val_accuracy: 0.8114 - val_auc: 0.4963 - val_loss: 0.6658 - val_precision: 0.1503 - val_recall: 0.0530 - learning_rate: 1.0000e-05
# Epoch 58/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8155 - auc: 0.4936 - loss: 0.6889 - precision: 0.1319 - recall: 0.0428
# Epoch 58: val_accuracy improved from 0.81139 to 0.81255, saving model to best_cnn_model_simple.keras
#
# Epoch 58: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.8134 - auc: 0.4872 - loss: 0.6929 - precision: 0.1355 - recall: 0.0434 - val_accuracy: 0.8126 - val_auc: 0.4967 - val_loss: 0.6660 - val_precision: 0.1488 - val_recall: 0.0507 - learning_rate: 1.0000e-05
# Epoch 59/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8130 - auc: 0.4882 - loss: 0.6939 - precision: 0.1264 - recall: 0.0392
# Epoch 59: val_accuracy improved from 0.81255 to 0.81442, saving model to best_cnn_model_simple.keras
#
# Epoch 59: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.8147 - auc: 0.4860 - loss: 0.6928 - precision: 0.1341 - recall: 0.0413 - val_accuracy: 0.8144 - val_auc: 0.4993 - val_loss: 0.6667 - val_precision: 0.1556 - val_recall: 0.0513 - learning_rate: 1.0000e-05
# Epoch 60/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8154 - auc: 0.4853 - loss: 0.6924 - precision: 0.1236 - recall: 0.0369
# Epoch 60: val_accuracy improved from 0.81442 to 0.81487, saving model to best_cnn_model_simple.keras
#
# Epoch 60: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 73ms/step - accuracy: 0.8160 - auc: 0.4886 - loss: 0.6927 - precision: 0.1357 - recall: 0.0403 - val_accuracy: 0.8149 - val_auc: 0.4969 - val_loss: 0.6667 - val_precision: 0.1468 - val_recall: 0.0466 - learning_rate: 1.0000e-05
# Epoch 61/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8204 - auc: 0.4890 - loss: 0.6845 - precision: 0.1363 - recall: 0.0402
# Epoch 61: val_accuracy improved from 0.81487 to 0.81674, saving model to best_cnn_model_simple.keras
#
# Epoch 61: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8171 - auc: 0.4844 - loss: 0.6926 - precision: 0.1360 - recall: 0.0391 - val_accuracy: 0.8167 - val_auc: 0.4997 - val_loss: 0.6671 - val_precision: 0.1501 - val_recall: 0.0454 - learning_rate: 1.0000e-05
# Epoch 62/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8153 - auc: 0.4821 - loss: 0.6973 - precision: 0.1330 - recall: 0.0374
# Epoch 62: val_accuracy improved from 0.81674 to 0.81763, saving model to best_cnn_model_simple.keras
#
# Epoch 62: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.8182 - auc: 0.4909 - loss: 0.6925 - precision: 0.1354 - recall: 0.0375 - val_accuracy: 0.8176 - val_auc: 0.5092 - val_loss: 0.6678 - val_precision: 0.1503 - val_recall: 0.0442 - learning_rate: 1.0000e-05
# Epoch 63/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8191 - auc: 0.4981 - loss: 0.6919 - precision: 0.1367 - recall: 0.0371
# Epoch 63: val_accuracy improved from 0.81763 to 0.81817, saving model to best_cnn_model_simple.keras
#
# Epoch 63: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8187 - auc: 0.4957 - loss: 0.6924 - precision: 0.1335 - recall: 0.0361 - val_accuracy: 0.8182 - val_auc: 0.5087 - val_loss: 0.6680 - val_precision: 0.1478 - val_recall: 0.0424 - learning_rate: 1.0000e-05
# Epoch 64/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8223 - auc: 0.4893 - loss: 0.6878 - precision: 0.1288 - recall: 0.0338
# Epoch 64: val_accuracy improved from 0.81817 to 0.81825, saving model to best_cnn_model_simple.keras
#
# Epoch 64: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.8200 - auc: 0.4917 - loss: 0.6923 - precision: 0.1378 - recall: 0.0361 - val_accuracy: 0.8183 - val_auc: 0.5075 - val_loss: 0.6684 - val_precision: 0.1437 - val_recall: 0.0407 - learning_rate: 1.0000e-05
# Epoch 65/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8193 - auc: 0.4926 - loss: 0.6954 - precision: 0.1456 - recall: 0.0371
# Epoch 65: val_accuracy improved from 0.81825 to 0.81870, saving model to best_cnn_model_simple.keras
#
# Epoch 65: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8204 - auc: 0.4905 - loss: 0.6922 - precision: 0.1364 - recall: 0.0352 - val_accuracy: 0.8187 - val_auc: 0.5085 - val_loss: 0.6687 - val_precision: 0.1392 - val_recall: 0.0383 - learning_rate: 1.0000e-05
# Epoch 66/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8248 - auc: 0.4979 - loss: 0.6852 - precision: 0.1359 - recall: 0.0349
# Epoch 66: val_accuracy improved from 0.81870 to 0.81932, saving model to best_cnn_model_simple.keras
#
# Epoch 66: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8212 - auc: 0.4926 - loss: 0.6922 - precision: 0.1358 - recall: 0.0340 - val_accuracy: 0.8193 - val_auc: 0.5098 - val_loss: 0.6693 - val_precision: 0.1382 - val_recall: 0.0371 - learning_rate: 1.0000e-05
# Epoch 67/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8226 - auc: 0.4918 - loss: 0.6937 - precision: 0.1312 - recall: 0.0305
# Epoch 67: val_accuracy did not improve from 0.81932
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.8216 - auc: 0.4936 - loss: 0.6921 - precision: 0.1337 - recall: 0.0328 - val_accuracy: 0.8193 - val_auc: 0.5083 - val_loss: 0.6694 - val_precision: 0.1333 - val_recall: 0.0354 - learning_rate: 1.0000e-05
# Epoch 68/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8210 - auc: 0.4897 - loss: 0.6971 - precision: 0.1269 - recall: 0.0284
# Epoch 68: val_accuracy did not improve from 0.81932
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 88s 84ms/step - accuracy: 0.8228 - auc: 0.4942 - loss: 0.6920 - precision: 0.1314 - recall: 0.0306 - val_accuracy: 0.8191 - val_auc: 0.5069 - val_loss: 0.6697 - val_precision: 0.1292 - val_recall: 0.0342 - learning_rate: 1.0000e-05
# Epoch 69/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8218 - auc: 0.4871 - loss: 0.6910 - precision: 0.1184 - recall: 0.0282
# Epoch 69: val_accuracy improved from 0.81932 to 0.82093, saving model to best_cnn_model_simple.keras
#
# Epoch 69: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8228 - auc: 0.4923 - loss: 0.6919 - precision: 0.1302 - recall: 0.0303 - val_accuracy: 0.8209 - val_auc: 0.5070 - val_loss: 0.6702 - val_precision: 0.1338 - val_recall: 0.0336 - learning_rate: 1.0000e-05
# Epoch 70/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8229 - auc: 0.4940 - loss: 0.6920 - precision: 0.1355 - recall: 0.0310
# Epoch 70: val_accuracy improved from 0.82093 to 0.82325, saving model to best_cnn_model_simple.keras
#
# Epoch 70: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 84s 80ms/step - accuracy: 0.8227 - auc: 0.4927 - loss: 0.6919 - precision: 0.1262 - recall: 0.0291 - val_accuracy: 0.8232 - val_auc: 0.5072 - val_loss: 0.6709 - val_precision: 0.1407 - val_recall: 0.0330 - learning_rate: 1.0000e-05
# Epoch 71/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8231 - auc: 0.4968 - loss: 0.6902 - precision: 0.1150 - recall: 0.0264
# Epoch 71: val_accuracy improved from 0.82325 to 0.82351, saving model to best_cnn_model_simple.keras
#
# Epoch 71: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8244 - auc: 0.4956 - loss: 0.6918 - precision: 0.1265 - recall: 0.0273 - val_accuracy: 0.8235 - val_auc: 0.5147 - val_loss: 0.6713 - val_precision: 0.1399 - val_recall: 0.0324 - learning_rate: 1.0000e-05
# Epoch 72/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8266 - auc: 0.5033 - loss: 0.6874 - precision: 0.1232 - recall: 0.0267
# Epoch 72: val_accuracy did not improve from 0.82351
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.8247 - auc: 0.5048 - loss: 0.6917 - precision: 0.1264 - recall: 0.0269 - val_accuracy: 0.8229 - val_auc: 0.5229 - val_loss: 0.6715 - val_precision: 0.1357 - val_recall: 0.0318 - learning_rate: 1.0000e-05
# Epoch 73/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8245 - auc: 0.5090 - loss: 0.6928 - precision: 0.1069 - recall: 0.0217
# Epoch 73: val_accuracy did not improve from 0.82351
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 76ms/step - accuracy: 0.8253 - auc: 0.5097 - loss: 0.6917 - precision: 0.1225 - recall: 0.0251 - val_accuracy: 0.8233 - val_auc: 0.5250 - val_loss: 0.6719 - val_precision: 0.1355 - val_recall: 0.0312 - learning_rate: 1.0000e-05
# Epoch 74/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8257 - auc: 0.5078 - loss: 0.6936 - precision: 0.1345 - recall: 0.0267
# Epoch 74: val_accuracy did not improve from 0.82351
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.8254 - auc: 0.5116 - loss: 0.6916 - precision: 0.1258 - recall: 0.0259 - val_accuracy: 0.8209 - val_auc: 0.5143 - val_loss: 0.6718 - val_precision: 0.1268 - val_recall: 0.0312 - learning_rate: 1.0000e-05
# Epoch 75/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8232 - auc: 0.5036 - loss: 0.6928 - precision: 0.1270 - recall: 0.0280
# Epoch 75: val_accuracy improved from 0.82351 to 0.82387, saving model to best_cnn_model_simple.keras
#
# Epoch 75: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.8240 - auc: 0.5030 - loss: 0.6916 - precision: 0.1168 - recall: 0.0250 - val_accuracy: 0.8239 - val_auc: 0.5172 - val_loss: 0.6726 - val_precision: 0.1377 - val_recall: 0.0312 - learning_rate: 1.0000e-05
# Epoch 76/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8213 - auc: 0.5009 - loss: 0.7013 - precision: 0.1276 - recall: 0.0248
# Epoch 76: val_accuracy did not improve from 0.82387
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8255 - auc: 0.5030 - loss: 0.6915 - precision: 0.1216 - recall: 0.0248 - val_accuracy: 0.8238 - val_auc: 0.5149 - val_loss: 0.6729 - val_precision: 0.1277 - val_recall: 0.0283 - learning_rate: 1.0000e-05
# Epoch 77/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8235 - auc: 0.5058 - loss: 0.6949 - precision: 0.1245 - recall: 0.0251
# Epoch 77: val_accuracy improved from 0.82387 to 0.82610, saving model to best_cnn_model_simple.keras
#
# Epoch 77: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8241 - auc: 0.4985 - loss: 0.6914 - precision: 0.1178 - recall: 0.0251 - val_accuracy: 0.8261 - val_auc: 0.5193 - val_loss: 0.6739 - val_precision: 0.1351 - val_recall: 0.0277 - learning_rate: 1.0000e-05
# Epoch 78/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.8291 - auc: 0.4983 - loss: 0.6908 - precision: 0.1242 - recall: 0.0220
# Epoch 78: val_accuracy did not improve from 0.82610
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 76ms/step - accuracy: 0.8272 - auc: 0.5029 - loss: 0.6914 - precision: 0.1229 - recall: 0.0232 - val_accuracy: 0.8235 - val_auc: 0.5145 - val_loss: 0.6735 - val_precision: 0.1247 - val_recall: 0.0277 - learning_rate: 1.0000e-05
# Epoch 79/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8251 - auc: 0.4982 - loss: 0.6882 - precision: 0.1105 - recall: 0.0239
# Epoch 79: val_accuracy improved from 0.82610 to 0.82708, saving model to best_cnn_model_simple.keras
#
# Epoch 79: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.8247 - auc: 0.5003 - loss: 0.6914 - precision: 0.1127 - recall: 0.0232 - val_accuracy: 0.8271 - val_auc: 0.5192 - val_loss: 0.6745 - val_precision: 0.1351 - val_recall: 0.0265 - learning_rate: 1.0000e-05
# Epoch 80/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8287 - auc: 0.5004 - loss: 0.6914 - precision: 0.1260 - recall: 0.0225
# Epoch 80: val_accuracy did not improve from 0.82708
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.8275 - auc: 0.5042 - loss: 0.6913 - precision: 0.1167 - recall: 0.0214 - val_accuracy: 0.8241 - val_auc: 0.5159 - val_loss: 0.6743 - val_precision: 0.1230 - val_recall: 0.0265 - learning_rate: 1.0000e-05
# Epoch 81/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8290 - auc: 0.5041 - loss: 0.6883 - precision: 0.1140 - recall: 0.0207
# Epoch 81: val_accuracy did not improve from 0.82708
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 73ms/step - accuracy: 0.8268 - auc: 0.5016 - loss: 0.6913 - precision: 0.1116 - recall: 0.0208 - val_accuracy: 0.8245 - val_auc: 0.5143 - val_loss: 0.6746 - val_precision: 0.1222 - val_recall: 0.0259 - learning_rate: 1.0000e-05
# Epoch 82/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8302 - auc: 0.5035 - loss: 0.6866 - precision: 0.1175 - recall: 0.0219
# Epoch 82: val_accuracy did not improve from 0.82708
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.8273 - auc: 0.5015 - loss: 0.6912 - precision: 0.1151 - recall: 0.0212 - val_accuracy: 0.8244 - val_auc: 0.5119 - val_loss: 0.6748 - val_precision: 0.1260 - val_recall: 0.0271 - learning_rate: 1.0000e-05
# Epoch 83/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8228 - auc: 0.5035 - loss: 0.6922 - precision: 0.1105 - recall: 0.0237
# Epoch 83: val_accuracy did not improve from 0.82708
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 71ms/step - accuracy: 0.8256 - auc: 0.5017 - loss: 0.6912 - precision: 0.1164 - recall: 0.0232 - val_accuracy: 0.8252 - val_auc: 0.5155 - val_loss: 0.6752 - val_precision: 0.1250 - val_recall: 0.0259 - learning_rate: 1.0000e-05
# Epoch 84/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8258 - auc: 0.5016 - loss: 0.6938 - precision: 0.1169 - recall: 0.0216
# Epoch 84: val_accuracy did not improve from 0.82708
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8275 - auc: 0.5064 - loss: 0.6912 - precision: 0.1225 - recall: 0.0228 - val_accuracy: 0.8253 - val_auc: 0.5202 - val_loss: 0.6753 - val_precision: 0.1275 - val_recall: 0.0265 - learning_rate: 1.0000e-05
# Epoch 85/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8272 - auc: 0.5079 - loss: 0.6885 - precision: 0.1240 - recall: 0.0253
# Epoch 85: val_accuracy did not improve from 0.82708
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.8267 - auc: 0.5099 - loss: 0.6911 - precision: 0.1191 - recall: 0.0228 - val_accuracy: 0.8248 - val_auc: 0.5276 - val_loss: 0.6755 - val_precision: 0.1295 - val_recall: 0.0277 - learning_rate: 1.0000e-05
# Epoch 86/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8249 - auc: 0.5187 - loss: 0.6885 - precision: 0.1250 - recall: 0.0278
# Epoch 86: val_accuracy improved from 0.82708 to 0.82735, saving model to best_cnn_model_simple.keras
#
# Epoch 86: finished saving model to best_cnn_model_simple.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 74ms/step - accuracy: 0.8240 - auc: 0.5172 - loss: 0.6911 - precision: 0.1167 - recall: 0.0250 - val_accuracy: 0.8273 - val_auc: 0.5323 - val_loss: 0.6762 - val_precision: 0.1364 - val_recall: 0.0265 - learning_rate: 1.0000e-05
# Epoch 87/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.8259 - auc: 0.5253 - loss: 0.6951 - precision: 0.1103 - recall: 0.0192
# Epoch 87: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 75s 72ms/step - accuracy: 0.8284 - auc: 0.5219 - loss: 0.6910 - precision: 0.1214 - recall: 0.0216 - val_accuracy: 0.8230 - val_auc: 0.5307 - val_loss: 0.6759 - val_precision: 0.1247 - val_recall: 0.0283 - learning_rate: 1.0000e-05
# Epoch 88/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8244 - auc: 0.5196 - loss: 0.6914 - precision: 0.1343 - recall: 0.0291
# Epoch 88: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 75ms/step - accuracy: 0.8250 - auc: 0.5212 - loss: 0.6910 - precision: 0.1212 - recall: 0.0251 - val_accuracy: 0.8240 - val_auc: 0.5349 - val_loss: 0.6764 - val_precision: 0.1226 - val_recall: 0.0265 - learning_rate: 1.0000e-05
# Epoch 89/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.8236 - auc: 0.5242 - loss: 0.6911 - precision: 0.1137 - recall: 0.0242
# Epoch 89: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 77s 74ms/step - accuracy: 0.8248 - auc: 0.5208 - loss: 0.6910 - precision: 0.1192 - recall: 0.0248 - val_accuracy: 0.8227 - val_auc: 0.5314 - val_loss: 0.6765 - val_precision: 0.1237 - val_recall: 0.0283 - learning_rate: 1.0000e-05
# Epoch 90/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.8231 - auc: 0.5123 - loss: 0.6890 - precision: 0.1029 - recall: 0.0231
# Epoch 90: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.8223 - auc: 0.5169 - loss: 0.6909 - precision: 0.1130 - recall: 0.0255 - val_accuracy: 0.8202 - val_auc: 0.5292 - val_loss: 0.6768 - val_precision: 0.1226 - val_recall: 0.0306 - learning_rate: 1.0000e-05
# Epoch 91/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.8202 - auc: 0.5199 - loss: 0.6883 - precision: 0.1355 - recall: 0.0369
# Epoch 91: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.8148 - auc: 0.5150 - loss: 0.6909 - precision: 0.1333 - recall: 0.0409 - val_accuracy: 0.8204 - val_auc: 0.5295 - val_loss: 0.6773 - val_precision: 0.1370 - val_recall: 0.0354 - learning_rate: 1.0000e-05
# Epoch 92/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.8175 - auc: 0.5143 - loss: 0.6958 - precision: 0.1449 - recall: 0.0389
# Epoch 92: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 85s 80ms/step - accuracy: 0.8156 - auc: 0.5164 - loss: 0.6909 - precision: 0.1529 - recall: 0.0483 - val_accuracy: 0.7961 - val_auc: 0.5238 - val_loss: 0.6769 - val_precision: 0.1729 - val_recall: 0.0919 - learning_rate: 1.0000e-05
# Epoch 93/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7955 - auc: 0.5101 - loss: 0.6867 - precision: 0.1594 - recall: 0.0870
# Epoch 93: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7863 - auc: 0.5118 - loss: 0.6908 - precision: 0.1707 - recall: 0.1071 - val_accuracy: 0.7925 - val_auc: 0.5262 - val_loss: 0.6773 - val_precision: 0.1940 - val_recall: 0.1179 - learning_rate: 1.0000e-05
# Epoch 94/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7829 - auc: 0.5053 - loss: 0.6943 - precision: 0.1743 - recall: 0.1146
# Epoch 94: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7736 - auc: 0.5138 - loss: 0.6908 - precision: 0.1765 - recall: 0.1356 - val_accuracy: 0.7543 - val_auc: 0.5238 - val_loss: 0.6773 - val_precision: 0.1923 - val_recall: 0.1951 - learning_rate: 1.0000e-05
# Epoch 95/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7612 - auc: 0.5078 - loss: 0.6944 - precision: 0.1836 - recall: 0.1641
# Epoch 95: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.7474 - auc: 0.5136 - loss: 0.6908 - precision: 0.1757 - recall: 0.1815 - val_accuracy: 0.6895 - val_auc: 0.5202 - val_loss: 0.6772 - val_precision: 0.1785 - val_recall: 0.2923 - learning_rate: 1.0000e-05
# Epoch 96/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6647 - auc: 0.5039 - loss: 0.6962 - precision: 0.1749 - recall: 0.3159
# Epoch 96: val_accuracy did not improve from 0.82735
#
# Epoch 96: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.6713 - auc: 0.5094 - loss: 0.6907 - precision: 0.1750 - recall: 0.3157 - val_accuracy: 0.6761 - val_auc: 0.5243 - val_loss: 0.6777 - val_precision: 0.1773 - val_recall: 0.3135 - learning_rate: 1.0000e-05
# Epoch 97/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6616 - auc: 0.5131 - loss: 0.6884 - precision: 0.1693 - recall: 0.3201
# Epoch 97: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.6614 - auc: 0.5112 - loss: 0.6907 - precision: 0.1714 - recall: 0.3232 - val_accuracy: 0.6550 - val_auc: 0.5240 - val_loss: 0.6778 - val_precision: 0.1732 - val_recall: 0.3394 - learning_rate: 5.0000e-06
# Epoch 98/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.6408 - auc: 0.5143 - loss: 0.6941 - precision: 0.1745 - recall: 0.3593
# Epoch 98: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.6348 - auc: 0.5101 - loss: 0.6907 - precision: 0.1684 - recall: 0.3591 - val_accuracy: 0.6547 - val_auc: 0.5252 - val_loss: 0.6781 - val_precision: 0.1748 - val_recall: 0.3447 - learning_rate: 5.0000e-06
# Epoch 99/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6478 - auc: 0.5170 - loss: 0.6932 - precision: 0.1770 - recall: 0.3573
# Epoch 99: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.6362 - auc: 0.5128 - loss: 0.6907 - precision: 0.1683 - recall: 0.3566 - val_accuracy: 0.6345 - val_auc: 0.5252 - val_loss: 0.6781 - val_precision: 0.1734 - val_recall: 0.3760 - learning_rate: 5.0000e-06
# Epoch 100/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6271 - auc: 0.5094 - loss: 0.6956 - precision: 0.1713 - recall: 0.3725
# Epoch 100: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.6213 - auc: 0.5133 - loss: 0.6907 - precision: 0.1672 - recall: 0.3778 - val_accuracy: 0.6145 - val_auc: 0.5248 - val_loss: 0.6781 - val_precision: 0.1720 - val_recall: 0.4060 - learning_rate: 5.0000e-06
# Epoch 101/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.6087 - auc: 0.5079 - loss: 0.6924 - precision: 0.1678 - recall: 0.3984
# Epoch 101: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 75ms/step - accuracy: 0.6075 - auc: 0.5132 - loss: 0.6906 - precision: 0.1660 - recall: 0.3965 - val_accuracy: 0.5960 - val_auc: 0.5233 - val_loss: 0.6780 - val_precision: 0.1690 - val_recall: 0.4266 - learning_rate: 5.0000e-06
# Epoch 102/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5791 - auc: 0.5070 - loss: 0.6982 - precision: 0.1650 - recall: 0.4211
# Epoch 102: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 84s 80ms/step - accuracy: 0.5820 - auc: 0.5105 - loss: 0.6906 - precision: 0.1633 - recall: 0.4277 - val_accuracy: 0.5911 - val_auc: 0.5246 - val_loss: 0.6782 - val_precision: 0.1681 - val_recall: 0.4313 - learning_rate: 5.0000e-06
# Epoch 103/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5881 - auc: 0.5167 - loss: 0.6919 - precision: 0.1699 - recall: 0.4404
# Epoch 103: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.5786 - auc: 0.5119 - loss: 0.6906 - precision: 0.1625 - recall: 0.4303 - val_accuracy: 0.5759 - val_auc: 0.5252 - val_loss: 0.6783 - val_precision: 0.1649 - val_recall: 0.4437 - learning_rate: 5.0000e-06
# Epoch 104/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5669 - auc: 0.5104 - loss: 0.6958 - precision: 0.1619 - recall: 0.4350
# Epoch 104: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 83s 79ms/step - accuracy: 0.5648 - auc: 0.5125 - loss: 0.6906 - precision: 0.1605 - recall: 0.4438 - val_accuracy: 0.5689 - val_auc: 0.5259 - val_loss: 0.6784 - val_precision: 0.1636 - val_recall: 0.4496 - learning_rate: 5.0000e-06
# Epoch 105/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5578 - auc: 0.5150 - loss: 0.6913 - precision: 0.1616 - recall: 0.4562
# Epoch 105: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 82s 78ms/step - accuracy: 0.5554 - auc: 0.5126 - loss: 0.6906 - precision: 0.1599 - recall: 0.4558 - val_accuracy: 0.5632 - val_auc: 0.5262 - val_loss: 0.6786 - val_precision: 0.1632 - val_recall: 0.4573 - learning_rate: 5.0000e-06
# Epoch 106/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5535 - auc: 0.5124 - loss: 0.6893 - precision: 0.1592 - recall: 0.4584
# Epoch 106: val_accuracy did not improve from 0.82735
#
# Epoch 106: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.5533 - auc: 0.5147 - loss: 0.6906 - precision: 0.1599 - recall: 0.4593 - val_accuracy: 0.5510 - val_auc: 0.5280 - val_loss: 0.6786 - val_precision: 0.1622 - val_recall: 0.4726 - learning_rate: 5.0000e-06
# Epoch 107/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5427 - auc: 0.5163 - loss: 0.6915 - precision: 0.1574 - recall: 0.4628
# Epoch 107: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 80s 76ms/step - accuracy: 0.5436 - auc: 0.5143 - loss: 0.6905 - precision: 0.1586 - recall: 0.4686 - val_accuracy: 0.5466 - val_auc: 0.5293 - val_loss: 0.6786 - val_precision: 0.1622 - val_recall: 0.4797 - learning_rate: 2.5000e-06
# Epoch 108/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5445 - auc: 0.5095 - loss: 0.6914 - precision: 0.1560 - recall: 0.4563
# Epoch 108: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.5408 - auc: 0.5152 - loss: 0.6905 - precision: 0.1584 - recall: 0.4721 - val_accuracy: 0.5417 - val_auc: 0.5304 - val_loss: 0.6786 - val_precision: 0.1617 - val_recall: 0.4850 - learning_rate: 2.5000e-06
# Epoch 109/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5310 - auc: 0.5131 - loss: 0.6882 - precision: 0.1554 - recall: 0.4792
# Epoch 109: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.5334 - auc: 0.5159 - loss: 0.6905 - precision: 0.1580 - recall: 0.4815 - val_accuracy: 0.5380 - val_auc: 0.5315 - val_loss: 0.6786 - val_precision: 0.1617 - val_recall: 0.4909 - learning_rate: 2.5000e-06
# Epoch 110/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5310 - auc: 0.5108 - loss: 0.6922 - precision: 0.1566 - recall: 0.4754
# Epoch 110: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 76ms/step - accuracy: 0.5315 - auc: 0.5175 - loss: 0.6905 - precision: 0.1581 - recall: 0.4849 - val_accuracy: 0.5338 - val_auc: 0.5304 - val_loss: 0.6787 - val_precision: 0.1613 - val_recall: 0.4956 - learning_rate: 2.5000e-06
# Epoch 111/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5294 - auc: 0.5172 - loss: 0.6905 - precision: 0.1556 - recall: 0.4780
# Epoch 111: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.5317 - auc: 0.5183 - loss: 0.6905 - precision: 0.1578 - recall: 0.4835 - val_accuracy: 0.5295 - val_auc: 0.5320 - val_loss: 0.6787 - val_precision: 0.1615 - val_recall: 0.5032 - learning_rate: 2.5000e-06
# Epoch 112/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.5269 - auc: 0.5168 - loss: 0.6881 - precision: 0.1558 - recall: 0.4870
# Epoch 112: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 81s 77ms/step - accuracy: 0.5239 - auc: 0.5199 - loss: 0.6905 - precision: 0.1573 - recall: 0.4927 - val_accuracy: 0.5266 - val_auc: 0.5332 - val_loss: 0.6787 - val_precision: 0.1617 - val_recall: 0.5091 - learning_rate: 2.5000e-06
# Epoch 113/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5281 - auc: 0.5223 - loss: 0.6853 - precision: 0.1565 - recall: 0.4971
# Epoch 113: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 78s 74ms/step - accuracy: 0.5230 - auc: 0.5202 - loss: 0.6905 - precision: 0.1576 - recall: 0.4955 - val_accuracy: 0.5225 - val_auc: 0.5353 - val_loss: 0.6787 - val_precision: 0.1615 - val_recall: 0.5144 - learning_rate: 2.5000e-06
# Epoch 114/120
# 1051/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5252 - auc: 0.5229 - loss: 0.6832 - precision: 0.1549 - recall: 0.4993
# Epoch 114: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 85s 77ms/step - accuracy: 0.5192 - auc: 0.5212 - loss: 0.6905 - precision: 0.1574 - recall: 0.5006 - val_accuracy: 0.5200 - val_auc: 0.5359 - val_loss: 0.6788 - val_precision: 0.1614 - val_recall: 0.5180 - learning_rate: 2.5000e-06
# Epoch 115/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5143 - auc: 0.5165 - loss: 0.6942 - precision: 0.1561 - recall: 0.4931
# Epoch 115: val_accuracy did not improve from 0.82735
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 75ms/step - accuracy: 0.5152 - auc: 0.5225 - loss: 0.6905 - precision: 0.1570 - recall: 0.5047 - val_accuracy: 0.5163 - val_auc: 0.5359 - val_loss: 0.6788 - val_precision: 0.1607 - val_recall: 0.5203 - learning_rate: 2.5000e-06
# Epoch 116/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5141 - auc: 0.5256 - loss: 0.6914 - precision: 0.1589 - recall: 0.5136
# Epoch 116: val_accuracy did not improve from 0.82735
#
# Epoch 116: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 79s 76ms/step - accuracy: 0.5106 - auc: 0.5227 - loss: 0.6905 - precision: 0.1566 - recall: 0.5100 - val_accuracy: 0.5132 - val_auc: 0.5386 - val_loss: 0.6788 - val_precision: 0.1602 - val_recall: 0.5227 - learning_rate: 2.5000e-06

# %%
model.load_weights('best_cnn_model_simple.keras')
# Buscamos el índice de la época con el mayor val_accuracy
best_epoch_idx = np.argmax(history.history['val_accuracy'])

# 1. CURVAS DE CONVERGENCIA DEL ENTRENAMIENTO
plt.figure(figsize=(14, 10))

# Gráfica de Loss
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Función de Coste (Binary Crossentropy)')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

# Gráfica de Accuracy
plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Accuracy')
plt.legend()

# Gráfica de AUC
plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Área bajo la curva (AUC) por época')
plt.xlabel('Época')
plt.ylabel('AUC')
plt.legend()

# Gráfica de Recall
plt.subplot(2, 2, 4)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Sensibilidad (Recall)')
plt.xlabel('Época')
plt.ylabel('Recall')
plt.legend()

plt.tight_layout()
plt.show()

# 2. PREDICCIONES Y EVALUACIÓN
print(f"\nEvaluando el mejor modelo guardado (Época {best_epoch_idx + 1})...")
eval_results = model.evaluate(test_gen, verbose=1)

print(f"\nMétricas de Test -> Loss: {eval_results[0]:.4f} | Accuracy: {eval_results[1]:.4f} | Recall: {eval_results[2]:.4f} | Precision: {eval_results[3]:.4f} | AUC: {eval_results[4]:.4f}")

predictions = model.predict(test_gen)
y_pred = (predictions > 0.5).astype(int).flatten()
y_true = test_gen.classes

# 3. CURVA ROC
plt.figure(figsize=(14, 6))
fpr, tpr, thresholds = roc_curve(y_true, predictions)
roc_auc = auc(fpr, tpr)
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC del Modelo')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# 4. MATRIZ DE CONFUSIÓN Y REPORTE
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_gen.class_indices.keys(),
            yticklabels=test_gen.class_indices.keys())
plt.title('Matriz de Confusión')
plt.ylabel('Real (Verdad)')
plt.xlabel('Predicción del Modelo')
plt.show()

print("\nReporte de Clasificación:")
print(classification_report(y_true, y_pred, target_names=test_gen.class_indices.keys()))
# Out:
# Evaluando el mejor modelo guardado (Época 86)...
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 19s 55ms/step - accuracy: 0.8286 - auc: 0.5333 - loss: 0.6761 - precision: 0.1331 - recall: 0.0242
#
# Métricas de Test -> Loss: 0.6761 | Accuracy: 0.8286 | Recall: 0.0242 | Precision: 0.1331 | AUC: 0.5333
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 19s 54ms/step
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.97      0.91      9522
#     Positive       0.13      0.02      0.04      1697
#
#     accuracy                           0.83     11219
#    macro avg       0.49      0.50      0.47     11219
# weighted avg       0.74      0.83      0.78     11219

# %%
positive_dir = SPLIT_DIR / 'test' / 'Positive'
negative_dir = SPLIT_DIR / 'test' / 'Negative'
sample_positive_path = sorted(positive_dir.glob('*.jpg'))[5]
sample_negative_path = sorted(negative_dir.glob('*.jpg'))[5]

# Buscamos la primera capa convolucional
capa_base = model.layers[0]
if isinstance(capa_base, tf.keras.Model):
    conv_layer = [layer for layer in capa_base.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=capa_base.inputs, outputs=conv_layer.output)
    es_resnet = True
else:
    conv_layer = [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=model.inputs, outputs=conv_layer.output)
    es_resnet = False

print(f"Extrayendo mapas de características de la capa: {conv_layer.name}")
num_filtros = min(6, conv_layer.filters)
muestras = [
    (sample_positive_path, 'Grieta (Positive)'),
    (sample_negative_path, 'Sin Grieta (Negative)')]
for path, label in muestras:
    # Cargar imagen original para mostrarla
    img_raw = load_img(path, target_size=(227, 227))
    img_array = img_to_array(img_raw)
    if es_resnet:
        img_procesada = preprocess_input(img_array.copy())
    else:
        img_procesada = img_array.copy() / 255.0
    img_batch = np.expand_dims(img_procesada, axis=0)
    # Extraer los mapas de características
    feature_maps = visual_model.predict(img_batch, verbose=0)
    fig, axes = plt.subplots(1, num_filtros + 1, figsize=(3 * (num_filtros + 1), 4))
    fig.suptitle(f"Análisis Interno - {label} | Capa: {conv_layer.name}", fontsize=16, fontweight='bold')
    axes[0].imshow(img_raw)
    axes[0].set_title("Original", fontsize=12)
    axes[0].axis('off')
    # Dibujar los mapas de características
    for i in range(num_filtros):
        axes[i + 1].imshow(feature_maps[0, :, :, i], cmap='viridis')
        axes[i + 1].set_title(f"Filtro {i}", fontsize=12)
        axes[i + 1].axis('off')
    plt.tight_layout()
    plt.show()
# Out:
# Extrayendo mapas de características de la capa: conv2d_1
# WARNING:tensorflow:6 out of the last 357 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7fcd38faaf20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
