# %% [markdown]
# <a href="https://colab.research.google.com/github/rogoraul/Proyecto-Concrete/blob/main/notebooks/03_Modelos_Complejos_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Concrete Crack Images for Classification
#
# ---

# %%
# Cargamos las librerias necesarias
import sys
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import zipfile
import shutil
import pandas as pd
import seaborn as sns
from PIL import Image
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from google.colab import files
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import kagglehub
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import tensorflow as tf
from tensorflow.keras.metrics import Recall, AUC, Precision
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import roc_curve, auc

# %%
# Descarga de los datos
path = kagglehub.dataset_download("aniruddhsharma/structural-defects-network-concrete-crack-images")
print("Path to dataset files:", path)

os.makedirs('./data', exist_ok=True)

datasets_dl = {'structural_defects': path}

for name, source in datasets_dl.items():
    target = os.path.join('./data', name)
    if not os.path.exists(target):
        os.symlink(source, target)
        print(f'Dataset {name} vinculado en: {target}')
    else:
        print(f'El enlace para {name} ya existe en ./data')

print('\nContenido actual de ./data:', os.listdir('./data'))
# Out:
# Using Colab cache for faster access to the 'structural-defects-network-concrete-crack-images' dataset.
# Path to dataset files: /kaggle/input/structural-defects-network-concrete-crack-images
# Dataset structural_defects vinculado en: ./data/structural_defects
#
# Contenido actual de ./data: ['structural_defects']

# %%
# Fusión de las imagenes en una sola carpeta
structural_defects_path = Path('./data/structural_defects')
merged_path = Path('./data/merged_cracks')
merged_path.mkdir(exist_ok=True)

clases = ['Positive', 'Negative']
for clase in clases:
    (merged_path / clase).mkdir(exist_ok=True)

total_stats = {'Positive': 0, 'Negative': 0}

# Structural Defects (Cracked / Non-cracked × 3)
sd_mapping = {
    'Positive': [
        structural_defects_path / 'Walls' / 'Cracked',
        structural_defects_path / 'Decks' / 'Cracked',
        structural_defects_path / 'Pavements' / 'Cracked',
    ],
    'Negative': [
        structural_defects_path / 'Walls' / 'Non-cracked',
        structural_defects_path / 'Decks' / 'Non-cracked',
        structural_defects_path / 'Pavements' / 'Non-cracked',
    ],
}

for clase, dirs in sd_mapping.items():
    for src_dir in dirs:
        tag = src_dir.parent.name[:2].lower()  # wa, de, pa
        count = 0
        for img_file in src_dir.iterdir():
            if img_file.is_file():
                dest_file = merged_path / clase / f"sd_{tag}_{img_file.name}"
                if not dest_file.exists():
                    shutil.copy2(str(img_file), str(dest_file))
                    count += 1
        total_stats[clase] += count
        print(f"Structural Defects [{src_dir.parent.name}/{src_dir.name}]: +{count}")

# Resumen final
n_pos = len(list((merged_path / 'Positive').iterdir()))
n_neg = len(list((merged_path / 'Negative').iterdir()))
print(f"Dataset fusionado en: {merged_path.resolve()}")
print(f"  Positive (Grieta):    {n_pos}")
print(f"  Negative (Sin Grieta): {n_neg}")
print(f"  Total:                 {n_pos + n_neg}")
if n_pos > 0:
    print(f"  Ratio Neg/Pos:         {n_neg/n_pos:.2f}")
else:
    print("  Ratio Neg/Pos:         N/A")
# Out:
# Structural Defects [Walls/Cracked]: +3851
# Structural Defects [Decks/Cracked]: +2025
# Structural Defects [Pavements/Cracked]: +2608
# Structural Defects [Walls/Non-cracked]: +14287
# Structural Defects [Decks/Non-cracked]: +11595
# Structural Defects [Pavements/Non-cracked]: +21726
# Dataset fusionado en: /content/data/merged_cracks
#   Positive (Grieta):    8484
#   Negative (Sin Grieta): 47608
#   Total:                 56092
#   Ratio Neg/Pos:         5.61

# %%
# Split en Train, Validation y Test
SOURCE_DIR = Path('./data/merged_cracks')
SPLIT_DIR  = Path('./data/split')

# Recopilar todos los paths y labels
all_paths  = []
all_labels = []

for img_path in sorted((SOURCE_DIR / 'Positive').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(1)
for img_path in sorted((SOURCE_DIR / 'Negative').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(0)

print(f"Total imágenes encontradas: {len(all_paths)}")
print(f"  Positivas: {sum(all_labels)}, Negativas: {len(all_labels) - sum(all_labels)}")

# Split 60% train / 20% val / 20% test
paths_tv, paths_test, y_tv, y_te = train_test_split(
    all_paths, all_labels, test_size=0.2, random_state=42, stratify=all_labels
)
paths_train, paths_val, y_tr, y_va = train_test_split(
    paths_tv, y_tv, test_size=0.25, random_state=42, stratify=y_tv
)

# Crear directorios y copiar archivos
splits = {'train': paths_train, 'val': paths_val, 'test': paths_test}

for split_name, split_paths in splits.items():
    for cls in ['Positive', 'Negative']:
        (SPLIT_DIR / split_name / cls).mkdir(parents=True, exist_ok=True)

    copied = 0
    for p in split_paths:
        cls = p.parent.name
        dest = SPLIT_DIR / split_name / cls / p.name
        if not dest.exists():
            shutil.copy2(str(p), str(dest))
            copied += 1

    total = len(list((SPLIT_DIR / split_name / 'Positive').iterdir())) + \
            len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))
    print(f"\n{split_name.upper()}: {total} imágenes ({copied} copiadas ahora)")
    print(f"  Positive: {len(list((SPLIT_DIR / split_name / 'Positive').iterdir()))}")
    print(f"  Negative: {len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))}")
# Out:
# Total imágenes encontradas: 56092
#   Positivas: 8484, Negativas: 47608
#
# TRAIN: 33654 imágenes (33654 copiadas ahora)
#   Positive: 5090
#   Negative: 28564
#
# VAL: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522
#
# TEST: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522

# %%
import importlib

os.makedirs('models', exist_ok=True)

with open('models/cnn_resnet_1.py', 'w') as f:
    f.write("""
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import ResNet50

def build_model_resnet_finetuned(input_shape=(227, 227, 3)):
  base_model = ResNet50(weights='imagenet', include_top=False, input_shape=input_shape)
  base_model.trainable = False

  # Descongelamos solo el último bloque
  base_model.trainable = True
  for layer in base_model.layers:
      if layer.name == 'conv5_block1_1_conv':
          break
      layer.trainable = False

  model = models.Sequential([
      base_model,
      layers.GlobalAveragePooling2D(),
      layers.Dense(128, activation='relu'),
      layers.Dropout(0.3),
      layers.Dense(1, activation='sigmoid')
  ])
  return model
""")

sys.path.append('./models')

import cnn_resnet_1
importlib.reload(cnn_resnet_1)

from cnn_resnet_1 import build_model_resnet_finetuned

modelo_complejo = build_model_resnet_finetuned()
modelo_complejo.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 8, 8, 2048)     │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,850,113 (90.98 MB)
#  Trainable params: 15,238,401 (58.13 MB)
#  Non-trainable params: 8,611,712 (32.85 MB)

# %%
# Carga de datos para entrenamiento
IMG_SIZE = (227, 227)
BATCH_SIZE = 32

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'train'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=True, seed=42
)

val_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'val'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)

test_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'test'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)
# Out:
# Found 33654 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import Adam
# Compilacion y entrenamiento
model = build_model_resnet_finetuned(input_shape=(227, 227, 3))

# Compilamos usando un Learning Rate bajo
optimizer = Adam(learning_rate=0.00001)
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy', Recall(name='recall'), Precision(name='precision'), AUC(name='auc')]
)

checkpoint = ModelCheckpoint('best_resnet_model_1.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.0000001, verbose=1, mode='max')
early_stopping = EarlyStopping(monitor='val_accuracy', patience=40, restore_best_weights=True, mode='max')

n_pos = 8484   # Positive (Clase 1)
n_neg = 47608  # Negative (Clase 0)
total = n_pos + n_neg

# Fórmula para balancear pesos
weight_for_0 = (1 / n_neg) * (total / 2.0)
weight_for_1 = (1 / n_pos) * (total / 2.0)

class_weight = {
    0: weight_for_0,
    1: weight_for_1
}

print(f"Peso para Negative (0): {weight_for_0:.2f}")
print(f"Peso para Positive (1): {weight_for_1:.2f}")

history = model.fit(
    train_gen,
    validation_data=val_gen,
    class_weight=class_weight,
    epochs=120,
    callbacks=[checkpoint, reduce_lr, early_stopping]
)

# Cargar el modelo en su mejor punto
model.load_weights('best_resnet_model_1.keras')
# Out:
# Peso para Negative (0): 0.59
# Peso para Positive (1): 3.31
# Epoch 1/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.7786 - auc: 0.8185 - loss: 0.5006 - precision: 0.3867 - recall: 0.6945
# Epoch 1: val_accuracy improved from None to 0.88216, saving model to best_resnet_model_1.keras
#
# Epoch 1: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 219s 185ms/step - accuracy: 0.8337 - auc: 0.8749 - loss: 0.4292 - precision: 0.4685 - recall: 0.7385 - val_accuracy: 0.8822 - val_auc: 0.9120 - val_loss: 0.3373 - val_precision: 0.5839 - val_recall: 0.7690 - learning_rate: 1.0000e-05
# Epoch 2/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9007 - auc: 0.9457 - loss: 0.2957 - precision: 0.6326 - recall: 0.8281
# Epoch 2: val_accuracy improved from 0.88216 to 0.89019, saving model to best_resnet_model_1.keras
#
# Epoch 2: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9026 - auc: 0.9465 - loss: 0.2915 - precision: 0.6364 - recall: 0.8305 - val_accuracy: 0.8902 - val_auc: 0.9205 - val_loss: 0.2978 - val_precision: 0.6075 - val_recall: 0.7743 - learning_rate: 1.0000e-05
# Epoch 3/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9428 - auc: 0.9803 - loss: 0.1872 - precision: 0.7608 - recall: 0.9028
# Epoch 3: val_accuracy improved from 0.89019 to 0.90106, saving model to best_resnet_model_1.keras
#
# Epoch 3: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9401 - auc: 0.9796 - loss: 0.1873 - precision: 0.7529 - recall: 0.8992 - val_accuracy: 0.9011 - val_auc: 0.9166 - val_loss: 0.2744 - val_precision: 0.6501 - val_recall: 0.7490 - learning_rate: 1.0000e-05
# Epoch 4/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9721 - auc: 0.9950 - loss: 0.1004 - precision: 0.8659 - recall: 0.9622
# Epoch 4: val_accuracy did not improve from 0.90106
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9705 - auc: 0.9945 - loss: 0.0991 - precision: 0.8612 - recall: 0.9597 - val_accuracy: 0.8992 - val_auc: 0.9106 - val_loss: 0.2931 - val_precision: 0.6466 - val_recall: 0.7354 - learning_rate: 1.0000e-05
# Epoch 5/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9855 - auc: 0.9988 - loss: 0.0494 - precision: 0.9263 - recall: 0.9818
# Epoch 5: val_accuracy improved from 0.90106 to 0.91693, saving model to best_resnet_model_1.keras
#
# Epoch 5: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9856 - auc: 0.9986 - loss: 0.0493 - precision: 0.9271 - recall: 0.9817 - val_accuracy: 0.9169 - val_auc: 0.9036 - val_loss: 0.2955 - val_precision: 0.7422 - val_recall: 0.6906 - learning_rate: 1.0000e-05
# Epoch 6/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9925 - auc: 0.9996 - loss: 0.0275 - precision: 0.9603 - recall: 0.9922
# Epoch 6: val_accuracy did not improve from 0.91693
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9924 - auc: 0.9996 - loss: 0.0272 - precision: 0.9597 - recall: 0.9912 - val_accuracy: 0.9131 - val_auc: 0.8915 - val_loss: 0.3421 - val_precision: 0.7251 - val_recall: 0.6853 - learning_rate: 1.0000e-05
# Epoch 7/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9942 - auc: 0.9998 - loss: 0.0198 - precision: 0.9688 - recall: 0.9937
# Epoch 7: val_accuracy did not improve from 0.91693
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9931 - auc: 0.9997 - loss: 0.0222 - precision: 0.9634 - recall: 0.9923 - val_accuracy: 0.9104 - val_auc: 0.8918 - val_loss: 0.3670 - val_precision: 0.7102 - val_recall: 0.6889 - learning_rate: 1.0000e-05
# Epoch 8/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9957 - auc: 0.9999 - loss: 0.0144 - precision: 0.9754 - recall: 0.9969
# Epoch 8: val_accuracy improved from 0.91693 to 0.92022, saving model to best_resnet_model_1.keras
#
# Epoch 8: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 0.9953 - auc: 0.9998 - loss: 0.0155 - precision: 0.9739 - recall: 0.9955 - val_accuracy: 0.9202 - val_auc: 0.8799 - val_loss: 0.3878 - val_precision: 0.7732 - val_recall: 0.6688 - learning_rate: 1.0000e-05
# Epoch 9/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9965 - auc: 0.9999 - loss: 0.0133 - precision: 0.9818 - recall: 0.9955
# Epoch 9: val_accuracy did not improve from 0.92022
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 185s 176ms/step - accuracy: 0.9958 - auc: 0.9998 - loss: 0.0155 - precision: 0.9782 - recall: 0.9941 - val_accuracy: 0.9188 - val_auc: 0.8828 - val_loss: 0.3821 - val_precision: 0.7575 - val_recall: 0.6812 - learning_rate: 1.0000e-05
# Epoch 10/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9950 - auc: 0.9999 - loss: 0.0147 - precision: 0.9724 - recall: 0.9950
# Epoch 10: val_accuracy did not improve from 0.92022
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9948 - auc: 0.9998 - loss: 0.0162 - precision: 0.9714 - recall: 0.9947 - val_accuracy: 0.9177 - val_auc: 0.8785 - val_loss: 0.3935 - val_precision: 0.7573 - val_recall: 0.6712 - learning_rate: 1.0000e-05
# Epoch 11/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9957 - auc: 0.9998 - loss: 0.0138 - precision: 0.9767 - recall: 0.9957
# Epoch 11: val_accuracy improved from 0.92022 to 0.92165, saving model to best_resnet_model_1.keras
#
# Epoch 11: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 189s 180ms/step - accuracy: 0.9961 - auc: 0.9998 - loss: 0.0130 - precision: 0.9784 - recall: 0.9961 - val_accuracy: 0.9217 - val_auc: 0.8821 - val_loss: 0.4078 - val_precision: 0.7712 - val_recall: 0.6853 - learning_rate: 1.0000e-05
# Epoch 12/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9979 - auc: 1.0000 - loss: 0.0075 - precision: 0.9888 - recall: 0.9971
# Epoch 12: val_accuracy did not improve from 0.92165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9971 - auc: 1.0000 - loss: 0.0091 - precision: 0.9852 - recall: 0.9961 - val_accuracy: 0.9160 - val_auc: 0.8771 - val_loss: 0.4395 - val_precision: 0.7394 - val_recall: 0.6871 - learning_rate: 1.0000e-05
# Epoch 13/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9949 - auc: 0.9998 - loss: 0.0147 - precision: 0.9714 - recall: 0.9952
# Epoch 13: val_accuracy did not improve from 0.92165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9958 - auc: 0.9998 - loss: 0.0119 - precision: 0.9769 - recall: 0.9961 - val_accuracy: 0.9200 - val_auc: 0.8800 - val_loss: 0.4120 - val_precision: 0.7630 - val_recall: 0.6830 - learning_rate: 1.0000e-05
# Epoch 14/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9968 - auc: 0.9998 - loss: 0.0113 - precision: 0.9839 - recall: 0.9956
# Epoch 14: val_accuracy did not improve from 0.92165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9968 - auc: 0.9998 - loss: 0.0108 - precision: 0.9831 - recall: 0.9959 - val_accuracy: 0.9132 - val_auc: 0.8831 - val_loss: 0.4580 - val_precision: 0.7128 - val_recall: 0.7136 - learning_rate: 1.0000e-05
# Epoch 15/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9977 - auc: 0.9999 - loss: 0.0082 - precision: 0.9868 - recall: 0.9983
# Epoch 15: val_accuracy did not improve from 0.92165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9971 - auc: 0.9999 - loss: 0.0096 - precision: 0.9839 - recall: 0.9969 - val_accuracy: 0.9151 - val_auc: 0.8753 - val_loss: 0.4427 - val_precision: 0.7372 - val_recall: 0.6812 - learning_rate: 1.0000e-05
# Epoch 16/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9982 - auc: 0.9999 - loss: 0.0076 - precision: 0.9899 - recall: 0.9980
# Epoch 16: val_accuracy did not improve from 0.92165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9975 - auc: 0.9998 - loss: 0.0097 - precision: 0.9860 - recall: 0.9974 - val_accuracy: 0.9069 - val_auc: 0.8901 - val_loss: 0.4627 - val_precision: 0.6783 - val_recall: 0.7319 - learning_rate: 1.0000e-05
# Epoch 17/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9966 - auc: 0.9999 - loss: 0.0105 - precision: 0.9826 - recall: 0.9949
# Epoch 17: val_accuracy did not improve from 0.92165
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9964 - auc: 0.9999 - loss: 0.0115 - precision: 0.9808 - recall: 0.9955 - val_accuracy: 0.9183 - val_auc: 0.8886 - val_loss: 0.4197 - val_precision: 0.7453 - val_recall: 0.6983 - learning_rate: 1.0000e-05
# Epoch 18/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9970 - auc: 0.9999 - loss: 0.0084 - precision: 0.9840 - recall: 0.9963
# Epoch 18: val_accuracy improved from 0.92165 to 0.92174, saving model to best_resnet_model_1.keras
#
# Epoch 18: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9970 - auc: 0.9999 - loss: 0.0091 - precision: 0.9845 - recall: 0.9959 - val_accuracy: 0.9217 - val_auc: 0.8737 - val_loss: 0.4243 - val_precision: 0.7795 - val_recall: 0.6730 - learning_rate: 1.0000e-05
# Epoch 19/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9983 - auc: 1.0000 - loss: 0.0056 - precision: 0.9902 - recall: 0.9983
# Epoch 19: val_accuracy did not improve from 0.92174
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9982 - auc: 1.0000 - loss: 0.0060 - precision: 0.9903 - recall: 0.9980 - val_accuracy: 0.9198 - val_auc: 0.8738 - val_loss: 0.4450 - val_precision: 0.7709 - val_recall: 0.6682 - learning_rate: 1.0000e-05
# Epoch 20/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9978 - auc: 0.9999 - loss: 0.0062 - precision: 0.9871 - recall: 0.9983
# Epoch 20: val_accuracy did not improve from 0.92174
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9979 - auc: 0.9998 - loss: 0.0073 - precision: 0.9883 - recall: 0.9976 - val_accuracy: 0.9180 - val_auc: 0.8771 - val_loss: 0.4693 - val_precision: 0.7473 - val_recall: 0.6918 - learning_rate: 1.0000e-05
# Epoch 21/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9984 - auc: 1.0000 - loss: 0.0048 - precision: 0.9907 - recall: 0.9986
# Epoch 21: val_accuracy did not improve from 0.92174
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 185s 176ms/step - accuracy: 0.9986 - auc: 1.0000 - loss: 0.0045 - precision: 0.9922 - recall: 0.9986 - val_accuracy: 0.9187 - val_auc: 0.8678 - val_loss: 0.5005 - val_precision: 0.7567 - val_recall: 0.6818 - learning_rate: 1.0000e-05
# Epoch 22/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9989 - auc: 1.0000 - loss: 0.0033 - precision: 0.9935 - recall: 0.9991
# Epoch 22: val_accuracy did not improve from 0.92174
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 185s 176ms/step - accuracy: 0.9990 - auc: 1.0000 - loss: 0.0034 - precision: 0.9941 - recall: 0.9990 - val_accuracy: 0.9208 - val_auc: 0.8712 - val_loss: 0.4967 - val_precision: 0.7635 - val_recall: 0.6906 - learning_rate: 5.0000e-06
# Epoch 23/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0017 - precision: 0.9984 - recall: 0.9995
# Epoch 23: val_accuracy did not improve from 0.92174
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9993 - auc: 1.0000 - loss: 0.0029 - precision: 0.9967 - recall: 0.9986 - val_accuracy: 0.9213 - val_auc: 0.8715 - val_loss: 0.4910 - val_precision: 0.7699 - val_recall: 0.6841 - learning_rate: 5.0000e-06
# Epoch 24/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0017 - precision: 0.9978 - recall: 0.9993
# Epoch 24: val_accuracy did not improve from 0.92174
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 185s 176ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0015 - precision: 0.9980 - recall: 0.9998 - val_accuracy: 0.9187 - val_auc: 0.8770 - val_loss: 0.5021 - val_precision: 0.7492 - val_recall: 0.6953 - learning_rate: 5.0000e-06
# Epoch 25/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 8.4376e-04 - precision: 0.9983 - recall: 1.0000
# Epoch 25: val_accuracy improved from 0.92174 to 0.92361, saving model to best_resnet_model_1.keras
#
# Epoch 25: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 8.9427e-04 - precision: 0.9984 - recall: 1.0000 - val_accuracy: 0.9236 - val_auc: 0.8708 - val_loss: 0.5016 - val_precision: 0.7834 - val_recall: 0.6841 - learning_rate: 5.0000e-06
# Epoch 26/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 9.9087e-04 - precision: 0.9990 - recall: 0.9998
# Epoch 26: val_accuracy improved from 0.92361 to 0.92539, saving model to best_resnet_model_1.keras
#
# Epoch 26: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0012 - precision: 0.9982 - recall: 0.9996 - val_accuracy: 0.9254 - val_auc: 0.8651 - val_loss: 0.5217 - val_precision: 0.8063 - val_recall: 0.6671 - learning_rate: 5.0000e-06
# Epoch 27/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9995 - auc: 1.0000 - loss: 0.0018 - precision: 0.9973 - recall: 0.9993
# Epoch 27: val_accuracy did not improve from 0.92539
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 0.0021 - precision: 0.9967 - recall: 0.9994 - val_accuracy: 0.9189 - val_auc: 0.8774 - val_loss: 0.5107 - val_precision: 0.7498 - val_recall: 0.6959 - learning_rate: 5.0000e-06
# Epoch 28/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 0.0019 - precision: 0.9966 - recall: 0.9997
# Epoch 28: val_accuracy improved from 0.92539 to 0.92602, saving model to best_resnet_model_1.keras
#
# Epoch 28: finished saving model to best_resnet_model_1.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 0.0018 - precision: 0.9967 - recall: 0.9996 - val_accuracy: 0.9260 - val_auc: 0.8632 - val_loss: 0.5207 - val_precision: 0.8017 - val_recall: 0.6788 - learning_rate: 5.0000e-06
# Epoch 29/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 0.9999 - loss: 0.0015 - precision: 0.9984 - recall: 0.9999
# Epoch 29: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9996 - auc: 0.9999 - loss: 0.0024 - precision: 0.9976 - recall: 0.9996 - val_accuracy: 0.9225 - val_auc: 0.8748 - val_loss: 0.5206 - val_precision: 0.7640 - val_recall: 0.7060 - learning_rate: 5.0000e-06
# Epoch 30/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 0.0011 - precision: 0.9987 - recall: 0.9997
# Epoch 30: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0013 - precision: 0.9978 - recall: 0.9998 - val_accuracy: 0.9243 - val_auc: 0.8637 - val_loss: 0.5309 - val_precision: 0.7877 - val_recall: 0.6841 - learning_rate: 5.0000e-06
# Epoch 31/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9990 - auc: 1.0000 - loss: 0.0050 - precision: 0.9955 - recall: 0.9981
# Epoch 31: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 185s 176ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 0.0028 - precision: 0.9969 - recall: 0.9990 - val_accuracy: 0.9221 - val_auc: 0.8712 - val_loss: 0.5300 - val_precision: 0.7674 - val_recall: 0.6959 - learning_rate: 5.0000e-06
# Epoch 32/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0015 - precision: 0.9986 - recall: 0.9998
# Epoch 32: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 190s 181ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0018 - precision: 0.9984 - recall: 0.9996 - val_accuracy: 0.9240 - val_auc: 0.8649 - val_loss: 0.5240 - val_precision: 0.7855 - val_recall: 0.6841 - learning_rate: 5.0000e-06
# Epoch 33/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 9.3214e-04 - precision: 0.9983 - recall: 0.9999
# Epoch 33: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0011 - precision: 0.9984 - recall: 0.9998 - val_accuracy: 0.9217 - val_auc: 0.8727 - val_loss: 0.5261 - val_precision: 0.7639 - val_recall: 0.6977 - learning_rate: 5.0000e-06
# Epoch 34/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 9.7738e-04 - precision: 0.9977 - recall: 0.9995
# Epoch 34: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9995 - auc: 1.0000 - loss: 0.0013 - precision: 0.9976 - recall: 0.9992 - val_accuracy: 0.9258 - val_auc: 0.8658 - val_loss: 0.5293 - val_precision: 0.8021 - val_recall: 0.6759 - learning_rate: 5.0000e-06
# Epoch 35/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 0.0022 - precision: 0.9970 - recall: 0.9989
# Epoch 35: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9994 - auc: 1.0000 - loss: 0.0020 - precision: 0.9971 - recall: 0.9990 - val_accuracy: 0.9223 - val_auc: 0.8691 - val_loss: 0.5324 - val_precision: 0.7673 - val_recall: 0.6977 - learning_rate: 5.0000e-06
# Epoch 36/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 7.1463e-04 - precision: 0.9984 - recall: 0.9999
# Epoch 36: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 8.2577e-04 - precision: 0.9986 - recall: 0.9998 - val_accuracy: 0.9242 - val_auc: 0.8684 - val_loss: 0.5272 - val_precision: 0.7821 - val_recall: 0.6918 - learning_rate: 5.0000e-06
# Epoch 37/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 0.0010 - precision: 0.9984 - recall: 0.9996
# Epoch 37: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0015 - precision: 0.9976 - recall: 0.9994 - val_accuracy: 0.9212 - val_auc: 0.8732 - val_loss: 0.5436 - val_precision: 0.7584 - val_recall: 0.7030 - learning_rate: 5.0000e-06
# Epoch 38/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0018 - precision: 0.9981 - recall: 0.9993
# Epoch 38: val_accuracy did not improve from 0.92602
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9996 - auc: 1.0000 - loss: 0.0018 - precision: 0.9980 - recall: 0.9992 - val_accuracy: 0.9244 - val_auc: 0.8645 - val_loss: 0.5420 - val_precision: 0.7862 - val_recall: 0.6871 - learning_rate: 5.0000e-06
# Epoch 39/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 7.9325e-04 - precision: 0.9992 - recall: 1.0000
# Epoch 39: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 9.5603e-04 - precision: 0.9988 - recall: 1.0000 - val_accuracy: 0.9229 - val_auc: 0.8688 - val_loss: 0.5368 - val_precision: 0.7751 - val_recall: 0.6906 - learning_rate: 2.5000e-06
# Epoch 40/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.0295e-04 - precision: 0.9992 - recall: 1.0000
# Epoch 40: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 6.1007e-04 - precision: 0.9990 - recall: 1.0000 - val_accuracy: 0.9218 - val_auc: 0.8694 - val_loss: 0.5315 - val_precision: 0.7642 - val_recall: 0.6989 - learning_rate: 2.5000e-06
# Epoch 41/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.5944e-04 - precision: 0.9997 - recall: 0.9997
# Epoch 41: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.4398e-04 - precision: 0.9996 - recall: 0.9998 - val_accuracy: 0.9233 - val_auc: 0.8666 - val_loss: 0.5476 - val_precision: 0.7811 - val_recall: 0.6853 - learning_rate: 2.5000e-06
# Epoch 42/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.3024e-04 - precision: 0.9994 - recall: 1.0000
# Epoch 42: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 4.0902e-04 - precision: 0.9996 - recall: 1.0000 - val_accuracy: 0.9257 - val_auc: 0.8647 - val_loss: 0.5590 - val_precision: 0.7937 - val_recall: 0.6871 - learning_rate: 2.5000e-06
# Epoch 43/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.4152e-04 - precision: 0.9997 - recall: 1.0000
# Epoch 43: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 3.4518e-04 - precision: 0.9996 - recall: 1.0000 - val_accuracy: 0.9250 - val_auc: 0.8638 - val_loss: 0.5459 - val_precision: 0.7892 - val_recall: 0.6883 - learning_rate: 2.5000e-06
# Epoch 44/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.1749e-04 - precision: 0.9994 - recall: 0.9996
# Epoch 44: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 6.2206e-04 - precision: 0.9992 - recall: 0.9996 - val_accuracy: 0.9246 - val_auc: 0.8629 - val_loss: 0.5578 - val_precision: 0.7904 - val_recall: 0.6824 - learning_rate: 2.5000e-06
# Epoch 45/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 3.4796e-04 - precision: 0.9997 - recall: 1.0000
# Epoch 45: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 4.5363e-04 - precision: 0.9996 - recall: 0.9998 - val_accuracy: 0.9255 - val_auc: 0.8594 - val_loss: 0.5781 - val_precision: 0.7915 - val_recall: 0.6889 - learning_rate: 2.5000e-06
# Epoch 46/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.5464e-04 - precision: 0.9997 - recall: 0.9999
# Epoch 46: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.5376e-04 - precision: 0.9994 - recall: 0.9996 - val_accuracy: 0.9257 - val_auc: 0.8613 - val_loss: 0.5675 - val_precision: 0.7933 - val_recall: 0.6877 - learning_rate: 2.5000e-06
# Epoch 47/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9997 - auc: 1.0000 - loss: 8.9763e-04 - precision: 0.9982 - recall: 0.9996
# Epoch 47: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9998 - auc: 1.0000 - loss: 6.2048e-04 - precision: 0.9988 - recall: 0.9998 - val_accuracy: 0.9241 - val_auc: 0.8633 - val_loss: 0.5769 - val_precision: 0.7831 - val_recall: 0.6895 - learning_rate: 2.5000e-06
# Epoch 48/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 4.9464e-04 - precision: 0.9995 - recall: 0.9998
# Epoch 48: val_accuracy did not improve from 0.92602
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.2085e-04 - precision: 0.9994 - recall: 0.9998 - val_accuracy: 0.9220 - val_auc: 0.8655 - val_loss: 0.5701 - val_precision: 0.7683 - val_recall: 0.6936 - learning_rate: 2.5000e-06
# Epoch 49/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.5089e-04 - precision: 0.9999 - recall: 1.0000
# Epoch 49: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 176ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 2.7390e-04 - precision: 0.9996 - recall: 1.0000 - val_accuracy: 0.9252 - val_auc: 0.8661 - val_loss: 0.5697 - val_precision: 0.7887 - val_recall: 0.6906 - learning_rate: 1.2500e-06
# Epoch 50/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.5903e-04 - precision: 0.9999 - recall: 1.0000
# Epoch 50: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.8089e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9248 - val_auc: 0.8632 - val_loss: 0.5697 - val_precision: 0.7903 - val_recall: 0.6841 - learning_rate: 1.2500e-06
# Epoch 51/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.4322e-04 - precision: 0.9999 - recall: 0.9999
# Epoch 51: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 4.9633e-04 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9236 - val_auc: 0.8641 - val_loss: 0.5648 - val_precision: 0.7830 - val_recall: 0.6847 - learning_rate: 1.2500e-06
# Epoch 52/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 3.0394e-04 - precision: 0.9998 - recall: 1.0000
# Epoch 52: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 5.0611e-04 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9255 - val_auc: 0.8591 - val_loss: 0.5773 - val_precision: 0.8004 - val_recall: 0.6759 - learning_rate: 1.2500e-06
# Epoch 53/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.8635e-04 - precision: 0.9998 - recall: 1.0000
# Epoch 53: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 2.1413e-04 - precision: 0.9996 - recall: 1.0000 - val_accuracy: 0.9220 - val_auc: 0.8626 - val_loss: 0.5787 - val_precision: 0.7693 - val_recall: 0.6918 - learning_rate: 1.2500e-06
# Epoch 54/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.6967e-04 - precision: 0.9999 - recall: 1.0000
# Epoch 54: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 1.9571e-04 - precision: 0.9996 - recall: 1.0000 - val_accuracy: 0.9223 - val_auc: 0.8622 - val_loss: 0.5761 - val_precision: 0.7748 - val_recall: 0.6853 - learning_rate: 1.2500e-06
# Epoch 55/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.0512e-04 - precision: 0.9998 - recall: 0.9999
# Epoch 55: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 2.6220e-04 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9241 - val_auc: 0.8605 - val_loss: 0.5745 - val_precision: 0.7868 - val_recall: 0.6830 - learning_rate: 1.2500e-06
# Epoch 56/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 3.0733e-04 - precision: 0.9995 - recall: 1.0000
# Epoch 56: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 2.5062e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9246 - val_auc: 0.8594 - val_loss: 0.5718 - val_precision: 0.7937 - val_recall: 0.6777 - learning_rate: 1.2500e-06
# Epoch 57/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 9.1101e-04 - precision: 1.0000 - recall: 0.9992
# Epoch 57: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 3.9564e-04 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9239 - val_auc: 0.8611 - val_loss: 0.5796 - val_precision: 0.7889 - val_recall: 0.6783 - learning_rate: 1.2500e-06
# Epoch 58/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.7262e-04 - precision: 0.9998 - recall: 1.0000
# Epoch 58: val_accuracy did not improve from 0.92602
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 2.6524e-04 - precision: 0.9996 - recall: 1.0000 - val_accuracy: 0.9225 - val_auc: 0.8657 - val_loss: 0.5767 - val_precision: 0.7738 - val_recall: 0.6895 - learning_rate: 1.2500e-06
# Epoch 59/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 7.2906e-05 - precision: 1.0000 - recall: 1.0000
# Epoch 59: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.3765e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9241 - val_auc: 0.8621 - val_loss: 0.5802 - val_precision: 0.7866 - val_recall: 0.6841 - learning_rate: 6.2500e-07
# Epoch 60/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.4362e-04 - precision: 0.9998 - recall: 1.0000
# Epoch 60: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.4812e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9249 - val_auc: 0.8626 - val_loss: 0.5823 - val_precision: 0.7890 - val_recall: 0.6877 - learning_rate: 6.2500e-07
# Epoch 61/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 1.3714e-04 - precision: 0.9997 - recall: 1.0000
# Epoch 61: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 2.3551e-04 - precision: 0.9998 - recall: 0.9998 - val_accuracy: 0.9234 - val_auc: 0.8623 - val_loss: 0.5854 - val_precision: 0.7801 - val_recall: 0.6877 - learning_rate: 6.2500e-07
# Epoch 62/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.3631e-04 - precision: 0.9997 - recall: 1.0000
# Epoch 62: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.5910e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9229 - val_auc: 0.8611 - val_loss: 0.5883 - val_precision: 0.7788 - val_recall: 0.6847 - learning_rate: 6.2500e-07
# Epoch 63/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.7690e-04 - precision: 0.9998 - recall: 1.0000
# Epoch 63: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.7337e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9245 - val_auc: 0.8594 - val_loss: 0.5875 - val_precision: 0.7919 - val_recall: 0.6794 - learning_rate: 6.2500e-07
# Epoch 64/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 9.3011e-05 - precision: 1.0000 - recall: 1.0000
# Epoch 64: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 186s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.4340e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9240 - val_auc: 0.8595 - val_loss: 0.5940 - val_precision: 0.7879 - val_recall: 0.6806 - learning_rate: 6.2500e-07
# Epoch 65/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 2.4390e-04 - precision: 0.9994 - recall: 1.0000
# Epoch 65: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.0859e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9241 - val_auc: 0.8602 - val_loss: 0.5884 - val_precision: 0.7881 - val_recall: 0.6818 - learning_rate: 6.2500e-07
# Epoch 66/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 6.6442e-05 - precision: 0.9999 - recall: 1.0000
# Epoch 66: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 178ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 8.7375e-05 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9234 - val_auc: 0.8587 - val_loss: 0.6043 - val_precision: 0.7850 - val_recall: 0.6800 - learning_rate: 6.2500e-07
# Epoch 67/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.0334e-04 - precision: 0.9997 - recall: 1.0000
# Epoch 67: val_accuracy did not improve from 0.92602
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.2857e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9250 - val_auc: 0.8575 - val_loss: 0.6022 - val_precision: 0.7964 - val_recall: 0.6777 - learning_rate: 6.2500e-07
# Epoch 68/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9999 - auc: 1.0000 - loss: 1.6440e-04 - precision: 0.9996 - recall: 1.0000
# Epoch 68: val_accuracy did not improve from 0.92602
#
# Epoch 68: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 187s 177ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 1.5870e-04 - precision: 0.9998 - recall: 1.0000 - val_accuracy: 0.9249 - val_auc: 0.8585 - val_loss: 0.6055 - val_precision: 0.7961 - val_recall: 0.6765 - learning_rate: 6.2500e-07

# %%
# Buscamos el índice de la época con el mayor accuracy
best_epoch_idx = np.argmax(history.history['val_accuracy'])

# 1. CURVAS DE CONVERGENCIA DEL ENTRENAMIENTO
plt.figure(figsize=(14, 10))

# Gráfica de Loss
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Función de Coste (Binary Crossentropy)')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

# Gráfica de Accuracy
plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Accuracy')
plt.legend()

# Gráfica de AUC
plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Área bajo la curva (AUC) por época')
plt.xlabel('Época')
plt.ylabel('AUC')
plt.legend()

# Gráfica de Recall
plt.subplot(2, 2, 4)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Sensibilidad (Recall)')
plt.xlabel('Época')
plt.ylabel('Recall')
plt.legend()

plt.tight_layout()
plt.show()

# 2. PREDICCIONES Y EVALUACIÓN
print(f"\nEvaluando el mejor modelo guardado (Época {best_epoch_idx + 1})...")
eval_results = model.evaluate(test_gen, verbose=1)

print(f"\nMétricas de Test -> Loss: {eval_results[0]:.4f} | Accuracy: {eval_results[1]:.4f} | Recall: {eval_results[2]:.4f} | Precision: {eval_results[3]:.4f} | AUC: {eval_results[4]:.4f}")

predictions = model.predict(test_gen)
y_pred = (predictions > 0.5).astype(int).flatten()
y_true = test_gen.classes

# 3. CURVA ROC
plt.figure(figsize=(14, 6))
fpr, tpr, thresholds = roc_curve(y_true, predictions)
roc_auc = auc(fpr, tpr)
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC del Modelo')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# 4. MATRIZ DE CONFUSIÓN Y REPORTE
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_gen.class_indices.keys(),
            yticklabels=test_gen.class_indices.keys())
plt.title('Matriz de Confusión - ResNet50')
plt.ylabel('Real (Verdad)')
plt.xlabel('Predicción del Modelo')
plt.show()

print("\nReporte de Clasificación:")
print(classification_report(y_true, y_pred, target_names=test_gen.class_indices.keys()))
# Out:
# Evaluando el mejor modelo guardado (Época 28)...
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 36s 102ms/step - accuracy: 0.9283 - auc: 0.8749 - loss: 0.4785 - precision: 0.8210 - recall: 0.6730
#
# Métricas de Test -> Loss: 0.4785 | Accuracy: 0.9283 | Recall: 0.6730 | Precision: 0.8210 | AUC: 0.8749
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 37s 104ms/step
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#     Negative       0.94      0.97      0.96      9522
#     Positive       0.82      0.67      0.74      1697
#
#     accuracy                           0.93     11219
#    macro avg       0.88      0.82      0.85     11219
# weighted avg       0.92      0.93      0.93     11219

# %%
positive_dir = SPLIT_DIR / 'test' / 'Positive'
negative_dir = SPLIT_DIR / 'test' / 'Negative'
sample_positive_path = sorted(positive_dir.glob('*.jpg'))[5]
sample_negative_path = sorted(negative_dir.glob('*.jpg'))[5]

# Buscamos la primera capa convolucional
capa_base = model.layers[0]
if isinstance(capa_base, tf.keras.Model):
    conv_layer = [layer for layer in capa_base.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=capa_base.inputs, outputs=conv_layer.output)
    es_resnet = True
else:
    conv_layer = [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=model.inputs, outputs=conv_layer.output)
    es_resnet = False

print(f"Extrayendo mapas de características de la capa: {conv_layer.name}")
num_filtros = min(6, conv_layer.filters)
muestras = [
    (sample_positive_path, 'Grieta (Positive)'),
    (sample_negative_path, 'Sin Grieta (Negative)')]
for path, label in muestras:
    # Cargar imagen original para mostrarla
    img_raw = load_img(path, target_size=(227, 227))
    img_array = img_to_array(img_raw)
    if es_resnet:
        img_procesada = preprocess_input(img_array.copy())
    else:
        img_procesada = img_array.copy() / 255.0
    img_batch = np.expand_dims(img_procesada, axis=0)
    # Extraer los mapas de características
    feature_maps = visual_model.predict(img_batch, verbose=0)
    fig, axes = plt.subplots(1, num_filtros + 1, figsize=(3 * (num_filtros + 1), 4))
    fig.suptitle(f"Análisis Interno - {label} | Capa: {conv_layer.name}", fontsize=16, fontweight='bold')
    axes[0].imshow(img_raw)
    axes[0].set_title("Original", fontsize=12)
    axes[0].axis('off')
    # Dibujar los mapas de características
    for i in range(num_filtros):
        axes[i + 1].imshow(feature_maps[0, :, :, i], cmap='viridis')
        axes[i + 1].set_title(f"Filtro {i}", fontsize=12)
        axes[i + 1].axis('off')
    plt.tight_layout()
    plt.show()
# Out:
# Extrayendo mapas de características de la capa: conv1_conv
