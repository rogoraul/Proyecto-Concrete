# %% [markdown]
# <a href="https://colab.research.google.com/github/rogoraul/Proyecto-Concrete/blob/main/notebooks/03_Modelos_Simple_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Concrete Crack Images for Classification
#
# ---

# %%
# Cargamos las librerias necesarias
import sys
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import zipfile
import shutil
import pandas as pd
import seaborn as sns
from PIL import Image
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from google.colab import files
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, CSVLogger
import kagglehub
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import img_to_array, load_img
import tensorflow as tf
from tensorflow.keras.metrics import Recall, AUC, Precision
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import roc_curve, auc

# %%
# Descarga de los datos
path = kagglehub.dataset_download("aniruddhsharma/structural-defects-network-concrete-crack-images")
print("Path to dataset files:", path)

os.makedirs('./data', exist_ok=True)

datasets_dl = {'structural_defects': path}

for name, source in datasets_dl.items():
    target = os.path.join('./data', name)
    if not os.path.exists(target):
        os.symlink(source, target)
        print(f'Dataset {name} vinculado en: {target}')
    else:
        print(f'El enlace para {name} ya existe en ./data')

print('\nContenido actual de ./data:', os.listdir('./data'))
# Out:
# Using Colab cache for faster access to the 'structural-defects-network-concrete-crack-images' dataset.
# Path to dataset files: /kaggle/input/structural-defects-network-concrete-crack-images
# Dataset structural_defects vinculado en: ./data/structural_defects
#
# Contenido actual de ./data: ['structural_defects']

# %%
# Fusión de las imagenes en una sola carpeta
structural_defects_path = Path('./data/structural_defects')
merged_path = Path('./data/merged_cracks')
merged_path.mkdir(exist_ok=True)

clases = ['Positive', 'Negative']
for clase in clases:
    (merged_path / clase).mkdir(exist_ok=True)

total_stats = {'Positive': 0, 'Negative': 0}

# Structural Defects (Cracked / Non-cracked × 3)
sd_mapping = {
    'Positive': [
        structural_defects_path / 'Walls' / 'Cracked',
        structural_defects_path / 'Decks' / 'Cracked',
        structural_defects_path / 'Pavements' / 'Cracked',
    ],
    'Negative': [
        structural_defects_path / 'Walls' / 'Non-cracked',
        structural_defects_path / 'Decks' / 'Non-cracked',
        structural_defects_path / 'Pavements' / 'Non-cracked',
    ],
}

for clase, dirs in sd_mapping.items():
    for src_dir in dirs:
        tag = src_dir.parent.name[:2].lower()  # wa, de, pa
        count = 0
        for img_file in src_dir.iterdir():
            if img_file.is_file():
                dest_file = merged_path / clase / f"sd_{tag}_{img_file.name}"
                if not dest_file.exists():
                    shutil.copy2(str(img_file), str(dest_file))
                    count += 1
        total_stats[clase] += count
        print(f"Structural Defects [{src_dir.parent.name}/{src_dir.name}]: +{count}")

# Resumen final
n_pos = len(list((merged_path / 'Positive').iterdir()))
n_neg = len(list((merged_path / 'Negative').iterdir()))
print(f"Dataset fusionado en: {merged_path.resolve()}")
print(f"  Positive (Grieta):    {n_pos}")
print(f"  Negative (Sin Grieta): {n_neg}")
print(f"  Total:                 {n_pos + n_neg}")
if n_pos > 0:
    print(f"  Ratio Neg/Pos:         {n_neg/n_pos:.2f}")
else:
    print("  Ratio Neg/Pos:         N/A")
# Out:
# Structural Defects [Walls/Cracked]: +3851
# Structural Defects [Decks/Cracked]: +2025
# Structural Defects [Pavements/Cracked]: +2608
# Structural Defects [Walls/Non-cracked]: +14287
# Structural Defects [Decks/Non-cracked]: +11595
# Structural Defects [Pavements/Non-cracked]: +21726
# Dataset fusionado en: /content/data/merged_cracks
#   Positive (Grieta):    8484
#   Negative (Sin Grieta): 47608
#   Total:                 56092
#   Ratio Neg/Pos:         5.61

# %%
# Split en Train, Validation y Test
SOURCE_DIR = Path('./data/merged_cracks')
SPLIT_DIR  = Path('./data/split')

# Recopilar todos los paths y labels
all_paths  = []
all_labels = []

for img_path in sorted((SOURCE_DIR / 'Positive').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(1)
for img_path in sorted((SOURCE_DIR / 'Negative').glob('*.jpg')):
    all_paths.append(img_path)
    all_labels.append(0)

print(f"Total imágenes encontradas: {len(all_paths)}")
print(f"  Positivas: {sum(all_labels)}, Negativas: {len(all_labels) - sum(all_labels)}")

# Split 60% train / 20% val / 20% test
paths_tv, paths_test, y_tv, y_te = train_test_split(
    all_paths, all_labels, test_size=0.2, random_state=42, stratify=all_labels
)
paths_train, paths_val, y_tr, y_va = train_test_split(
    paths_tv, y_tv, test_size=0.25, random_state=42, stratify=y_tv
)

# Crear directorios y copiar archivos
splits = {'train': paths_train, 'val': paths_val, 'test': paths_test}

for split_name, split_paths in splits.items():
    for cls in ['Positive', 'Negative']:
        (SPLIT_DIR / split_name / cls).mkdir(parents=True, exist_ok=True)

    copied = 0
    for p in split_paths:
        cls = p.parent.name
        dest = SPLIT_DIR / split_name / cls / p.name
        if not dest.exists():
            shutil.copy2(str(p), str(dest))
            copied += 1

    total = len(list((SPLIT_DIR / split_name / 'Positive').iterdir())) + \
            len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))
    print(f"\n{split_name.upper()}: {total} imágenes ({copied} copiadas ahora)")
    print(f"  Positive: {len(list((SPLIT_DIR / split_name / 'Positive').iterdir()))}")
    print(f"  Negative: {len(list((SPLIT_DIR / split_name / 'Negative').iterdir()))}")
# Out:
# Total imágenes encontradas: 56092
#   Positivas: 8484, Negativas: 47608
#
# TRAIN: 33654 imágenes (33654 copiadas ahora)
#   Positive: 5090
#   Negative: 28564
#
# VAL: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522
#
# TEST: 11219 imágenes (11219 copiadas ahora)
#   Positive: 1697
#   Negative: 9522

# %%
import importlib

os.makedirs('models', exist_ok=True)

with open('models/cnn_simple3.py', 'w') as f:
    f.write("""
import tensorflow as tf
from tensorflow.keras import layers, models

def build_simple_3(input_shape=(227, 227, 3)):
    model = models.Sequential([
        layers.Input(shape=input_shape),

        layers.Conv2D(32, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(64, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(128, (3, 3), padding='same'),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        layers.GlobalAveragePooling2D(),
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.5), # Regularización fuerte
        layers.Dense(1, activation='sigmoid')
    ])
    return model
""")

sys.path.append('./models')

import cnn_simple3
importlib.reload(cnn_simple3)

from cnn_simple3 import build_simple_3

modelo_complejo = build_simple_3()
modelo_complejo.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 227, 227, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 227, 227, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 227, 227, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 113, 113, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 113, 113, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 113, 113, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 102,465 (400.25 KB)
#  Trainable params: 102,017 (398.50 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
# Carga de datos para entrenamiento
IMG_SIZE = (227, 227)
BATCH_SIZE = 32

datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

train_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'train'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=True, seed=42
)

val_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'val'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)

test_gen = datagen.flow_from_directory(
    str(SPLIT_DIR / 'test'), target_size=IMG_SIZE, color_mode='rgb',
    batch_size=BATCH_SIZE, class_mode='binary', shuffle=False
)
# Out:
# Found 33654 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.
# Found 11219 images belonging to 2 classes.

# %%
from tensorflow.keras.optimizers import Adam
# Compilacion y entrenamiento
model = build_simple_3(input_shape=(227, 227, 3))

# Compilamos usando un Learning Rate bajo
optimizer = Adam(learning_rate=0.00001)
model.compile(
    optimizer=optimizer,
    loss='binary_crossentropy',
    metrics=['accuracy', Recall(name='recall'), Precision(name='precision'), AUC(name='auc')]
)
csv_logger = CSVLogger('historial_entrenamiento_cnn3.csv', append=True)
checkpoint = ModelCheckpoint('best_cnn_model3.keras', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.0000001, verbose=1, mode='max')
early_stopping = EarlyStopping(monitor='val_accuracy', patience=30, restore_best_weights=True, mode='max')

n_pos = 8484   # Positive (Clase 1)
n_neg = 47608  # Negative (Clase 0)
total = n_pos + n_neg

# Fórmula para balancear pesos
weight_for_0 = (1 / n_neg) * (total / 2.0)
weight_for_1 = (1 / n_pos) * (total / 2.0)

class_weight = {
    0: weight_for_0,
    1: weight_for_1
}

print(f"Peso para Negative (0): {weight_for_0:.2f}")
print(f"Peso para Positive (1): {weight_for_1:.2f}")

history = model.fit(
    train_gen,
    validation_data=val_gen,
    class_weight=class_weight,
    epochs=120,
    callbacks=[checkpoint, reduce_lr, early_stopping, csv_logger]
)

# Cargar el modelo en su mejor punto
model.load_weights('best_cnn_model_3.keras')
# Out:
# Peso para Negative (0): 0.59
# Peso para Positive (1): 3.31
# Epoch 1/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4967 - auc: 0.5380 - loss: 0.7503 - precision: 0.1626 - recall: 0.5722
# Epoch 1: val_accuracy improved from None to 0.56547, saving model to best_resnet_model_6.keras
#
# Epoch 1: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 118s 102ms/step - accuracy: 0.5147 - auc: 0.5488 - loss: 0.7342 - precision: 0.1695 - recall: 0.5664 - val_accuracy: 0.5655 - val_auc: 0.6227 - val_loss: 0.6857 - val_precision: 0.1977 - val_recall: 0.6123 - learning_rate: 1.0000e-05
# Epoch 2/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5294 - auc: 0.5721 - loss: 0.7108 - precision: 0.1809 - recall: 0.5790
# Epoch 2: val_accuracy improved from 0.56547 to 0.61075, saving model to best_resnet_model_6.keras
#
# Epoch 2: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.5396 - auc: 0.5786 - loss: 0.6990 - precision: 0.1811 - recall: 0.5804 - val_accuracy: 0.6107 - val_auc: 0.6343 - val_loss: 0.6603 - val_precision: 0.2092 - val_recall: 0.5657 - learning_rate: 1.0000e-05
# Epoch 3/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5701 - auc: 0.6060 - loss: 0.6844 - precision: 0.1970 - recall: 0.5886
# Epoch 3: val_accuracy improved from 0.61075 to 0.65157, saving model to best_resnet_model_6.keras
#
# Epoch 3: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.5673 - auc: 0.6009 - loss: 0.6830 - precision: 0.1927 - recall: 0.5837 - val_accuracy: 0.6516 - val_auc: 0.6415 - val_loss: 0.6287 - val_precision: 0.2229 - val_recall: 0.5245 - learning_rate: 1.0000e-05
# Epoch 4/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.5763 - auc: 0.6071 - loss: 0.6810 - precision: 0.1995 - recall: 0.5889
# Epoch 4: val_accuracy did not improve from 0.65157
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 101s 96ms/step - accuracy: 0.5724 - auc: 0.6142 - loss: 0.6748 - precision: 0.1983 - recall: 0.6004 - val_accuracy: 0.5689 - val_auc: 0.6477 - val_loss: 0.6825 - val_precision: 0.2081 - val_recall: 0.6594 - learning_rate: 1.0000e-05
# Epoch 5/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5728 - auc: 0.6252 - loss: 0.6694 - precision: 0.2004 - recall: 0.6134
# Epoch 5: val_accuracy did not improve from 0.65157
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.5757 - auc: 0.6257 - loss: 0.6698 - precision: 0.2017 - recall: 0.6104 - val_accuracy: 0.6016 - val_auc: 0.6561 - val_loss: 0.6636 - val_precision: 0.2174 - val_recall: 0.6288 - learning_rate: 1.0000e-05
# Epoch 6/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.5870 - auc: 0.6351 - loss: 0.6682 - precision: 0.2094 - recall: 0.6155
# Epoch 6: val_accuracy did not improve from 0.65157
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 102s 96ms/step - accuracy: 0.5893 - auc: 0.6361 - loss: 0.6652 - precision: 0.2099 - recall: 0.6206 - val_accuracy: 0.6179 - val_auc: 0.6582 - val_loss: 0.6506 - val_precision: 0.2233 - val_recall: 0.6158 - learning_rate: 1.0000e-05
# Epoch 7/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5918 - auc: 0.6416 - loss: 0.6621 - precision: 0.2106 - recall: 0.6173
# Epoch 7: val_accuracy did not improve from 0.65157
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.5940 - auc: 0.6390 - loss: 0.6637 - precision: 0.2108 - recall: 0.6138 - val_accuracy: 0.6333 - val_auc: 0.6642 - val_loss: 0.6432 - val_precision: 0.2260 - val_recall: 0.5875 - learning_rate: 1.0000e-05
# Epoch 8/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6015 - auc: 0.6560 - loss: 0.6625 - precision: 0.2233 - recall: 0.6312
# Epoch 8: val_accuracy did not improve from 0.65157
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.6040 - auc: 0.6482 - loss: 0.6591 - precision: 0.2163 - recall: 0.6167 - val_accuracy: 0.6336 - val_auc: 0.6716 - val_loss: 0.6446 - val_precision: 0.2297 - val_recall: 0.6046 - learning_rate: 1.0000e-05
# Epoch 9/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6018 - auc: 0.6476 - loss: 0.6599 - precision: 0.2146 - recall: 0.6154
# Epoch 9: val_accuracy did not improve from 0.65157
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 102s 97ms/step - accuracy: 0.6001 - auc: 0.6520 - loss: 0.6579 - precision: 0.2158 - recall: 0.6242 - val_accuracy: 0.6280 - val_auc: 0.6725 - val_loss: 0.6464 - val_precision: 0.2272 - val_recall: 0.6075 - learning_rate: 1.0000e-05
# Epoch 10/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.
120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6121 - auc: 0.6758 - loss: 0.6487 - precision: 0.2292 - recall: 0.6522
# Epoch 17: val_accuracy did not improve from 0.66628
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 101s 96ms/step - accuracy: 0.6162 - auc: 0.6722 - loss: 0.6483 - precision: 0.2269 - recall: 0.6391 - val_accuracy: 0.6617 - val_auc: 0.6896 - val_loss: 0.6180 - val_precision: 0.2430 - val_recall: 0.5846 - learning_rate: 1.0000e-05
# Epoch 18/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6146 - auc: 0.6730 - loss: 0.6493 - precision: 0.2290 - recall: 0.6444
# Epoch 18: val_accuracy improved from 0.66628 to 0.68616, saving model to best_resnet_model_6.keras
#
# Epoch 18: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.6164 - auc: 0.6724 - loss: 0.6469 - precision: 0.2268 - recall: 0.6373 - val_accuracy: 0.6862 - val_auc: 0.6961 - val_loss: 0.6097 - val_precision: 0.2536 - val_recall: 0.5533 - learning_rate: 1.0000e-05
# Epoch 19/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6181 - auc: 0.6723 - loss: 0.6494 - precision: 0.2285 - recall: 0.6349
# Epoch 19: val_accuracy did not improve from 0.68616
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.6151 - auc: 0.6702 - loss: 0.6484 - precision: 0.2246 - recall: 0.6297 - val_accuracy: 0.6809 - val_auc: 0.7049 - val_loss: 0.6161 - val_precision: 0.2555 - val_recall: 0.5798 - learning_rate: 1.0000e-05
# Epoch 20/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6329 - auc: 0.6831 - loss: 0.6400 - precision: 0.2340 - recall: 0.6392
# Epoch 20: val_accuracy did not improve from 0.68616
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 127s 121ms/step - accuracy: 0.6249 - auc: 0.6802 - loss: 0.6439 - precision: 0.2329 - recall: 0.6454 - val_accuracy: 0.6547 - val_auc: 0.7001 - val_loss: 0.6213 - val_precision: 0.2454 - val_recall: 0.6181 - learning_rate: 1.0000e-05
# Epoch 21/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6243 - auc: 0.6812 - loss: 0.6392 - precision: 0.2302 - recall: 0.6471
# Epoch 21: val_accuracy did not improve from 0.68616
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 101s 96ms/step - accuracy: 0.6204 - auc: 0.6816 - loss: 0.6426 - precision: 0.2317 - recall: 0.6523 - val_accuracy: 0.5920 - val_auc: 0.6949 - val_loss: 0.6698 - val_precision: 0.2251 - val_recall: 0.6948 - learning_rate: 1.0000e-05
# Epoch 22/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6190 - auc: 0.6806 - loss: 0.6399 - precision: 0.2291 - recall: 0.6529
# Epoch 22: val_accuracy did not improve from 0.68616
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 102s 97ms/step - accuracy: 0.6226 - auc: 0.6820 - loss: 0.6423 - precision: 0.2326 - recall: 0.6503 - val_accuracy: 0.6411 - val_auc: 0.6994 - val_loss: 0.6343 - val_precision: 0.2397 - val_recall: 0.6317 - learning_rate: 1.0000e-05
# Epoch 23/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6375 - auc: 0.6817 - loss: 0.6403 - precision: 0.2351 - recall: 0.6288
# Epoch 23: val_accuracy improved from 0.68616 to 0.69498, saving model to best_resnet_model_6.keras
#
# Epoch 23: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 101s 96ms/step - accuracy: 0.6350 - auc: 0.6826 - loss: 0.6424 - precision: 0.2359 - recall: 0.6312 - val_accuracy: 0.6950 - val_auc: 0.7100 - val_loss: 0.6112 - val_precision: 0.2656 - val_recall: 0.5757 - learning_rate: 1.0000e-05
# Epoch 24/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6346 - auc: 0.6823 - loss: 0.6441 - precision: 0.2372 - recall: 0.6332
# Epoch 24: val_accuracy did not improve from 0.69498
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6319 - auc: 0.6821 - loss: 0.6427 - precision: 0.2355 - recall: 0.6383 - val_accuracy: 0.6782 - val_auc: 0.7072 - val_loss: 0.6167 - val_precision: 0.2580 - val_recall: 0.6011 - learning_rate: 1.0000e-05
# Epoch 25/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.6408 - auc: 0.6899 - loss: 0.6395 - precision: 0.2420 - recall: 0.6427
# Epoch 25: val_accuracy did not improve from 0.69498
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.6350 - auc: 0.6854 - loss: 0.6410 - precision: 0.2370 - recall: 0.6369 - val_accuracy: 0.6464 - val_auc: 0.7065 - val_loss: 0.6258 - val_precision: 0.2439 - val_recall: 0.6370 - learning_rate: 1.0000e-05
# Epoch 26/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6278 - auc: 0.6835 - loss: 0.6412 - precision: 0.2345 - recall: 0.6466
# Epoch 26: val_accuracy did not improve from 0.69498
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.6339 - auc: 0.6884 - loss: 0.6395 - precision: 0.2394 - recall: 0.6527 - val_accuracy: 0.6219 - val_auc: 0.7061 - val_loss: 0.6462 - val_precision: 0.2395 - val_recall: 0.6895 - learning_rate: 1.0000e-05
# Epoch 27/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6252 - auc: 0.6789 - loss: 0.6463 - precision: 0.2331 - recall: 0.6384
# Epoch 27: val_accuracy did not improve from 0.69498
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.6288 - auc: 0.6825 - loss: 0.6426 - precision: 0.2339 - recall: 0.6391 - val_accuracy: 0.6626 - val_auc: 0.7150 - val_loss: 0.6283 - val_precision: 0.2555 - val_recall: 0.6429 - learning_rate: 1.0000e-05
# Epoch 28/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6271 - auc: 0.6834 - loss: 0.6466 - precision: 0.2372 - recall: 0.6429
# Epoch 28: val_accuracy improved from 0.69498 to 0.70381, saving model to best_resnet_model_6.keras
#
# Epoch 28: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.6309 - auc: 0.6873 - loss: 0.6401 - precision: 0.2367 - recall: 0.6475 - val_accuracy: 0.7038 - val_auc: 0.7167 - val_loss: 0.6075 - val_precision: 0.2728 - val_recall: 0.5751 - learning_rate: 1.0000e-05
# Epoch 29/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6426 - auc: 0.6954 - loss: 0.6375 - precision: 0.2450 - recall: 0.6464
# Epoch 29: val_accuracy did not improve from 0.70381
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.6413 - auc: 0.6944 - loss: 0.6357 - precision: 0.2425 - recall: 0.6456 - val_accuracy: 0.7018 - val_auc: 0.7154 - val_loss: 0.5933 - val_precision: 0.2706 - val_recall: 0.5728 - learning_rate: 1.0000e-05
# Epoch 30/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6357 - auc: 0.6972 - loss: 0.6361 - precision: 0.2432 - recall: 0.6598
# Epoch 30: val_accuracy improved from 0.70381 to 0.73857, saving model to best_resnet_model_6.keras
#
# Epoch 30: finished saving model to best_resnet_model_6.keras
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6406 - auc: 0.6957 - loss: 0.6349 - precision: 0.2432 - recall: 0.6515 - val_accuracy: 0.7386 - val_auc: 0.7243 - val_loss: 0.5900 - val_precision: 0.2992 - val_recall: 0.5427 - learning_rate: 1.0000e-05
# Epoch 31/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6418 - auc: 0.6924 - loss: 0.6357 - precision: 0.2401 - recall: 0.6374
# Epoch 31: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 102s 97ms/step - accuracy: 0.6341 - auc: 0.6917 - loss: 0.6363 - precision: 0.2371 - recall: 0.6401 - val_accuracy: 0.6901 - val_auc: 0.7127 - val_loss: 0.5932 - val_precision: 0.2638 - val_recall: 0.5857 - learning_rate: 1.0000e-05
# Epoch 32/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6453 - auc: 0.6977 - loss: 0.6318 - precision: 0.2425 - recall: 0.6413
# Epoch 32: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.6401 - auc: 0.6977 - loss: 0.6332 - precision: 0.2427 - recall: 0.6507 - val_accuracy: 0.6427 - val_auc: 0.7148 - val_loss: 0.6252 - val_precision: 0.2460 - val_recall: 0.6594 - learning_rate: 1.0000e-05
# Epoch 33/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.6416 - auc: 0.6972 - loss: 0.6327 - precision: 0.2408 - recall: 0.6453
# Epoch 33: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.6396 - auc: 0.6979 - loss: 0.6337 - precision: 0.2420 - recall: 0.6485 - val_accuracy: 0.6414 - val_auc: 0.7171 - val_loss: 0.6378 - val_precision: 0.2498 - val_recall: 0.6841 - learning_rate: 1.0000e-05
# Epoch 34/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6428 - auc: 0.6980 - loss: 0.6288 - precision: 0.2397 - recall: 0.6453
# Epoch 34: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6432 - auc: 0.6978 - loss: 0.6332 - precision: 0.2439 - recall: 0.6472 - val_accuracy: 0.6610 - val_auc: 0.7222 - val_loss: 0.6150 - val_precision: 0.2552 - val_recall: 0.6470 - learning_rate: 1.0000e-05
# Epoch 35/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6357 - auc: 0.7014 - loss: 0.6346 - precision: 0.2455 - recall: 0.6636
# Epoch 35: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 98s 93ms/step - accuracy: 0.6438 - auc: 0.7003 - loss: 0.6318 - precision: 0.2453 - recall: 0.6527 - val_accuracy: 0.6972 - val_auc: 0.7235 - val_loss: 0.5910 - val_precision: 0.2713 - val_recall: 0.5940 - learning_rate: 1.0000e-05
# Epoch 36/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6317 - auc: 0.7008 - loss: 0.6365 - precision: 0.2458 - recall: 0.6695
# Epoch 36: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6375 - auc: 0.6976 - loss: 0.6328 - precision: 0.2413 - recall: 0.6511 - val_accuracy: 0.6788 - val_auc: 0.7256 - val_loss: 0.6079 - val_precision: 0.2654 - val_recall: 0.6352 - learning_rate: 1.0000e-05
# Epoch 37/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6473 - auc: 0.6998 - loss: 0.6313 - precision: 0.2439 - recall: 0.6464
# Epoch 37: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 101s 96ms/step - accuracy: 0.6447 - auc: 0.7027 - loss: 0.6307 - precision: 0.2466 - recall: 0.6568 - val_accuracy: 0.6637 - val_auc: 0.7223 - val_loss: 0.6102 - val_precision: 0.2561 - val_recall: 0.6423 - learning_rate: 1.0000e-05
# Epoch 38/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6492 - auc: 0.7033 - loss: 0.6316 - precision: 0.2483 - recall: 0.6467
# Epoch 38: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 99s 94ms/step - accuracy: 0.6460 - auc: 0.7011 - loss: 0.6315 - precision: 0.2462 - recall: 0.6503 - val_accuracy: 0.6679 - val_auc: 0.7233 - val_loss: 0.6149 - val_precision: 0.2594 - val_recall: 0.6447 - learning_rate: 1.0000e-05
# Epoch 39/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6289 - auc: 0.7011 - loss: 0.6366 - precision: 0.2453 - recall: 0.6708
# Epoch 39: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6391 - auc: 0.7039 - loss: 0.6293 - precision: 0.2445 - recall: 0.6631 - val_accuracy: 0.6597 - val_auc: 0.7279 - val_loss: 0.6152 - val_precision: 0.2585 - val_recall: 0.6688 - learning_rate: 1.0000e-05
# Epoch 40/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6533 - auc: 0.7091 - loss: 0.6252 - precision: 0.2502 - recall: 0.6528
# Epoch 40: val_accuracy did not improve from 0.73857
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6518 - auc: 0.7083 - loss: 0.6266 - precision: 0.2498 - recall: 0.6499 - val_accuracy: 0.6632 - val_auc: 0.7246 - val_loss: 0.6069 - val_precision: 0.2578 - val_recall: 0.6529 - learning_rate: 1.0000e-05
# Epoch 41/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6509 - auc: 0.7108 - loss: 0.6220 - precision: 0.2488 - recall: 0.6662
# Epoch 41: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6528 - auc: 0.7098 - loss: 0.6262 - precision: 0.2523 - recall: 0.6601 - val_accuracy: 0.6700 - val_auc: 0.7315 - val_loss: 0.6197 - val_precision: 0.2633 - val_recall: 0.6570 - learning_rate: 5.0000e-06
# Epoch 42/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6426 - auc: 0.7058 - loss: 0.6292 - precision: 0.2464 - recall: 0.6558
# Epoch 42: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 102s 96ms/step - accuracy: 0.6410 - auc: 0.7073 - loss: 0.6275 - precision: 0.2452 - recall: 0.6607 - val_accuracy: 0.7091 - val_auc: 0.7322 - val_loss: 0.5916 - val_precision: 0.2840 - val_recall: 0.6070 - learning_rate: 5.0000e-06
# Epoch 43/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6494 - auc: 0.7096 - loss: 0.6245 - precision: 0.2481 - recall: 0.6537
# Epoch 43: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 103s 97ms/step - accuracy: 0.6463 - auc: 0.7082 - loss: 0.6268 - precision: 0.2474 - recall: 0.6554 - val_accuracy: 0.6801 - val_auc: 0.7287 - val_loss: 0.6008 - val_precision: 0.2664 - val_recall: 0.6358 - learning_rate: 5.0000e-06
# Epoch 44/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6488 - auc: 0.7066 - loss: 0.6245 - precision: 0.2457 - recall: 0.6472
# Epoch 44: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━
120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6524 - auc: 0.7172 - loss: 0.6200 - precision: 0.2493 - recall: 0.6511
# Epoch 59: val_accuracy did not improve from 0.73857
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 100s 95ms/step - accuracy: 0.6563 - auc: 0.7205 - loss: 0.6190 - precision: 0.2541 - recall: 0.6576 - val_accuracy: 0.6901 - val_auc: 0.7354 - val_loss: 0.5925 - val_precision: 0.2743 - val_recall: 0.6376 - learning_rate: 2.5000e-06
# Epoch 60/120
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6524 - auc: 0.7085 - loss: 0.6211 - precision: 0.2469 - recall: 0.6525
# Epoch 60: val_accuracy did not improve from 0.73857
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 1052/1052 ━━━━━━━━━━━━━━━━━━━━ 101s 96ms/step - accuracy: 0.6537 - auc: 0.7168 - loss: 0.6210 - precision: 0.2536 - recall: 0.6639 - val_accuracy: 0.7088 - val_auc: 0.7394 - val_loss: 0.5857 - val_precision: 0.2865 - val_recall: 0.6205 - learning_rate: 2.5000e-06
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_4551/1784092675.py in <cell line: 0>()
#      40
#      41 # Cargar el modelo en su mejor punto
# ---> 42 model.load_weights('best_cnn_model_3.keras')
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1355                         filemode = modeDict[filemode]
#    1356                         continue
# -> 1357                     raise
#    1358                 break
#    1359         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best_cnn_model_3.keras'

# %%
model.load_weights('best_cnn_model3.keras')
# Buscamos el índice de la época con el mayor val_accuracy
best_epoch_idx = np.argmax(history.history['val_accuracy'])

# 1. CURVAS DE CONVERGENCIA DEL ENTRENAMIENTO
plt.figure(figsize=(14, 10))

# Gráfica de Loss
plt.subplot(2, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Función de Coste (Binary Crossentropy)')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.legend()

# Gráfica de Accuracy
plt.subplot(2, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Precisión (Accuracy)')
plt.xlabel('Época')
plt.ylabel('Accuracy')
plt.legend()

# Gráfica de AUC
plt.subplot(2, 2, 3)
plt.plot(history.history['auc'], label='Train AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Área bajo la curva (AUC) por época')
plt.xlabel('Época')
plt.ylabel('AUC')
plt.legend()

# Gráfica de Recall
plt.subplot(2, 2, 4)
plt.plot(history.history['recall'], label='Train Recall')
plt.plot(history.history['val_recall'], label='Val Recall')
plt.axvline(x=best_epoch_idx, color='r', linestyle='--', label=f'Mejor Modelo (Ép. {best_epoch_idx + 1})')
plt.title('Sensibilidad (Recall)')
plt.xlabel('Época')
plt.ylabel('Recall')
plt.legend()

plt.tight_layout()
plt.show()

# 2. PREDICCIONES Y EVALUACIÓN
print(f"\nEvaluando el mejor modelo guardado (Época {best_epoch_idx + 1})...")
eval_results = model.evaluate(test_gen, verbose=1)

print(f"\nMétricas de Test -> Loss: {eval_results[0]:.4f} | Accuracy: {eval_results[1]:.4f} | Recall: {eval_results[2]:.4f} | Precision: {eval_results[3]:.4f} | AUC: {eval_results[4]:.4f}")

predictions = model.predict(test_gen)
y_pred = (predictions > 0.5).astype(int).flatten()
y_true = test_gen.classes

# 3. CURVA ROC
plt.figure(figsize=(14, 6))
fpr, tpr, thresholds = roc_curve(y_true, predictions)
roc_auc = auc(fpr, tpr)
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'Curva ROC (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC del Modelo')
plt.legend(loc="lower right")

plt.tight_layout()
plt.show()

# 4. MATRIZ DE CONFUSIÓN Y REPORTE
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=test_gen.class_indices.keys(),
            yticklabels=test_gen.class_indices.keys())
plt.title('Matriz de Confusión ')
plt.ylabel('Real (Verdad)')
plt.xlabel('Predicción del Modelo')
plt.show()

print("\nReporte de Clasificación:")
print(classification_report(y_true, y_pred, target_names=test_gen.class_indices.keys()))
# Out:
# Evaluando el mejor modelo guardado (Época 30)...
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 24s 67ms/step - accuracy: 0.7414 - auc: 0.7519 - loss: 0.5878 - precision: 0.3153 - recall: 0.6058
#
# Métricas de Test -> Loss: 0.5878 | Accuracy: 0.7414 | Recall: 0.6058 | Precision: 0.3153 | AUC: 0.7519
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 22s 64ms/step
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#     Negative       0.92      0.77      0.83      9522
#     Positive       0.32      0.61      0.41      1697
#
#     accuracy                           0.74     11219
#    macro avg       0.62      0.69      0.62     11219
# weighted avg       0.83      0.74      0.77     11219

# %%
positive_dir = SPLIT_DIR / 'test' / 'Positive'
negative_dir = SPLIT_DIR / 'test' / 'Negative'
sample_positive_path = sorted(positive_dir.glob('*.jpg'))[5]
sample_negative_path = sorted(negative_dir.glob('*.jpg'))[5]

# Buscamos la primera capa convolucional
capa_base = model.layers[0]
if isinstance(capa_base, tf.keras.Model):
    conv_layer = [layer for layer in capa_base.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=capa_base.inputs, outputs=conv_layer.output)
    es_resnet = True
else:
    conv_layer = [layer for layer in model.layers if isinstance(layer, tf.keras.layers.Conv2D)][0]
    visual_model = Model(inputs=model.inputs, outputs=conv_layer.output)
    es_resnet = False

print(f"Extrayendo mapas de características de la capa: {conv_layer.name}")
num_filtros = min(6, conv_layer.filters)
muestras = [
    (sample_positive_path, 'Grieta (Positive)'),
    (sample_negative_path, 'Sin Grieta (Negative)')]
for path, label in muestras:
    # Cargar imagen original para mostrarla
    img_raw = load_img(path, target_size=(227, 227))
    img_array = img_to_array(img_raw)
    if es_resnet:
        img_procesada = preprocess_input(img_array.copy())
    else:
        img_procesada = img_array.copy() / 255.0
    img_batch = np.expand_dims(img_procesada, axis=0)
    # Extraer los mapas de características
    feature_maps = visual_model.predict(img_batch, verbose=0)
    fig, axes = plt.subplots(1, num_filtros + 1, figsize=(3 * (num_filtros + 1), 4))
    fig.suptitle(f"Análisis Interno - {label} | Capa: {conv_layer.name}", fontsize=16, fontweight='bold')
    axes[0].imshow(img_raw)
    axes[0].set_title("Original", fontsize=12)
    axes[0].axis('off')
    # Dibujar los mapas de características
    for i in range(num_filtros):
        axes[i + 1].imshow(feature_maps[0, :, :, i], cmap='viridis')
        axes[i + 1].set_title(f"Filtro {i}", fontsize=12)
        axes[i + 1].axis('off')
    plt.tight_layout()
    plt.show()
# Out:
# Extrayendo mapas de características de la capa: conv2d_3
